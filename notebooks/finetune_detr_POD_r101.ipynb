# %% [markdown]
# # Objective: fine-tuning DETR
#
# -   This notebook can be found on my Github profile: https://github.com/woctezuma/finetune-detr
# -   Official DETR repository: https://github.com/facebookresearch/detr
# -   Discussion about fine-tuning in [a Github issue](https://github.com/facebookresearch/detr/issues/9).
# -   A nice blog post about another approach (Mask R-CNN) and the balloon dataset (which we use in this notebook): [here](https://engineering.matterport.com/splash-of-color-instance-segmentation-with-mask-r-cnn-and-tensorflow-7c761e238b46).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Define useful boilerplate functions
#
# Adapted from:
# -   https://colab.research.google.com/github/facebookresearch/detr/blob/colab/notebooks/detr_attention.ipynb

# %%
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())

torch.set_grad_enabled(False);

import os
proj_path = "/content/drive/My Drive/Main Task"
os.chdir(proj_path)
# Out:
# 1.6.0+cu101 False

# %%
import torchvision.transforms as T

# standard PyTorch mean-std input image normalization
transform = T.Compose([
    T.Resize(800),
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# for output bounding box post-processing
def box_cxcywh_to_xyxy(x):
    x_c, y_c, w, h = x.unbind(1)
    b = [(x_c - 0.5 * w), (y_c - 0.5 * h),
         (x_c + 0.5 * w), (y_c + 0.5 * h)]
    return torch.stack(b, dim=1)

def rescale_bboxes(out_bbox, size):
    img_w, img_h = size
    b = box_cxcywh_to_xyxy(out_bbox)
    b = b * torch.tensor([img_w, img_h, img_w, img_h], dtype=torch.float32)
    return b

# %%
def filter_bboxes_from_outputs(outputs, size,
                               threshold=0.7):
  
  # keep only predictions with confidence above threshold
  probas = outputs['pred_logits'].softmax(-1)[0, :, :-1]
  keep = probas.max(-1).values > threshold

  probas_to_keep = probas[keep]

  # convert boxes from [0; 1] to image scales
  bboxes_scaled = rescale_bboxes(outputs['pred_boxes'][0, keep], size)
  
  return probas_to_keep, bboxes_scaled

# %%
def bb_intersection_over_union(boxA, boxB):
	# determine the (x, y)-coordinates of the intersection rectangle
	xA = max(boxA[0], boxB[0])
	yA = max(boxA[1], boxB[1])
	xB = min(boxA[2], boxB[2])
	yB = min(boxA[3], boxB[3])
	# compute the area of intersection rectangle
	interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)
	# compute the area of both the prediction and ground-truth
	# rectangles
	boxAArea = (boxA[2] - boxA[0] + 1) * (boxA[3] - boxA[1] + 1)
	boxBArea = (boxB[2] - boxB[0] + 1) * (boxB[3] - boxB[1] + 1)
	# compute the intersection over union by taking the intersection
	# area and dividing it by the sum of prediction + ground-truth
	# areas - the interesection area
	iou = interArea / float(boxAArea + boxBArea - interArea)
	# return the intersection over union value
	return iou

# %%
# colors for visualization
COLORS = [[0.000, 0.447, 0.741], [0.850, 0.325, 0.098], [0.929, 0.694, 0.125],
          [0.494, 0.184, 0.556], [0.466, 0.674, 0.188], [0.301, 0.745, 0.933]]

# %% [markdown]
# ## Load pre-trained weights
#
# Load a check-point (urls can be found [here](https://github.com/facebookresearch/detr#model-zoo)), then remove the classification head.

# %%
# Get pretrained weights
checkpoint = torch.hub.load_state_dict_from_url(
            url='https://dl.fbaipublicfiles.com/detr/detr-r101-2c7b67e5.pth',
            map_location='cpu',
            check_hash=True)

# Remove class weights
del checkpoint["model"]["class_embed.weight"]
del checkpoint["model"]["class_embed.bias"]

# Save
os.chdir(os.path.join(proj_path,"content/detr"))
torch.save(checkpoint,
           'detr-r101_no-class-head.pth')
# Out:
# Downloading: "https://dl.fbaipublicfiles.com/detr/detr-r101-2c7b67e5.pth" to /root/.cache/torch/hub/checkpoints/detr-r101-2c7b67e5.pth
# HBox(children=(FloatProgress(value=0.0, max=242846568.0), HTML(value='')))

# %% [markdown]
# ## Prepare the dataset for fine-tuning

# %% [markdown]
# We expect the directory structure to be the following:
# ```
# path/to/coco/
# ├ annotations/  # JSON annotations
# │  ├ annotations/custom_train.json
# │  └ annotations/custom_val.json
# ├ train2017/    # training images
# └ val2017/      # validation images
# ```

# %% [markdown]
# ## Check the dataset after it was pre-processed for fine-tuning
#
# To verify the data loading is correct, let's visualize the annotations of randomly selected samples in the training set:
# -   Demo of COCO API: https://github.com/cocodataset/cocoapi/blob/master/PythonAPI/pycocoDemo.ipynb

# %%
# %matplotlib inline
import pycocotools.coco as coco
from pycocotools.coco import COCO
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
from PIL import Image

# %%
dataDir=proj_path+'/content/data/POD/'
dataType='train'
annFile='{}annotations/train.json'.format(dataDir)

# %%
# initialize COCO api for instance annotations
coco=COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=0.86s)
# creating index...
# index created!

# %%
# display COCO categories and supercategories
cats = coco.loadCats(coco.getCatIds())
nms=[cat['name'] for cat in cats]
print(nms)
nms1 = set([cat['supercategory'] for cat in cats])
print(nms1)
# Out:
# ['abstract', 'author', 'caption', 'date', 'equation', 'figure', 'footer', 'formula', 'list', 'logo', 'natural_image', 'paragraph', 'reference', 'section', 'signature', 'table', 'title']
# {'none'}

# %%
# load and display image
catIds = coco.getCatIds(catNms=[])

for id in catIds:
  imgCount = len(coco.getImgIds(catIds=id))
  if imgCount > 0:
    print("id :",id,", name : ",nms[id],", image count : ",imgCount)

imgIds = coco.getImgIds(catIds=[5,7,15])
# will return images having all objects mentioned in the catIds list

#print(catIds)
print(len(imgIds))
# Out:
# id : 5 , name :  figure , image count :  539
# id : 7 , name :  formula , image count :  533
# id : 15 , name :  table , image count :  339
# 24

# %%
img_id = imgIds[np.random.randint(0,len(imgIds))]
#print(img_id)

img = coco.loadImgs(img_id)[0]

img_name = '%s/%s/%s'%(dataDir,dataType,img['file_name'])
print(img_name)

I = io.imread(img_name)
plt.imshow(I)
# Out:
# /content/drive/My Drive/Main Task/content/data/POD//train/POD_0249.bmp

# %%
annIds = coco.getAnnIds(imgIds=img['id'], catIds=catIds)
anns = coco.loadAnns(annIds)
print(annIds)
_ = [print(i) for i in anns]
# Out:
# [756, 757, 758, 759, 760, 761, 762, 763, 764, 765, 766, 767, 768, 769, 770, 771, 772, 773, 774, 775]
# {'id': 756, 'image_id': 193, 'segmentation': [], 'ignore': 0, 'area': 3708, 'iscrowd': 0, 'bbox': [157, 334, 206, 18], 'category_id': 1}
# {'id': 757, 'image_id': 193, 'segmentation': [], 'ignore': 0, 'area': 6479, 'iscrowd': 0, 'bbox': [157, 355, 341, 19], 'category_id': 1}
# {'id': 758, 'image_id': 193, 'segmentation': [], 'ignore': 0, 'area': 6860, 'iscrowd': 0, 'bbox': [155, 397, 343, 20], 'category_id': 1}
# {'id': 759, 'image_id': 193, 'segmentation': [], 'ignore': 0, 'area': 3980, 'iscrowd': 0, 'bbox': [156, 419, 199, 20], 'category_id': 1}
# {'id': 760, 'image_id': 193, 'segmentation': [], 'ignore': 0, 'area': 6960, 'iscrowd': 0, 'bbox': [155, 463, 348, 20], 'category_id': 1}
# {'id': 761, 'image_id': 193, 'segmentation': [], 'ignore': 0, 'area': 6860, 'iscrowd': 0, 'bbox': [156, 485, 343, 20], 'category_id': 1}
# {'id': 762, 'image_id': 193, 'segmentation': [], 'ignore': 0, 'area': 4032, 'iscrowd': 0, 'bbox': [157, 939, 224, 18], 'category_id': 1}
# {'id': 763, 'image_id': 193, 'segmentation': [], 'ignore': 0, 'area': 5022, 'iscrowd': 0, 'bbox': [157, 969, 279, 18], 'category_id': 1}
# {'id': 764, 'image_id': 193, 'segmentation': [], 'ignore': 0, 'area': 6820, 'iscrowd': 0, 'bbox': [157, 1010, 341, 20], 'category_id': 1}
# {'id': 765, 'image_id': 193, 'segmentation': [], 'ignore': 0, 'area': 5339, 'iscrowd': 0, 'bbox': [155, 1108, 281, 19], 'category_id': 1}
# {'id': 766, 'image_id': 193, 'segmentation': [], 'ignore': 0, 'area': 6182, 'iscrowd': 0, 'bbox': [155, 1135, 281, 22], 'category_id': 1}
# {'id': 767, 'image_id': 193, 'segmentation': [], 'ignore': 0, 'area': 5058, 'iscrowd': 0, 'bbox': [155, 1170, 281, 18], 'category_id': 1}
# {'id': 768, 'image_id': 193, 'segmentation': [], 'ignore': 0, 'area': 6463, 'iscrowd': 0, 'bbox': [155, 1195, 281, 23], 'category_id': 1}
# {'id': 769, 'image_id': 193, 'segmentation': [], 'ignore': 0, 'area': 5040, 'iscrowd': 0, 'bbox': [156, 1230, 280, 18], 'category_id': 1}
# {'id': 770, 'image_id': 193, 'segmentation': [], 'ignore': 0, 'area': 6444, 'iscrowd': 0, 'bbox': [563, 460, 358, 18], 'category_id': 1}
# {'id': 771, 'image_id': 193, 'segmentation': [], 'ignore': 0, 'area': 2448, 'iscrowd': 0, 'bbox': [563, 482, 136, 18], 'category_id': 1}
# {'id': 772, 'image_id': 193, 'segmentation': [], 'ignore': 0, 'area': 30783, 'iscrowd': 0, 'bbox': [568, 631, 331, 93], 'category_id': 0}
# {'id': 773, 'image_id': 193, 'segmentation': [], 'ignore': 0, 'area': 30783, 'iscrowd': 0, 'bbox': [567, 730, 331, 93], 'category_id': 0}
# {'id': 774, 'image_id': 193, 'segmentation': [], 'ignore': 0, 'area': 3564, 'iscrowd': 0, 'bbox': [559, 1260, 198, 18], 'category_id': 1}
# {'id': 775, 'image_id': 193, 'segmentation': [], 'ignore': 0, 'area': 18684, 'iscrowd': 0, 'bbox': [561, 1020, 346, 54], 'category_id': 2}

# %%
# load and display instance annotations
plt.imshow(I)
coco.showAnns(anns, draw_bbox=False)

# %%
plt.imshow(I)
coco.showAnns(anns, draw_bbox=True)

# %% [markdown]
# ## Fine-tuning
#
# -   Instructions appear in [a Github Gist](https://gist.github.com/mlk1337/651297e28199b4bb7907fc413c49f58f).
#
# NB: There is a `--frozen_weights` argument. However,
# i) I have yet to figure out how it is used,
# ii) it is of no use for box detection. Indeed, "frozen training is meant for segmentation only" (as mentioned at this [line](https://github.com/facebookresearch/detr/blob/f4cdc542de34de771da8b9189742e5465f5220cd/main.py#L110) of the source-code).

# %% [markdown]
# ## Boilerplate variables
# Caveat: the parameter name num_classes is misleading. It is actually the ID which DETR will reserve for its own no_object class.
#
# It should be set to one plus the highest class ID in your dataset.
#
# For instance, if you have one class (balloon):
#
# -   if you used the index n°0 for this class, then max_id = 0 and num_classes = max_id+1 = 1
# -   if you used the index n°1 for this class, then max_id = 1 and num_classes = max_id+1 = 2
#
# Reference: https://github.com/facebookresearch/detr/issues/108#issuecomment-650269223

# %%
# Fine-tuned classes
finetuned_classes = [
                     'abstract', 'author', 'caption', 'date', 'equation', 'figure', 'footer', 'formula', 'list', 'logo', 'natural_image', 'paragraph', 'reference', 'section', 'signature', 'table', 'title'
]

num_classes = len(finetuned_classes)
print(num_classes)
# Out:
# 17

# %%
os.chdir(os.path.join(proj_path,"content/detr"))
print(os.getcwd())

#resume "/content/drive/My Drive/Main Task/content/detr/outputs/checkpoint.pth" \
#resume "/content/drive/My Drive/Main Task/content/detr/detr-r101_no-class-head.pth" \
# Out:
# /content/drive/My Drive/Main Task/content/detr

# %%
# !python main.py \
  --dataset_file "custom" \
  --coco_path "/content/drive/My Drive/Main Task/content/data/POD" \
  --output_dir "outputs" \
  --resume "/content/drive/My Drive/Main Task/content/detr/outputs/checkpoint.pth" \
  --num_classes $num_classes \
  --epochs 100 \
  --device "cuda" \
  --batch_size 4  \
  --backbone "resnet101"
# Out:
# Not using distributed mode
# git:
#   sha: 6ecf58fe5e8eb503cb3be015983756789a9964f5, status: has uncommited changes, branch: finetune
#
# Namespace(aux_loss=True, backbone='resnet101', batch_size=4, bbox_loss_coef=5, clip_max_norm=0.1, coco_panoptic_path=None, coco_path='/content/drive/My Drive/Main Task/content/data/POD', dataset_file='custom', dec_layers=6, device='cuda', dice_loss_coef=1, dilation=False, dim_feedforward=2048, dist_url='env://', distributed=False, dropout=0.1, enc_layers=6, eos_coef=0.1, epochs=100, eval=False, frozen_weights=None, giou_loss_coef=2, hidden_dim=256, lr=0.0001, lr_backbone=1e-05, lr_drop=200, mask_loss_coef=1, masks=False, nheads=8, num_classes=17, num_queries=100, num_workers=2, output_dir='outputs', position_embedding='sine', pre_norm=False, remove_difficult=False, resume='/content/drive/My Drive/Main Task/content/detr/outputs/checkpoint.pth', seed=42, set_cost_bbox=5, set_cost_class=1, set_cost_giou=2, start_epoch=0, weight_decay=0.0001, world_size=1)
# number of params: 60223254
# loading annotations into memory...
# Done (t=0.07s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Start training
# Epoch: [80]  [  0/240]  eta: 0:05:30  lr: 0.000100  class_error: 25.00  loss: 1.5793 (1.5793)  loss_ce: 0.0419 (0.0419)  loss_bbox: 0.0469 (0.0469)  loss_giou: 0.0766 (0.0766)  loss_ce_0: 0.0880 (0.0880)  loss_bbox_0: 0.1234 (0.1234)  loss_giou_0: 0.2558 (0.2558)  loss_ce_1: 0.0711 (0.0711)  loss_bbox_1: 0.0830 (0.0830)  loss_giou_1: 0.1283 (0.1283)  loss_ce_2: 0.0485 (0.0485)  loss_bbox_2: 0.0488 (0.0488)  loss_giou_2: 0.1573 (0.1573)  loss_ce_3: 0.0846 (0.0846)  loss_bbox_3: 0.0479 (0.0479)  loss_giou_3: 0.0792 (0.0792)  loss_ce_4: 0.0420 (0.0420)  loss_bbox_4: 0.0703 (0.0703)  loss_giou_4: 0.0856 (0.0856)  loss_ce_unscaled: 0.0419 (0.0419)  class_error_unscaled: 25.0000 (25.0000)  loss_bbox_unscaled: 0.0094 (0.0094)  loss_giou_unscaled: 0.0383 (0.0383)  cardinality_error_unscaled: 0.7500 (0.7500)  loss_ce_0_unscaled: 0.0880 (0.0880)  loss_bbox_0_unscaled: 0.0247 (0.0247)  loss_giou_0_unscaled: 0.1279 (0.1279)  cardinality_error_0_unscaled: 0.7500 (0.7500)  loss_ce_1_unscaled: 0.0711 (0.0711)  loss_bbox_1_unscaled: 0.0166 (0.0166)  loss_giou_1_unscaled: 0.0642 (0.0642)  cardinality_error_1_unscaled: 1.0000 (1.0000)  loss_ce_2_unscaled: 0.0485 (0.0485)  loss_bbox_2_unscaled: 0.0098 (0.0098)  loss_giou_2_unscaled: 0.0787 (0.0787)  cardinality_error_2_unscaled: 0.7500 (0.7500)  loss_ce_3_unscaled: 0.0846 (0.0846)  loss_bbox_3_unscaled: 0.0096 (0.0096)  loss_giou_3_unscaled: 0.0396 (0.0396)  cardinality_error_3_unscaled: 0.5000 (0.5000)  loss_ce_4_unscaled: 0.0420 (0.0420)  loss_bbox_4_unscaled: 0.0141 (0.0141)  loss_giou_4_unscaled: 0.0428 (0.0428)  cardinality_error_4_unscaled: 0.7500 (0.7500)  time: 1.3776  data: 0.5318  max mem: 3165
# Epoch: [80]  [ 10/240]  eta: 0:03:49  lr: 0.000100  class_error: 0.00  loss: 3.3614 (3.4728)  loss_ce: 0.0793 (0.1032)  loss_bbox: 0.1101 (0.1031)  loss_giou: 0.3850 (0.3515)  loss_ce_0: 0.1282 (0.1364)  loss_bbox_0: 0.1521 (0.1563)  loss_giou_0: 0.3521 (0.3975)  loss_ce_1: 0.0735 (0.1194)  loss_bbox_1: 0.1283 (0.1256)  loss_giou_1: 0.3552 (0.3407)  loss_ce_2: 0.0918 (0.1009)  loss_bbox_2: 0.1077 (0.1093)  loss_giou_2: 0.3339 (0.3298)  loss_ce_3: 0.0878 (0.1083)  loss_bbox_3: 0.1006 (0.1063)  loss_giou_3: 0.2992 (0.3305)  loss_ce_4: 0.0768 (0.1086)  loss_bbox_4: 0.0986 (0.1091)  loss_giou_4: 0.3657 (0.3362)  loss_ce_unscaled: 0.0793 (0.1032)  class_error_unscaled: 9.0909 (12.1481)  loss_bbox_unscaled: 0.0220 (0.0206)  loss_giou_unscaled: 0.1925 (0.1758)  cardinality_error_unscaled: 0.5000 (0.8636)  loss_ce_0_unscaled: 0.1282 (0.1364)  loss_bbox_0_unscaled: 0.0304 (0.0313)  loss_giou_0_unscaled: 0.1761 (0.1987)  cardinality_error_0_unscaled: 0.7500 (2.0909)  loss_ce_1_unscaled: 0.0735 (0.1194)  loss_bbox_1_unscaled: 0.0257 (0.0251)  loss_giou_1_unscaled: 0.1776 (0.1703)  cardinality_error_1_unscaled: 1.0000 (1.6591)  loss_ce_2_unscaled: 0.0918 (0.1009)  loss_bbox_2_unscaled: 0.0215 (0.0219)  loss_giou_2_unscaled: 0.1669 (0.1649)  cardinality_error_2_unscaled: 0.5000 (1.0227)  loss_ce_3_unscaled: 0.0878 (0.1083)  loss_bbox_3_unscaled: 0.0201 (0.0213)  loss_giou_3_unscaled: 0.1496 (0.1652)  cardinality_error_3_unscaled: 0.2500 (0.9545)  loss_ce_4_unscaled: 0.0768 (0.1086)  loss_bbox_4_unscaled: 0.0197 (0.0218)  loss_giou_4_unscaled: 0.1828 (0.1681)  cardinality_error_4_unscaled: 0.5000 (0.8864)  time: 0.9999  data: 0.0650  max mem: 6981
# Epoch: [80]  [ 20/240]  eta: 0:03:41  lr: 0.000100  class_error: 0.00  loss: 4.0532 (3.7501)  loss_ce: 0.1195 (0.1065)  loss_bbox: 0.1098 (0.1054)  loss_giou: 0.3850 (0.3741)  loss_ce_0: 0.1548 (0.1899)  loss_bbox_0: 0.1521 (0.1521)  loss_giou_0: 0.4514 (0.4219)  loss_ce_1: 0.1392 (0.1421)  loss_bbox_1: 0.1283 (0.1262)  loss_giou_1: 0.3775 (0.3698)  loss_ce_2: 0.1004 (0.1249)  loss_bbox_2: 0.1084 (0.1124)  loss_giou_2: 0.3999 (0.3583)  loss_ce_3: 0.0910 (0.1211)  loss_bbox_3: 0.1027 (0.1092)  loss_giou_3: 0.3812 (0.3561)  loss_ce_4: 0.1312 (0.1163)  loss_bbox_4: 0.1078 (0.1098)  loss_giou_4: 0.3657 (0.3538)  loss_ce_unscaled: 0.1195 (0.1065)  class_error_unscaled: 9.0909 (10.9318)  loss_bbox_unscaled: 0.0220 (0.0211)  loss_giou_unscaled: 0.1925 (0.1870)  cardinality_error_unscaled: 0.7500 (1.2738)  loss_ce_0_unscaled: 0.1548 (0.1899)  loss_bbox_0_unscaled: 0.0304 (0.0304)  loss_giou_0_unscaled: 0.2257 (0.2110)  cardinality_error_0_unscaled: 2.2500 (3.0238)  loss_ce_1_unscaled: 0.1392 (0.1421)  loss_bbox_1_unscaled: 0.0257 (0.0252)  loss_giou_1_unscaled: 0.1887 (0.1849)  cardinality_error_1_unscaled: 1.5000 (2.6310)  loss_ce_2_unscaled: 0.1004 (0.1249)  loss_bbox_2_unscaled: 0.0217 (0.0225)  loss_giou_2_unscaled: 0.2000 (0.1791)  cardinality_error_2_unscaled: 0.7500 (1.8333)  loss_ce_3_unscaled: 0.0910 (0.1211)  loss_bbox_3_unscaled: 0.0205 (0.0218)  loss_giou_3_unscaled: 0.1906 (0.1781)  cardinality_error_3_unscaled: 0.7500 (1.3810)  loss_ce_4_unscaled: 0.1312 (0.1163)  loss_bbox_4_unscaled: 0.0216 (0.0220)  loss_giou_4_unscaled: 0.1828 (0.1769)  cardinality_error_4_unscaled: 0.7500 (1.2857)  time: 0.9870  data: 0.0180  max mem: 8375
# Epoch: [80]  [ 30/240]  eta: 0:03:31  lr: 0.000100  class_error: 0.00  loss: 3.5305 (3.8021)  loss_ce: 0.0883 (0.1094)  loss_bbox: 0.0987 (0.1041)  loss_giou: 0.3864 (0.3757)  loss_ce_0: 0.1969 (0.1926)  loss_bbox_0: 0.1466 (0.1517)  loss_giou_0: 0.4292 (0.4225)  loss_ce_1: 0.1392 (0.1512)  loss_bbox_1: 0.1079 (0.1211)  loss_giou_1: 0.3835 (0.3791)  loss_ce_2: 0.1043 (0.1266)  loss_bbox_2: 0.1137 (0.1101)  loss_giou_2: 0.4023 (0.3699)  loss_ce_3: 0.0820 (0.1180)  loss_bbox_3: 0.1018 (0.1085)  loss_giou_3: 0.3956 (0.3734)  loss_ce_4: 0.1278 (0.1226)  loss_bbox_4: 0.0976 (0.1071)  loss_giou_4: 0.3594 (0.3584)  loss_ce_unscaled: 0.0883 (0.1094)  class_error_unscaled: 6.2500 (9.2839)  loss_bbox_unscaled: 0.0197 (0.0208)  loss_giou_unscaled: 0.1932 (0.1879)  cardinality_error_unscaled: 1.2500 (1.9597)  loss_ce_0_unscaled: 0.1969 (0.1926)  loss_bbox_0_unscaled: 0.0293 (0.0303)  loss_giou_0_unscaled: 0.2146 (0.2112)  cardinality_error_0_unscaled: 3.2500 (4.2903)  loss_ce_1_unscaled: 0.1392 (0.1512)  loss_bbox_1_unscaled: 0.0216 (0.0242)  loss_giou_1_unscaled: 0.1918 (0.1895)  cardinality_error_1_unscaled: 2.5000 (3.4274)  loss_ce_2_unscaled: 0.1043 (0.1266)  loss_bbox_2_unscaled: 0.0227 (0.0220)  loss_giou_2_unscaled: 0.2012 (0.1850)  cardinality_error_2_unscaled: 2.0000 (2.6532)  loss_ce_3_unscaled: 0.0820 (0.1180)  loss_bbox_3_unscaled: 0.0204 (0.0217)  loss_giou_3_unscaled: 0.1978 (0.1867)  cardinality_error_3_unscaled: 1.2500 (2.0081)  loss_ce_4_unscaled: 0.1278 (0.1226)  loss_bbox_4_unscaled: 0.0195 (0.0214)  loss_giou_4_unscaled: 0.1797 (0.1792)  cardinality_error_4_unscaled: 1.5000 (1.9194)  time: 1.0132  data: 0.0182  max mem: 8375
# Epoch: [80]  [ 40/240]  eta: 0:03:22  lr: 0.000100  class_error: 0.00  loss: 3.3405 (3.6740)  loss_ce: 0.0739 (0.1016)  loss_bbox: 0.0873 (0.1012)  loss_giou: 0.2989 (0.3556)  loss_ce_0: 0.1467 (0.1821)  loss_bbox_0: 0.1465 (0.1498)  loss_giou_0: 0.3989 (0.4052)  loss_ce_1: 0.1148 (0.1428)  loss_bbox_1: 0.1097 (0.1202)  loss_giou_1: 0.3637 (0.3762)  loss_ce_2: 0.0910 (0.1207)  loss_bbox_2: 0.1066 (0.1103)  loss_giou_2: 0.3536 (0.3642)  loss_ce_3: 0.0765 (0.1137)  loss_bbox_3: 0.0986 (0.1083)  loss_giou_3: 0.3445 (0.3596)  loss_ce_4: 0.0783 (0.1125)  loss_bbox_4: 0.0962 (0.1033)  loss_giou_4: 0.3023 (0.3469)  loss_ce_unscaled: 0.0739 (0.1016)  class_error_unscaled: 5.8824 (9.1348)  loss_bbox_unscaled: 0.0175 (0.0202)  loss_giou_unscaled: 0.1494 (0.1778)  cardinality_error_unscaled: 0.7500 (1.7012)  loss_ce_0_unscaled: 0.1467 (0.1821)  loss_bbox_0_unscaled: 0.0293 (0.0300)  loss_giou_0_unscaled: 0.1995 (0.2026)  cardinality_error_0_unscaled: 4.2500 (4.3171)  loss_ce_1_unscaled: 0.1148 (0.1428)  loss_bbox_1_unscaled: 0.0219 (0.0240)  loss_giou_1_unscaled: 0.1818 (0.1881)  cardinality_error_1_unscaled: 2.5000 (3.3780)  loss_ce_2_unscaled: 0.0910 (0.1207)  loss_bbox_2_unscaled: 0.0213 (0.0221)  loss_giou_2_unscaled: 0.1768 (0.1821)  cardinality_error_2_unscaled: 2.0000 (2.4756)  loss_ce_3_unscaled: 0.0765 (0.1137)  loss_bbox_3_unscaled: 0.0197 (0.0217)  loss_giou_3_unscaled: 0.1722 (0.1798)  cardinality_error_3_unscaled: 1.0000 (1.8049)  loss_ce_4_unscaled: 0.0783 (0.1125)  loss_bbox_4_unscaled: 0.0192 (0.0207)  loss_giou_4_unscaled: 0.1511 (0.1734)  cardinality_error_4_unscaled: 1.0000 (1.6768)  time: 1.0157  data: 0.0181  max mem: 8375
# Epoch: [80]  [ 50/240]  eta: 0:03:15  lr: 0.000100  class_error: 15.79  loss: 3.6666 (3.8208)  loss_ce: 0.0854 (0.1091)  loss_bbox: 0.0980 (0.1034)  loss_giou: 0.3299 (0.3704)  loss_ce_0: 0.1632 (0.1894)  loss_bbox_0: 0.1529 (0.1533)  loss_giou_0: 0.3927 (0.4235)  loss_ce_1: 0.1269 (0.1547)  loss_bbox_1: 0.1150 (0.1242)  loss_giou_1: 0.3637 (0.3859)  loss_ce_2: 0.1050 (0.1271)  loss_bbox_2: 0.1053 (0.1105)  loss_giou_2: 0.3536 (0.3771)  loss_ce_3: 0.1027 (0.1200)  loss_bbox_3: 0.1059 (0.1085)  loss_giou_3: 0.3660 (0.3772)  loss_ce_4: 0.0849 (0.1191)  loss_bbox_4: 0.0964 (0.1047)  loss_giou_4: 0.3096 (0.3626)  loss_ce_unscaled: 0.0854 (0.1091)  class_error_unscaled: 0.0000 (8.7683)  loss_bbox_unscaled: 0.0196 (0.0207)  loss_giou_unscaled: 0.1650 (0.1852)  cardinality_error_unscaled: 0.7500 (2.0833)  loss_ce_0_unscaled: 0.1632 (0.1894)  loss_bbox_0_unscaled: 0.0306 (0.0307)  loss_giou_0_unscaled: 0.1964 (0.2118)  cardinality_error_0_unscaled: 4.7500 (4.8088)  loss_ce_1_unscaled: 0.1269 (0.1547)  loss_bbox_1_unscaled: 0.0230 (0.0248)  loss_giou_1_unscaled: 0.1818 (0.1930)  cardinality_error_1_unscaled: 3.2500 (3.7255)  loss_ce_2_unscaled: 0.1050 (0.1271)  loss_bbox_2_unscaled: 0.0211 (0.0221)  loss_giou_2_unscaled: 0.1768 (0.1885)  cardinality_error_2_unscaled: 2.2500 (2.7745)  loss_ce_3_unscaled: 0.1027 (0.1200)  loss_bbox_3_unscaled: 0.0212 (0.0217)  loss_giou_3_unscaled: 0.1830 (0.1886)  cardinality_error_3_unscaled: 0.7500 (2.0588)  loss_ce_4_unscaled: 0.0849 (0.1191)  loss_bbox_4_unscaled: 0.0193 (0.0209)  loss_giou_4_unscaled: 0.1548 (0.1813)  cardinality_error_4_unscaled: 0.7500 (1.9853)  time: 1.0601  data: 0.0177  max mem: 8375
# Epoch: [80]  [ 60/240]  eta: 0:03:03  lr: 0.000100  class_error: 0.00  loss: 4.0062 (3.9270)  loss_ce: 0.1343 (0.1146)  loss_bbox: 0.1190 (0.1073)  loss_giou: 0.4123 (0.3804)  loss_ce_0: 0.2206 (0.1964)  loss_bbox_0: 0.1602 (0.1564)  loss_giou_0: 0.4948 (0.4299)  loss_ce_1: 0.1972 (0.1614)  loss_bbox_1: 0.1240 (0.1264)  loss_giou_1: 0.3633 (0.3950)  loss_ce_2: 0.1607 (0.1355)  loss_bbox_2: 0.1146 (0.1135)  loss_giou_2: 0.3803 (0.3851)  loss_ce_3: 0.1266 (0.1240)  loss_bbox_3: 0.1081 (0.1123)  loss_giou_3: 0.3933 (0.3865)  loss_ce_4: 0.1290 (0.1200)  loss_bbox_4: 0.1155 (0.1096)  loss_giou_4: 0.4229 (0.3725)  loss_ce_unscaled: 0.1343 (0.1146)  class_error_unscaled: 5.5556 (9.0413)  loss_bbox_unscaled: 0.0238 (0.0215)  loss_giou_unscaled: 0.2061 (0.1902)  cardinality_error_unscaled: 1.0000 (2.1230)  loss_ce_0_unscaled: 0.2206 (0.1964)  loss_bbox_0_unscaled: 0.0320 (0.0313)  loss_giou_0_unscaled: 0.2474 (0.2150)  cardinality_error_0_unscaled: 5.0000 (4.8484)  loss_ce_1_unscaled: 0.1972 (0.1614)  loss_bbox_1_unscaled: 0.0248 (0.0253)  loss_giou_1_unscaled: 0.1817 (0.1975)  cardinality_error_1_unscaled: 3.7500 (3.8115)  loss_ce_2_unscaled: 0.1607 (0.1355)  loss_bbox_2_unscaled: 0.0229 (0.0227)  loss_giou_2_unscaled: 0.1902 (0.1926)  cardinality_error_2_unscaled: 2.2500 (2.7377)  loss_ce_3_unscaled: 0.1266 (0.1240)  loss_bbox_3_unscaled: 0.0216 (0.0225)  loss_giou_3_unscaled: 0.1966 (0.1933)  cardinality_error_3_unscaled: 1.0000 (2.1025)  loss_ce_4_unscaled: 0.1290 (0.1200)  loss_bbox_4_unscaled: 0.0231 (0.0219)  loss_giou_4_unscaled: 0.2114 (0.1862)  cardinality_error_4_unscaled: 1.2500 (2.0492)  time: 1.0405  data: 0.0181  max mem: 8375
# Epoch: [80]  [ 70/240]  eta: 0:02:52  lr: 0.000100  class_error: 28.57  loss: 3.9709 (3.9936)  loss_ce: 0.1217 (0.1168)  loss_bbox: 0.1035 (0.1102)  loss_giou: 0.3823 (0.3868)  loss_ce_0: 0.2277 (0.2041)  loss_bbox_0: 0.1614 (0.1614)  loss_giou_0: 0.4189 (0.4325)  loss_ce_1: 0.1629 (0.1657)  loss_bbox_1: 0.1331 (0.1302)  loss_giou_1: 0.3551 (0.3960)  loss_ce_2: 0.1432 (0.1396)  loss_bbox_2: 0.1207 (0.1186)  loss_giou_2: 0.3942 (0.3898)  loss_ce_3: 0.1081 (0.1268)  loss_bbox_3: 0.1117 (0.1148)  loss_giou_3: 0.3716 (0.3893)  loss_ce_4: 0.1151 (0.1216)  loss_bbox_4: 0.1099 (0.1120)  loss_giou_4: 0.4031 (0.3774)  loss_ce_unscaled: 0.1217 (0.1168)  class_error_unscaled: 6.6667 (9.2206)  loss_bbox_unscaled: 0.0207 (0.0220)  loss_giou_unscaled: 0.1912 (0.1934)  cardinality_error_unscaled: 1.0000 (2.1021)  loss_ce_0_unscaled: 0.2277 (0.2041)  loss_bbox_0_unscaled: 0.0323 (0.0323)  loss_giou_0_unscaled: 0.2094 (0.2162)  cardinality_error_0_unscaled: 4.2500 (4.8592)  loss_ce_1_unscaled: 0.1629 (0.1657)  loss_bbox_1_unscaled: 0.0266 (0.0260)  loss_giou_1_unscaled: 0.1776 (0.1980)  cardinality_error_1_unscaled: 2.7500 (3.8521)  loss_ce_2_unscaled: 0.1432 (0.1396)  loss_bbox_2_unscaled: 0.0241 (0.0237)  loss_giou_2_unscaled: 0.1971 (0.1949)  cardinality_error_2_unscaled: 1.5000 (2.7324)  loss_ce_3_unscaled: 0.1081 (0.1268)  loss_bbox_3_unscaled: 0.0223 (0.0230)  loss_giou_3_unscaled: 0.1858 (0.1947)  cardinality_error_3_unscaled: 1.2500 (2.1761)  loss_ce_4_unscaled: 0.1151 (0.1216)  loss_bbox_4_unscaled: 0.0220 (0.0224)  loss_giou_4_unscaled: 0.2015 (0.1887)  cardinality_error_4_unscaled: 1.0000 (2.0739)  time: 0.9789  data: 0.0178  max mem: 8375
# Epoch: [80]  [ 80/240]  eta: 0:02:41  lr: 0.000100  class_error: 20.00  loss: 3.2684 (4.0047)  loss_ce: 0.0781 (0.1182)  loss_bbox: 0.1035 (0.1094)  loss_giou: 0.3786 (0.3864)  loss_ce_0: 0.1921 (0.2054)  loss_bbox_0: 0.1389 (0.1591)  loss_giou_0: 0.4198 (0.4334)  loss_ce_1: 0.1814 (0.1708)  loss_bbox_1: 0.1274 (0.1293)  loss_giou_1: 0.3596 (0.3966)  loss_ce_2: 0.1432 (0.1439)  loss_bbox_2: 0.1078 (0.1175)  loss_giou_2: 0.4113 (0.3917)  loss_ce_3: 0.1070 (0.1300)  loss_bbox_3: 0.1054 (0.1137)  loss_giou_3: 0.3304 (0.3895)  loss_ce_4: 0.1050 (0.1222)  loss_bbox_4: 0.1048 (0.1110)  loss_giou_4: 0.3570 (0.3766)  loss_ce_unscaled: 0.0781 (0.1182)  class_error_unscaled: 0.0000 (9.1493)  loss_bbox_unscaled: 0.0207 (0.0219)  loss_giou_unscaled: 0.1893 (0.1932)  cardinality_error_unscaled: 1.2500 (2.2160)  loss_ce_0_unscaled: 0.1921 (0.2054)  loss_bbox_0_unscaled: 0.0278 (0.0318)  loss_giou_0_unscaled: 0.2099 (0.2167)  cardinality_error_0_unscaled: 4.2500 (5.0370)  loss_ce_1_unscaled: 0.1814 (0.1708)  loss_bbox_1_unscaled: 0.0255 (0.0259)  loss_giou_1_unscaled: 0.1798 (0.1983)  cardinality_error_1_unscaled: 4.0000 (4.1235)  loss_ce_2_unscaled: 0.1432 (0.1439)  loss_bbox_2_unscaled: 0.0216 (0.0235)  loss_giou_2_unscaled: 0.2056 (0.1959)  cardinality_error_2_unscaled: 2.7500 (2.8395)  loss_ce_3_unscaled: 0.1070 (0.1300)  loss_bbox_3_unscaled: 0.0211 (0.0227)  loss_giou_3_unscaled: 0.1652 (0.1947)  cardinality_error_3_unscaled: 1.5000 (2.3858)  loss_ce_4_unscaled: 0.1050 (0.1222)  loss_bbox_4_unscaled: 0.0210 (0.0222)  loss_giou_4_unscaled: 0.1785 (0.1883)  cardinality_error_4_unscaled: 1.5000 (2.2130)  time: 0.9827  data: 0.0173  max mem: 8375
# Epoch: [80]  [ 90/240]  eta: 0:02:33  lr: 0.000100  class_error: 0.00  loss: 3.4611 (3.9668)  loss_ce: 0.0915 (0.1183)  loss_bbox: 0.0994 (0.1086)  loss_giou: 0.3495 (0.3800)  loss_ce_0: 0.2048 (0.2060)  loss_bbox_0: 0.1356 (0.1580)  loss_giou_0: 0.4159 (0.4293)  loss_ce_1: 0.1730 (0.1716)  loss_bbox_1: 0.1037 (0.1276)  loss_giou_1: 0.3596 (0.3929)  loss_ce_2: 0.1260 (0.1431)  loss_bbox_2: 0.1020 (0.1163)  loss_giou_2: 0.3718 (0.3869)  loss_ce_3: 0.1214 (0.1305)  loss_bbox_3: 0.1043 (0.1128)  loss_giou_3: 0.3255 (0.3825)  loss_ce_4: 0.0975 (0.1231)  loss_bbox_4: 0.1006 (0.1100)  loss_giou_4: 0.3211 (0.3693)  loss_ce_unscaled: 0.0915 (0.1183)  class_error_unscaled: 4.0000 (9.0249)  loss_bbox_unscaled: 0.0199 (0.0217)  loss_giou_unscaled: 0.1748 (0.1900)  cardinality_error_unscaled: 1.5000 (2.1951)  loss_ce_0_unscaled: 0.2048 (0.2060)  loss_bbox_0_unscaled: 0.0271 (0.0316)  loss_giou_0_unscaled: 0.2079 (0.2147)  cardinality_error_0_unscaled: 4.2500 (5.1099)  loss_ce_1_unscaled: 0.1730 (0.1716)  loss_bbox_1_unscaled: 0.0207 (0.0255)  loss_giou_1_unscaled: 0.1798 (0.1965)  cardinality_error_1_unscaled: 4.5000 (4.1676)  loss_ce_2_unscaled: 0.1260 (0.1431)  loss_bbox_2_unscaled: 0.0204 (0.0233)  loss_giou_2_unscaled: 0.1859 (0.1934)  cardinality_error_2_unscaled: 2.7500 (2.7665)  loss_ce_3_unscaled: 0.1214 (0.1305)  loss_bbox_3_unscaled: 0.0209 (0.0226)  loss_giou_3_unscaled: 0.1628 (0.1912)  cardinality_error_3_unscaled: 2.7500 (2.4176)  loss_ce_4_unscaled: 0.0975 (0.1231)  loss_bbox_4_unscaled: 0.0201 (0.0220)  loss_giou_4_unscaled: 0.1606 (0.1846)  cardinality_error_4_unscaled: 1.7500 (2.1923)  time: 1.0439  data: 0.0173  max mem: 9656
# Epoch: [80]  [100/240]  eta: 0:02:22  lr: 0.000100  class_error: 0.00  loss: 3.6876 (3.9798)  loss_ce: 0.0963 (0.1187)  loss_bbox: 0.0994 (0.1086)  loss_giou: 0.3505 (0.3800)  loss_ce_0: 0.2050 (0.2075)  loss_bbox_0: 0.1447 (0.1580)  loss_giou_0: 0.4159 (0.4316)  loss_ce_1: 0.1703 (0.1724)  loss_bbox_1: 0.1146 (0.1289)  loss_giou_1: 0.3646 (0.3935)  loss_ce_2: 0.1353 (0.1457)  loss_bbox_2: 0.1064 (0.1165)  loss_giou_2: 0.3718 (0.3873)  loss_ce_3: 0.1124 (0.1323)  loss_bbox_3: 0.1022 (0.1130)  loss_giou_3: 0.3361 (0.3838)  loss_ce_4: 0.1008 (0.1238)  loss_bbox_4: 0.0994 (0.1096)  loss_giou_4: 0.3234 (0.3685)  loss_ce_unscaled: 0.0963 (0.1187)  class_error_unscaled: 5.2632 (8.9338)  loss_bbox_unscaled: 0.0199 (0.0217)  loss_giou_unscaled: 0.1752 (0.1900)  cardinality_error_unscaled: 1.2500 (2.1535)  loss_ce_0_unscaled: 0.2050 (0.2075)  loss_bbox_0_unscaled: 0.0289 (0.0316)  loss_giou_0_unscaled: 0.2079 (0.2158)  cardinality_error_0_unscaled: 4.2500 (5.0817)  loss_ce_1_unscaled: 0.1703 (0.1724)  loss_bbox_1_unscaled: 0.0229 (0.0258)  loss_giou_1_unscaled: 0.1823 (0.1967)  cardinality_error_1_unscaled: 4.0000 (4.1312)  loss_ce_2_unscaled: 0.1353 (0.1457)  loss_bbox_2_unscaled: 0.0213 (0.0233)  loss_giou_2_unscaled: 0.1859 (0.1936)  cardinality_error_2_unscaled: 1.7500 (2.6906)  loss_ce_3_unscaled: 0.1124 (0.1323)  loss_bbox_3_unscaled: 0.0204 (0.0226)  loss_giou_3_unscaled: 0.1681 (0.1919)  cardinality_error_3_unscaled: 2.5000 (2.4381)  loss_ce_4_unscaled: 0.1008 (0.1238)  loss_bbox_4_unscaled: 0.0199 (0.0219)  loss_giou_4_unscaled: 0.1617 (0.1843)  cardinality_error_4_unscaled: 1.5000 (2.1510)  time: 1.0427  data: 0.0172  max mem: 9656
# Epoch: [80]  [110/240]  eta: 0:02:12  lr: 0.000100  class_error: 0.00  loss: 4.1572 (3.9967)  loss_ce: 0.1192 (0.1193)  loss_bbox: 0.1006 (0.1098)  loss_giou: 0.4040 (0.3834)  loss_ce_0: 0.1752 (0.2070)  loss_bbox_0: 0.1464 (0.1582)  loss_giou_0: 0.4126 (0.4309)  loss_ce_1: 0.1612 (0.1712)  loss_bbox_1: 0.1205 (0.1295)  loss_giou_1: 0.3779 (0.3957)  loss_ce_2: 0.1538 (0.1454)  loss_bbox_2: 0.1066 (0.1171)  loss_giou_2: 0.3854 (0.3900)  loss_ce_3: 0.1239 (0.1324)  loss_bbox_3: 0.1154 (0.1135)  loss_giou_3: 0.3695 (0.3856)  loss_ce_4: 0.1195 (0.1236)  loss_bbox_4: 0.1026 (0.1107)  loss_giou_4: 0.3613 (0.3735)  loss_ce_unscaled: 0.1192 (0.1193)  class_error_unscaled: 10.0000 (8.9760)  loss_bbox_unscaled: 0.0201 (0.0220)  loss_giou_unscaled: 0.2020 (0.1917)  cardinality_error_unscaled: 1.5000 (2.1892)  loss_ce_0_unscaled: 0.1752 (0.2070)  loss_bbox_0_unscaled: 0.0293 (0.0316)  loss_giou_0_unscaled: 0.2063 (0.2154)  cardinality_error_0_unscaled: 3.7500 (5.0901)  loss_ce_1_unscaled: 0.1612 (0.1712)  loss_bbox_1_unscaled: 0.0241 (0.0259)  loss_giou_1_unscaled: 0.1889 (0.1979)  cardinality_error_1_unscaled: 3.2500 (4.1059)  loss_ce_2_unscaled: 0.1538 (0.1454)  loss_bbox_2_unscaled: 0.0213 (0.0234)  loss_giou_2_unscaled: 0.1927 (0.1950)  cardinality_error_2_unscaled: 2.2500 (2.7523)  loss_ce_3_unscaled: 0.1239 (0.1324)  loss_bbox_3_unscaled: 0.0231 (0.0227)  loss_giou_3_unscaled: 0.1848 (0.1928)  cardinality_error_3_unscaled: 2.5000 (2.5518)  loss_ce_4_unscaled: 0.1195 (0.1236)  loss_bbox_4_unscaled: 0.0205 (0.0221)  loss_giou_4_unscaled: 0.1806 (0.1867)  cardinality_error_4_unscaled: 1.7500 (2.2072)  time: 1.0061  data: 0.0176  max mem: 9656
# Epoch: [80]  [120/240]  eta: 0:02:02  lr: 0.000100  class_error: 14.29  loss: 4.1572 (4.0062)  loss_ce: 0.1276 (0.1198)  loss_bbox: 0.1121 (0.1109)  loss_giou: 0.3900 (0.3818)  loss_ce_0: 0.2060 (0.2094)  loss_bbox_0: 0.1641 (0.1599)  loss_giou_0: 0.4077 (0.4302)  loss_ce_1: 0.1643 (0.1732)  loss_bbox_1: 0.1175 (0.1303)  loss_giou_1: 0.3932 (0.3948)  loss_ce_2: 0.1538 (0.1474)  loss_bbox_2: 0.1231 (0.1197)  loss_giou_2: 0.3842 (0.3875)  loss_ce_3: 0.1391 (0.1320)  loss_bbox_3: 0.1154 (0.1155)  loss_giou_3: 0.3614 (0.3839)  loss_ce_4: 0.1198 (0.1243)  loss_bbox_4: 0.1060 (0.1126)  loss_giou_4: 0.4189 (0.3731)  loss_ce_unscaled: 0.1276 (0.1198)  class_error_unscaled: 10.0000 (9.0689)  loss_bbox_unscaled: 0.0224 (0.0222)  loss_giou_unscaled: 0.1950 (0.1909)  cardinality_error_unscaled: 1.5000 (2.1529)  loss_ce_0_unscaled: 0.2060 (0.2094)  loss_bbox_0_unscaled: 0.0328 (0.0320)  loss_giou_0_unscaled: 0.2039 (0.2151)  cardinality_error_0_unscaled: 3.7500 (4.9979)  loss_ce_1_unscaled: 0.1643 (0.1732)  loss_bbox_1_unscaled: 0.0235 (0.0261)  loss_giou_1_unscaled: 0.1966 (0.1974)  cardinality_error_1_unscaled: 3.2500 (3.9897)  loss_ce_2_unscaled: 0.1538 (0.1474)  loss_bbox_2_unscaled: 0.0246 (0.0239)  loss_giou_2_unscaled: 0.1921 (0.1938)  cardinality_error_2_unscaled: 2.2500 (2.7066)  loss_ce_3_unscaled: 0.1391 (0.1320)  loss_bbox_3_unscaled: 0.0231 (0.0231)  loss_giou_3_unscaled: 0.1807 (0.1919)  cardinality_error_3_unscaled: 2.5000 (2.5289)  loss_ce_4_unscaled: 0.1198 (0.1243)  loss_bbox_4_unscaled: 0.0212 (0.0225)  loss_giou_4_unscaled: 0.2095 (0.1865)  cardinality_error_4_unscaled: 1.7500 (2.1591)  time: 1.0515  data: 0.0179  max mem: 9656
# Epoch: [80]  [130/240]  eta: 0:01:51  lr: 0.000100  class_error: 0.00  loss: 4.0784 (4.0057)  loss_ce: 0.1080 (0.1188)  loss_bbox: 0.1052 (0.1103)  loss_giou: 0.3900 (0.3833)  loss_ce_0: 0.2308 (0.2099)  loss_bbox_0: 0.1437 (0.1588)  loss_giou_0: 0.4364 (0.4298)  loss_ce_1: 0.1962 (0.1730)  loss_bbox_1: 0.1174 (0.1297)  loss_giou_1: 0.3740 (0.3942)  loss_ce_2: 0.1495 (0.1475)  loss_bbox_2: 0.1131 (0.1189)  loss_giou_2: 0.3971 (0.3883)  loss_ce_3: 0.0925 (0.1321)  loss_bbox_3: 0.1072 (0.1151)  loss_giou_3: 0.3907 (0.3847)  loss_ce_4: 0.1078 (0.1242)  loss_bbox_4: 0.1073 (0.1120)  loss_giou_4: 0.3878 (0.3749)  loss_ce_unscaled: 0.1080 (0.1188)  class_error_unscaled: 10.0000 (9.0177)  loss_bbox_unscaled: 0.0210 (0.0221)  loss_giou_unscaled: 0.1950 (0.1916)  cardinality_error_unscaled: 1.7500 (2.1317)  loss_ce_0_unscaled: 0.2308 (0.2099)  loss_bbox_0_unscaled: 0.0287 (0.0318)  loss_giou_0_unscaled: 0.2182 (0.2149)  cardinality_error_0_unscaled: 4.7500 (5.0706)  loss_ce_1_unscaled: 0.1962 (0.1730)  loss_bbox_1_unscaled: 0.0235 (0.0259)  loss_giou_1_unscaled: 0.1870 (0.1971)  cardinality_error_1_unscaled: 3.2500 (4.0000)  loss_ce_2_unscaled: 0.1495 (0.1475)  loss_bbox_2_unscaled: 0.0226 (0.0238)  loss_giou_2_unscaled: 0.1986 (0.1942)  cardinality_error_2_unscaled: 2.2500 (2.7634)  loss_ce_3_unscaled: 0.0925 (0.1321)  loss_bbox_3_unscaled: 0.0214 (0.0230)  loss_giou_3_unscaled: 0.1954 (0.1923)  cardinality_error_3_unscaled: 2.2500 (2.5382)  loss_ce_4_unscaled: 0.1078 (0.1242)  loss_bbox_4_unscaled: 0.0215 (0.0224)  loss_giou_4_unscaled: 0.1939 (0.1874)  cardinality_error_4_unscaled: 1.7500 (2.1450)  time: 1.0138  data: 0.0172  max mem: 9656
# Epoch: [80]  [140/240]  eta: 0:01:42  lr: 0.000100  class_error: 17.65  loss: 3.9128 (4.0148)  loss_ce: 0.1058 (0.1203)  loss_bbox: 0.1052 (0.1109)  loss_giou: 0.3748 (0.3833)  loss_ce_0: 0.2026 (0.2093)  loss_bbox_0: 0.1659 (0.1606)  loss_giou_0: 0.4190 (0.4305)  loss_ce_1: 0.1972 (0.1731)  loss_bbox_1: 0.1174 (0.1308)  loss_giou_1: 0.3740 (0.3935)  loss_ce_2: 0.1495 (0.1486)  loss_bbox_2: 0.1131 (0.1195)  loss_giou_2: 0.3905 (0.3895)  loss_ce_3: 0.0925 (0.1317)  loss_bbox_3: 0.1087 (0.1155)  loss_giou_3: 0.3879 (0.3845)  loss_ce_4: 0.1069 (0.1246)  loss_bbox_4: 0.1073 (0.1124)  loss_giou_4: 0.3799 (0.3760)  loss_ce_unscaled: 0.1058 (0.1203)  class_error_unscaled: 10.0000 (9.0853)  loss_bbox_unscaled: 0.0210 (0.0222)  loss_giou_unscaled: 0.1874 (0.1916)  cardinality_error_unscaled: 1.7500 (2.1277)  loss_ce_0_unscaled: 0.2026 (0.2093)  loss_bbox_0_unscaled: 0.0332 (0.0321)  loss_giou_0_unscaled: 0.2095 (0.2153)  cardinality_error_0_unscaled: 5.0000 (5.0408)  loss_ce_1_unscaled: 0.1972 (0.1731)  loss_bbox_1_unscaled: 0.0235 (0.0262)  loss_giou_1_unscaled: 0.1870 (0.1968)  cardinality_error_1_unscaled: 4.2500 (4.0106)  loss_ce_2_unscaled: 0.1495 (0.1486)  loss_bbox_2_unscaled: 0.0226 (0.0239)  loss_giou_2_unscaled: 0.1953 (0.1948)  cardinality_error_2_unscaled: 3.0000 (2.7926)  loss_ce_3_unscaled: 0.0925 (0.1317)  loss_bbox_3_unscaled: 0.0217 (0.0231)  loss_giou_3_unscaled: 0.1940 (0.1923)  cardinality_error_3_unscaled: 2.2500 (2.5089)  loss_ce_4_unscaled: 0.1069 (0.1246)  loss_bbox_4_unscaled: 0.0215 (0.0225)  loss_giou_4_unscaled: 0.1900 (0.1880)  cardinality_error_4_unscaled: 1.7500 (2.1401)  time: 1.0046  data: 0.0169  max mem: 9656
# Epoch: [80]  [150/240]  eta: 0:01:32  lr: 0.000100  class_error: 11.11  loss: 3.5503 (3.9805)  loss_ce: 0.0976 (0.1193)  loss_bbox: 0.0978 (0.1108)  loss_giou: 0.3431 (0.3783)  loss_ce_0: 0.1500 (0.2070)  loss_bbox_0: 0.1663 (0.1602)  loss_giou_0: 0.4040 (0.4282)  loss_ce_1: 0.1431 (0.1706)  loss_bbox_1: 0.1213 (0.1305)  loss_giou_1: 0.3739 (0.3922)  loss_ce_2: 0.1747 (0.1471)  loss_bbox_2: 0.1133 (0.1190)  loss_giou_2: 0.3548 (0.3851)  loss_ce_3: 0.0940 (0.1304)  loss_bbox_3: 0.1036 (0.1155)  loss_giou_3: 0.3343 (0.3797)  loss_ce_4: 0.0831 (0.1229)  loss_bbox_4: 0.1000 (0.1122)  loss_giou_4: 0.3479 (0.3715)  loss_ce_unscaled: 0.0976 (0.1193)  class_error_unscaled: 6.6667 (8.8387)  loss_bbox_unscaled: 0.0196 (0.0222)  loss_giou_unscaled: 0.1715 (0.1892)  cardinality_error_unscaled: 1.7500 (2.1291)  loss_ce_0_unscaled: 0.1500 (0.2070)  loss_bbox_0_unscaled: 0.0333 (0.0320)  loss_giou_0_unscaled: 0.2020 (0.2141)  cardinality_error_0_unscaled: 4.7500 (5.0298)  loss_ce_1_unscaled: 0.1431 (0.1706)  loss_bbox_1_unscaled: 0.0243 (0.0261)  loss_giou_1_unscaled: 0.1870 (0.1961)  cardinality_error_1_unscaled: 3.5000 (3.9967)  loss_ce_2_unscaled: 0.1747 (0.1471)  loss_bbox_2_unscaled: 0.0227 (0.0238)  loss_giou_2_unscaled: 0.1774 (0.1926)  cardinality_error_2_unscaled: 2.2500 (2.7897)  loss_ce_3_unscaled: 0.0940 (0.1304)  loss_bbox_3_unscaled: 0.0207 (0.0231)  loss_giou_3_unscaled: 0.1672 (0.1898)  cardinality_error_3_unscaled: 1.5000 (2.4752)  loss_ce_4_unscaled: 0.0831 (0.1229)  loss_bbox_4_unscaled: 0.0200 (0.0224)  loss_giou_4_unscaled: 0.1739 (0.1858)  cardinality_error_4_unscaled: 1.2500 (2.1258)  time: 1.0782  data: 0.0173  max mem: 9656
# Epoch: [80]  [160/240]  eta: 0:01:21  lr: 0.000100  class_error: 10.00  loss: 3.4342 (3.9928)  loss_ce: 0.0656 (0.1193)  loss_bbox: 0.0978 (0.1106)  loss_giou: 0.3283 (0.3803)  loss_ce_0: 0.1500 (0.2094)  loss_bbox_0: 0.1455 (0.1605)  loss_giou_0: 0.3753 (0.4310)  loss_ce_1: 0.1355 (0.1728)  loss_bbox_1: 0.1115 (0.1302)  loss_giou_1: 0.3232 (0.3926)  loss_ce_2: 0.1215 (0.1484)  loss_bbox_2: 0.1007 (0.1185)  loss_giou_2: 0.3383 (0.3855)  loss_ce_3: 0.0716 (0.1305)  loss_bbox_3: 0.1035 (0.1152)  loss_giou_3: 0.3299 (0.3807)  loss_ce_4: 0.0534 (0.1227)  loss_bbox_4: 0.0966 (0.1120)  loss_giou_4: 0.3479 (0.3727)  loss_ce_unscaled: 0.0656 (0.1193)  class_error_unscaled: 0.0000 (8.6849)  loss_bbox_unscaled: 0.0196 (0.0221)  loss_giou_unscaled: 0.1642 (0.1902)  cardinality_error_unscaled: 1.7500 (2.1941)  loss_ce_0_unscaled: 0.1500 (0.2094)  loss_bbox_0_unscaled: 0.0291 (0.0321)  loss_giou_0_unscaled: 0.1876 (0.2155)  cardinality_error_0_unscaled: 4.7500 (5.0450)  loss_ce_1_unscaled: 0.1355 (0.1728)  loss_bbox_1_unscaled: 0.0223 (0.0260)  loss_giou_1_unscaled: 0.1616 (0.1963)  cardinality_error_1_unscaled: 4.0000 (4.0761)  loss_ce_2_unscaled: 0.1215 (0.1484)  loss_bbox_2_unscaled: 0.0201 (0.0237)  loss_giou_2_unscaled: 0.1692 (0.1928)  cardinality_error_2_unscaled: 2.7500 (2.8680)  loss_ce_3_unscaled: 0.0716 (0.1305)  loss_bbox_3_unscaled: 0.0207 (0.0230)  loss_giou_3_unscaled: 0.1649 (0.1904)  cardinality_error_3_unscaled: 1.5000 (2.5078)  loss_ce_4_unscaled: 0.0534 (0.1227)  loss_bbox_4_unscaled: 0.0193 (0.0224)  loss_giou_4_unscaled: 0.1739 (0.1864)  cardinality_error_4_unscaled: 1.5000 (2.1832)  time: 1.0441  data: 0.0174  max mem: 9656
# Epoch: [80]  [170/240]  eta: 0:01:11  lr: 0.000100  class_error: 23.53  loss: 3.7068 (4.0300)  loss_ce: 0.1002 (0.1204)  loss_bbox: 0.1050 (0.1127)  loss_giou: 0.3660 (0.3824)  loss_ce_0: 0.1951 (0.2095)  loss_bbox_0: 0.1606 (0.1626)  loss_giou_0: 0.4648 (0.4368)  loss_ce_1: 0.1598 (0.1731)  loss_bbox_1: 0.1196 (0.1312)  loss_giou_1: 0.3992 (0.3975)  loss_ce_2: 0.1307 (0.1480)  loss_bbox_2: 0.1140 (0.1202)  loss_giou_2: 0.4006 (0.3895)  loss_ce_3: 0.0723 (0.1305)  loss_bbox_3: 0.1138 (0.1167)  loss_giou_3: 0.4136 (0.3861)  loss_ce_4: 0.1128 (0.1236)  loss_bbox_4: 0.1011 (0.1132)  loss_giou_4: 0.3603 (0.3759)  loss_ce_unscaled: 0.1002 (0.1204)  class_error_unscaled: 5.5556 (8.8021)  loss_bbox_unscaled: 0.0210 (0.0225)  loss_giou_unscaled: 0.1830 (0.1912)  cardinality_error_unscaled: 1.0000 (2.2412)  loss_ce_0_unscaled: 0.1951 (0.2095)  loss_bbox_0_unscaled: 0.0321 (0.0325)  loss_giou_0_unscaled: 0.2324 (0.2184)  cardinality_error_0_unscaled: 3.7500 (5.0205)  loss_ce_1_unscaled: 0.1598 (0.1731)  loss_bbox_1_unscaled: 0.0239 (0.0262)  loss_giou_1_unscaled: 0.1996 (0.1988)  cardinality_error_1_unscaled: 3.2500 (4.0716)  loss_ce_2_unscaled: 0.1307 (0.1480)  loss_bbox_2_unscaled: 0.0228 (0.0240)  loss_giou_2_unscaled: 0.2003 (0.1947)  cardinality_error_2_unscaled: 2.5000 (2.9269)  loss_ce_3_unscaled: 0.0723 (0.1305)  loss_bbox_3_unscaled: 0.0228 (0.0233)  loss_giou_3_unscaled: 0.2068 (0.1930)  cardinality_error_3_unscaled: 1.7500 (2.5526)  loss_ce_4_unscaled: 0.1128 (0.1236)  loss_bbox_4_unscaled: 0.0202 (0.0226)  loss_giou_4_unscaled: 0.1802 (0.1880)  cardinality_error_4_unscaled: 1.0000 (2.2149)  time: 1.0446  data: 0.0174  max mem: 9656
# Epoch: [80]  [180/240]  eta: 0:01:01  lr: 0.000100  class_error: 0.00  loss: 3.8081 (4.0067)  loss_ce: 0.1002 (0.1191)  loss_bbox: 0.1039 (0.1119)  loss_giou: 0.3660 (0.3795)  loss_ce_0: 0.1643 (0.2070)  loss_bbox_0: 0.1564 (0.1623)  loss_giou_0: 0.4558 (0.4364)  loss_ce_1: 0.1598 (0.1722)  loss_bbox_1: 0.1231 (0.1308)  loss_giou_1: 0.4019 (0.3960)  loss_ce_2: 0.1144 (0.1466)  loss_bbox_2: 0.1140 (0.1198)  loss_giou_2: 0.4023 (0.3876)  loss_ce_3: 0.0926 (0.1289)  loss_bbox_3: 0.1067 (0.1159)  loss_giou_3: 0.4136 (0.3843)  loss_ce_4: 0.1128 (0.1223)  loss_bbox_4: 0.1026 (0.1125)  loss_giou_4: 0.3466 (0.3737)  loss_ce_unscaled: 0.1002 (0.1191)  class_error_unscaled: 9.0909 (8.8232)  loss_bbox_unscaled: 0.0208 (0.0224)  loss_giou_unscaled: 0.1830 (0.1897)  cardinality_error_unscaled: 0.7500 (2.1699)  loss_ce_0_unscaled: 0.1643 (0.2070)  loss_bbox_0_unscaled: 0.0313 (0.0325)  loss_giou_0_unscaled: 0.2279 (0.2182)  cardinality_error_0_unscaled: 3.5000 (4.9351)  loss_ce_1_unscaled: 0.1598 (0.1722)  loss_bbox_1_unscaled: 0.0246 (0.0262)  loss_giou_1_unscaled: 0.2009 (0.1980)  cardinality_error_1_unscaled: 1.7500 (3.9517)  loss_ce_2_unscaled: 0.1144 (0.1466)  loss_bbox_2_unscaled: 0.0228 (0.0240)  loss_giou_2_unscaled: 0.2012 (0.1938)  cardinality_error_2_unscaled: 1.5000 (2.8273)  loss_ce_3_unscaled: 0.0926 (0.1289)  loss_bbox_3_unscaled: 0.0213 (0.0232)  loss_giou_3_unscaled: 0.2068 (0.1921)  cardinality_error_3_unscaled: 0.7500 (2.4558)  loss_ce_4_unscaled: 0.1128 (0.1223)  loss_bbox_4_unscaled: 0.0205 (0.0225)  loss_giou_4_unscaled: 0.1733 (0.1868)  cardinality_error_4_unscaled: 0.7500 (2.1395)  time: 1.0685  data: 0.0174  max mem: 9656
# Epoch: [80]  [190/240]  eta: 0:00:51  lr: 0.000100  class_error: 0.00  loss: 3.2004 (3.9885)  loss_ce: 0.0625 (0.1177)  loss_bbox: 0.0962 (0.1115)  loss_giou: 0.2995 (0.3774)  loss_ce_0: 0.1597 (0.2072)  loss_bbox_0: 0.1548 (0.1621)  loss_giou_0: 0.4374 (0.4359)  loss_ce_1: 0.0960 (0.1704)  loss_bbox_1: 0.1300 (0.1315)  loss_giou_1: 0.3354 (0.3935)  loss_ce_2: 0.0723 (0.1453)  loss_bbox_2: 0.1130 (0.1199)  loss_giou_2: 0.3253 (0.3843)  loss_ce_3: 0.0646 (0.1274)  loss_bbox_3: 0.1067 (0.1161)  loss_giou_3: 0.3472 (0.3829)  loss_ce_4: 0.0558 (0.1205)  loss_bbox_4: 0.1026 (0.1126)  loss_giou_4: 0.3171 (0.3723)  loss_ce_unscaled: 0.0625 (0.1177)  class_error_unscaled: 6.2500 (8.5391)  loss_bbox_unscaled: 0.0192 (0.0223)  loss_giou_unscaled: 0.1498 (0.1887)  cardinality_error_unscaled: 0.5000 (2.2029)  loss_ce_0_unscaled: 0.1597 (0.2072)  loss_bbox_0_unscaled: 0.0310 (0.0324)  loss_giou_0_unscaled: 0.2187 (0.2179)  cardinality_error_0_unscaled: 3.2500 (5.0144)  loss_ce_1_unscaled: 0.0960 (0.1704)  loss_bbox_1_unscaled: 0.0260 (0.0263)  loss_giou_1_unscaled: 0.1677 (0.1968)  cardinality_error_1_unscaled: 1.7500 (3.9712)  loss_ce_2_unscaled: 0.0723 (0.1453)  loss_bbox_2_unscaled: 0.0226 (0.0240)  loss_giou_2_unscaled: 0.1627 (0.1922)  cardinality_error_2_unscaled: 0.7500 (2.8796)  loss_ce_3_unscaled: 0.0646 (0.1274)  loss_bbox_3_unscaled: 0.0213 (0.0232)  loss_giou_3_unscaled: 0.1736 (0.1915)  cardinality_error_3_unscaled: 0.7500 (2.4817)  loss_ce_4_unscaled: 0.0558 (0.1205)  loss_bbox_4_unscaled: 0.0205 (0.0225)  loss_giou_4_unscaled: 0.1586 (0.1862)  cardinality_error_4_unscaled: 0.5000 (2.1702)  time: 1.0651  data: 0.0169  max mem: 9656
# Epoch: [80]  [200/240]  eta: 0:00:41  lr: 0.000100  class_error: 20.00  loss: 3.5392 (3.9970)  loss_ce: 0.1046 (0.1189)  loss_bbox: 0.0970 (0.1116)  loss_giou: 0.3104 (0.3781)  loss_ce_0: 0.1925 (0.2074)  loss_bbox_0: 0.1533 (0.1618)  loss_giou_0: 0.4153 (0.4366)  loss_ce_1: 0.0997 (0.1699)  loss_bbox_1: 0.1283 (0.1313)  loss_giou_1: 0.3428 (0.3951)  loss_ce_2: 0.1119 (0.1461)  loss_bbox_2: 0.1121 (0.1200)  loss_giou_2: 0.3253 (0.3856)  loss_ce_3: 0.1029 (0.1278)  loss_bbox_3: 0.1104 (0.1163)  loss_giou_3: 0.3308 (0.3838)  loss_ce_4: 0.0607 (0.1206)  loss_bbox_4: 0.1017 (0.1128)  loss_giou_4: 0.3241 (0.3732)  loss_ce_unscaled: 0.1046 (0.1189)  class_error_unscaled: 6.8966 (8.7678)  loss_bbox_unscaled: 0.0194 (0.0223)  loss_giou_unscaled: 0.1552 (0.1891)  cardinality_error_unscaled: 1.5000 (2.1716)  loss_ce_0_unscaled: 0.1925 (0.2074)  loss_bbox_0_unscaled: 0.0307 (0.0324)  loss_giou_0_unscaled: 0.2077 (0.2183)  cardinality_error_0_unscaled: 4.2500 (5.0323)  loss_ce_1_unscaled: 0.0997 (0.1699)  loss_bbox_1_unscaled: 0.0257 (0.0263)  loss_giou_1_unscaled: 0.1714 (0.1976)  cardinality_error_1_unscaled: 2.5000 (3.9453)  loss_ce_2_unscaled: 0.1119 (0.1461)  loss_bbox_2_unscaled: 0.0224 (0.0240)  loss_giou_2_unscaled: 0.1627 (0.1928)  cardinality_error_2_unscaled: 1.2500 (2.8644)  loss_ce_3_unscaled: 0.1029 (0.1278)  loss_bbox_3_unscaled: 0.0221 (0.0233)  loss_giou_3_unscaled: 0.1654 (0.1919)  cardinality_error_3_unscaled: 1.5000 (2.4490)  loss_ce_4_unscaled: 0.0607 (0.1206)  loss_bbox_4_unscaled: 0.0203 (0.0226)  loss_giou_4_unscaled: 0.1621 (0.1866)  cardinality_error_4_unscaled: 1.2500 (2.1381)  time: 1.0793  data: 0.0173  max mem: 9656
# Epoch: [80]  [210/240]  eta: 0:00:31  lr: 0.000100  class_error: 0.00  loss: 3.8583 (3.9888)  loss_ce: 0.1064 (0.1185)  loss_bbox: 0.0993 (0.1111)  loss_giou: 0.3246 (0.3775)  loss_ce_0: 0.2030 (0.2075)  loss_bbox_0: 0.1439 (0.1613)  loss_giou_0: 0.4244 (0.4362)  loss_ce_1: 0.1402 (0.1688)  loss_bbox_1: 0.1132 (0.1309)  loss_giou_1: 0.3680 (0.3942)  loss_ce_2: 0.1349 (0.1457)  loss_bbox_2: 0.1078 (0.1197)  loss_giou_2: 0.4263 (0.3863)  loss_ce_3: 0.1085 (0.1273)  loss_bbox_3: 0.1068 (0.1158)  loss_giou_3: 0.3984 (0.3834)  loss_ce_4: 0.1024 (0.1202)  loss_bbox_4: 0.0949 (0.1121)  loss_giou_4: 0.3670 (0.3724)  loss_ce_unscaled: 0.1064 (0.1185)  class_error_unscaled: 11.1111 (8.8405)  loss_bbox_unscaled: 0.0199 (0.0222)  loss_giou_unscaled: 0.1623 (0.1887)  cardinality_error_unscaled: 1.5000 (2.1564)  loss_ce_0_unscaled: 0.2030 (0.2075)  loss_bbox_0_unscaled: 0.0288 (0.0323)  loss_giou_0_unscaled: 0.2122 (0.2181)  cardinality_error_0_unscaled: 3.7500 (4.9775)  loss_ce_1_unscaled: 0.1402 (0.1688)  loss_bbox_1_unscaled: 0.0226 (0.0262)  loss_giou_1_unscaled: 0.1840 (0.1971)  cardinality_error_1_unscaled: 2.2500 (3.8780)  loss_ce_2_unscaled: 0.1349 (0.1457)  loss_bbox_2_unscaled: 0.0216 (0.0239)  loss_giou_2_unscaled: 0.2131 (0.1931)  cardinality_error_2_unscaled: 1.5000 (2.8164)  loss_ce_3_unscaled: 0.1085 (0.1273)  loss_bbox_3_unscaled: 0.0214 (0.0232)  loss_giou_3_unscaled: 0.1992 (0.1917)  cardinality_error_3_unscaled: 1.5000 (2.4206)  loss_ce_4_unscaled: 0.1024 (0.1202)  loss_bbox_4_unscaled: 0.0190 (0.0224)  loss_giou_4_unscaled: 0.1835 (0.1862)  cardinality_error_4_unscaled: 1.2500 (2.1185)  time: 1.0554  data: 0.0183  max mem: 9656
# Epoch: [80]  [220/240]  eta: 0:00:20  lr: 0.000100  class_error: 18.75  loss: 3.4520 (3.9633)  loss_ce: 0.0637 (0.1175)  loss_bbox: 0.0993 (0.1107)  loss_giou: 0.3231 (0.3740)  loss_ce_0: 0.2079 (0.2073)  loss_bbox_0: 0.1465 (0.1615)  loss_giou_0: 0.3861 (0.4334)  loss_ce_1: 0.1371 (0.1675)  loss_bbox_1: 0.1176 (0.1307)  loss_giou_1: 0.3609 (0.3925)  loss_ce_2: 0.0968 (0.1437)  loss_bbox_2: 0.1062 (0.1193)  loss_giou_2: 0.3408 (0.3849)  loss_ce_3: 0.0730 (0.1259)  loss_bbox_3: 0.1043 (0.1152)  loss_giou_3: 0.3117 (0.3803)  loss_ce_4: 0.0753 (0.1188)  loss_bbox_4: 0.0948 (0.1115)  loss_giou_4: 0.3103 (0.3688)  loss_ce_unscaled: 0.0637 (0.1175)  class_error_unscaled: 5.2632 (8.6643)  loss_bbox_unscaled: 0.0199 (0.0221)  loss_giou_unscaled: 0.1616 (0.1870)  cardinality_error_unscaled: 1.5000 (2.1335)  loss_ce_0_unscaled: 0.2079 (0.2073)  loss_bbox_0_unscaled: 0.0293 (0.0323)  loss_giou_0_unscaled: 0.1930 (0.2167)  cardinality_error_0_unscaled: 3.2500 (4.9434)  loss_ce_1_unscaled: 0.1371 (0.1675)  loss_bbox_1_unscaled: 0.0235 (0.0261)  loss_giou_1_unscaled: 0.1804 (0.1963)  cardinality_error_1_unscaled: 2.2500 (3.8020)  loss_ce_2_unscaled: 0.0968 (0.1437)  loss_bbox_2_unscaled: 0.0212 (0.0239)  loss_giou_2_unscaled: 0.1704 (0.1924)  cardinality_error_2_unscaled: 1.5000 (2.7794)  loss_ce_3_unscaled: 0.0730 (0.1259)  loss_bbox_3_unscaled: 0.0209 (0.0230)  loss_giou_3_unscaled: 0.1558 (0.1901)  cardinality_error_3_unscaled: 1.5000 (2.3982)  loss_ce_4_unscaled: 0.0753 (0.1188)  loss_bbox_4_unscaled: 0.0190 (0.0223)  loss_giou_4_unscaled: 0.1552 (0.1844)  cardinality_error_4_unscaled: 1.5000 (2.0995)  time: 1.1263  data: 0.0185  max mem: 9695
# Epoch: [80]  [230/240]  eta: 0:00:10  lr: 0.000100  class_error: 5.88  loss: 3.4520 (3.9596)  loss_ce: 0.0772 (0.1164)  loss_bbox: 0.1060 (0.1107)  loss_giou: 0.3102 (0.3745)  loss_ce_0: 0.2106 (0.2086)  loss_bbox_0: 0.1566 (0.1613)  loss_giou_0: 0.3931 (0.4329)  loss_ce_1: 0.1397 (0.1678)  loss_bbox_1: 0.1284 (0.1307)  loss_giou_1: 0.3050 (0.3909)  loss_ce_2: 0.0968 (0.1434)  loss_bbox_2: 0.1105 (0.1190)  loss_giou_2: 0.3408 (0.3848)  loss_ce_3: 0.0938 (0.1252)  loss_bbox_3: 0.1040 (0.1150)  loss_giou_3: 0.3117 (0.3801)  loss_ce_4: 0.0816 (0.1177)  loss_bbox_4: 0.1000 (0.1113)  loss_giou_4: 0.3022 (0.3693)  loss_ce_unscaled: 0.0772 (0.1164)  class_error_unscaled: 0.0000 (8.5286)  loss_bbox_unscaled: 0.0212 (0.0221)  loss_giou_unscaled: 0.1551 (0.1873)  cardinality_error_unscaled: 1.5000 (2.1277)  loss_ce_0_unscaled: 0.2106 (0.2086)  loss_bbox_0_unscaled: 0.0313 (0.0323)  loss_giou_0_unscaled: 0.1966 (0.2164)  cardinality_error_0_unscaled: 5.0000 (4.9643)  loss_ce_1_unscaled: 0.1397 (0.1678)  loss_bbox_1_unscaled: 0.0257 (0.0261)  loss_giou_1_unscaled: 0.1525 (0.1954)  cardinality_error_1_unscaled: 2.5000 (3.7976)  loss_ce_2_unscaled: 0.0968 (0.1434)  loss_bbox_2_unscaled: 0.0221 (0.0238)  loss_giou_2_unscaled: 0.1704 (0.1924)  cardinality_error_2_unscaled: 2.5000 (2.8030)  loss_ce_3_unscaled: 0.0938 (0.1252)  loss_bbox_3_unscaled: 0.0208 (0.0230)  loss_giou_3_unscaled: 0.1558 (0.1901)  cardinality_error_3_unscaled: 2.5000 (2.4037)  loss_ce_4_unscaled: 0.0816 (0.1177)  loss_bbox_4_unscaled: 0.0200 (0.0223)  loss_giou_4_unscaled: 0.1511 (0.1846)  cardinality_error_4_unscaled: 1.7500 (2.0996)  time: 1.1301  data: 0.0181  max mem: 9695
# Epoch: [80]  [239/240]  eta: 0:00:01  lr: 0.000100  class_error: 0.00  loss: 3.7851 (3.9652)  loss_ce: 0.0859 (0.1164)  loss_bbox: 0.1060 (0.1110)  loss_giou: 0.3184 (0.3748)  loss_ce_0: 0.1809 (0.2078)  loss_bbox_0: 0.1516 (0.1614)  loss_giou_0: 0.3931 (0.4338)  loss_ce_1: 0.1397 (0.1665)  loss_bbox_1: 0.1284 (0.1311)  loss_giou_1: 0.3594 (0.3922)  loss_ce_2: 0.1486 (0.1434)  loss_bbox_2: 0.1062 (0.1192)  loss_giou_2: 0.3577 (0.3861)  loss_ce_3: 0.1055 (0.1250)  loss_bbox_3: 0.1040 (0.1153)  loss_giou_3: 0.3112 (0.3814)  loss_ce_4: 0.0856 (0.1175)  loss_bbox_4: 0.1014 (0.1119)  loss_giou_4: 0.3472 (0.3703)  loss_ce_unscaled: 0.0859 (0.1164)  class_error_unscaled: 4.1667 (8.4479)  loss_bbox_unscaled: 0.0212 (0.0222)  loss_giou_unscaled: 0.1592 (0.1874)  cardinality_error_unscaled: 1.2500 (2.1562)  loss_ce_0_unscaled: 0.1809 (0.2078)  loss_bbox_0_unscaled: 0.0303 (0.0323)  loss_giou_0_unscaled: 0.1966 (0.2169)  cardinality_error_0_unscaled: 5.0000 (5.0104)  loss_ce_1_unscaled: 0.1397 (0.1665)  loss_bbox_1_unscaled: 0.0257 (0.0262)  loss_giou_1_unscaled: 0.1797 (0.1961)  cardinality_error_1_unscaled: 3.2500 (3.8000)  loss_ce_2_unscaled: 0.1486 (0.1434)  loss_bbox_2_unscaled: 0.0212 (0.0238)  loss_giou_2_unscaled: 0.1788 (0.1931)  cardinality_error_2_unscaled: 2.2500 (2.8448)  loss_ce_3_unscaled: 0.1055 (0.1250)  loss_bbox_3_unscaled: 0.0208 (0.0231)  loss_giou_3_unscaled: 0.1556 (0.1907)  cardinality_error_3_unscaled: 1.7500 (2.4240)  loss_ce_4_unscaled: 0.0856 (0.1175)  loss_bbox_4_unscaled: 0.0203 (0.0224)  loss_giou_4_unscaled: 0.1736 (0.1852)  cardinality_error_4_unscaled: 1.2500 (2.1281)  time: 1.0734  data: 0.0176  max mem: 9695
# Epoch: [80] Total time: 0:04:10 (1.0446 s / it)
# Averaged stats: lr: 0.000100  class_error: 0.00  loss: 3.7851 (3.9652)  loss_ce: 0.0859 (0.1164)  loss_bbox: 0.1060 (0.1110)  loss_giou: 0.3184 (0.3748)  loss_ce_0: 0.1809 (0.2078)  loss_bbox_0: 0.1516 (0.1614)  loss_giou_0: 0.3931 (0.4338)  loss_ce_1: 0.1397 (0.1665)  loss_bbox_1: 0.1284 (0.1311)  loss_giou_1: 0.3594 (0.3922)  loss_ce_2: 0.1486 (0.1434)  loss_bbox_2: 0.1062 (0.1192)  loss_giou_2: 0.3577 (0.3861)  loss_ce_3: 0.1055 (0.1250)  loss_bbox_3: 0.1040 (0.1153)  loss_giou_3: 0.3112 (0.3814)  loss_ce_4: 0.0856 (0.1175)  loss_bbox_4: 0.1014 (0.1119)  loss_giou_4: 0.3472 (0.3703)  loss_ce_unscaled: 0.0859 (0.1164)  class_error_unscaled: 4.1667 (8.4479)  loss_bbox_unscaled: 0.0212 (0.0222)  loss_giou_unscaled: 0.1592 (0.1874)  cardinality_error_unscaled: 1.2500 (2.1562)  loss_ce_0_unscaled: 0.1809 (0.2078)  loss_bbox_0_unscaled: 0.0303 (0.0323)  loss_giou_0_unscaled: 0.1966 (0.2169)  cardinality_error_0_unscaled: 5.0000 (5.0104)  loss_ce_1_unscaled: 0.1397 (0.1665)  loss_bbox_1_unscaled: 0.0257 (0.0262)  loss_giou_1_unscaled: 0.1797 (0.1961)  cardinality_error_1_unscaled: 3.2500 (3.8000)  loss_ce_2_unscaled: 0.1486 (0.1434)  loss_bbox_2_unscaled: 0.0212 (0.0238)  loss_giou_2_unscaled: 0.1788 (0.1931)  cardinality_error_2_unscaled: 2.2500 (2.8448)  loss_ce_3_unscaled: 0.1055 (0.1250)  loss_bbox_3_unscaled: 0.0208 (0.0231)  loss_giou_3_unscaled: 0.1556 (0.1907)  cardinality_error_3_unscaled: 1.7500 (2.4240)  loss_ce_4_unscaled: 0.0856 (0.1175)  loss_bbox_4_unscaled: 0.0203 (0.0224)  loss_giou_4_unscaled: 0.1736 (0.1852)  cardinality_error_4_unscaled: 1.2500 (2.1281)
# Test:  [  0/160]  eta: 0:03:31  class_error: 10.00  loss: 3.1890 (3.1890)  loss_ce: 0.1888 (0.1888)  loss_bbox: 0.1170 (0.1170)  loss_giou: 0.2510 (0.2510)  loss_ce_0: 0.2105 (0.2105)  loss_bbox_0: 0.1311 (0.1311)  loss_giou_0: 0.2469 (0.2469)  loss_ce_1: 0.1772 (0.1772)  loss_bbox_1: 0.1121 (0.1121)  loss_giou_1: 0.2126 (0.2126)  loss_ce_2: 0.1623 (0.1623)  loss_bbox_2: 0.1121 (0.1121)  loss_giou_2: 0.2250 (0.2250)  loss_ce_3: 0.1452 (0.1452)  loss_bbox_3: 0.1091 (0.1091)  loss_giou_3: 0.2173 (0.2173)  loss_ce_4: 0.1927 (0.1927)  loss_bbox_4: 0.1260 (0.1260)  loss_giou_4: 0.2519 (0.2519)  loss_ce_unscaled: 0.1888 (0.1888)  class_error_unscaled: 10.0000 (10.0000)  loss_bbox_unscaled: 0.0234 (0.0234)  loss_giou_unscaled: 0.1255 (0.1255)  cardinality_error_unscaled: 0.5000 (0.5000)  loss_ce_0_unscaled: 0.2105 (0.2105)  loss_bbox_0_unscaled: 0.0262 (0.0262)  loss_giou_0_unscaled: 0.1234 (0.1234)  cardinality_error_0_unscaled: 3.5000 (3.5000)  loss_ce_1_unscaled: 0.1772 (0.1772)  loss_bbox_1_unscaled: 0.0224 (0.0224)  loss_giou_1_unscaled: 0.1063 (0.1063)  cardinality_error_1_unscaled: 1.7500 (1.7500)  loss_ce_2_unscaled: 0.1623 (0.1623)  loss_bbox_2_unscaled: 0.0224 (0.0224)  loss_giou_2_unscaled: 0.1125 (0.1125)  cardinality_error_2_unscaled: 1.2500 (1.2500)  loss_ce_3_unscaled: 0.1452 (0.1452)  loss_bbox_3_unscaled: 0.0218 (0.0218)  loss_giou_3_unscaled: 0.1087 (0.1087)  cardinality_error_3_unscaled: 0.5000 (0.5000)  loss_ce_4_unscaled: 0.1927 (0.1927)  loss_bbox_4_unscaled: 0.0252 (0.0252)  loss_giou_4_unscaled: 0.1260 (0.1260)  cardinality_error_4_unscaled: 0.5000 (0.5000)  time: 1.3193  data: 0.6603  max mem: 9695
# Test:  [ 10/160]  eta: 0:01:37  class_error: 0.00  loss: 5.0678 (4.9249)  loss_ce: 0.2207 (0.2321)  loss_bbox: 0.1175 (0.1436)  loss_giou: 0.3642 (0.3725)  loss_ce_0: 0.2308 (0.2820)  loss_bbox_0: 0.1967 (0.2257)  loss_giou_0: 0.4648 (0.4624)  loss_ce_1: 0.3059 (0.2847)  loss_bbox_1: 0.1396 (0.1753)  loss_giou_1: 0.4071 (0.3930)  loss_ce_2: 0.2537 (0.2406)  loss_bbox_2: 0.1552 (0.1665)  loss_giou_2: 0.3721 (0.3832)  loss_ce_3: 0.2892 (0.2466)  loss_bbox_3: 0.1357 (0.1496)  loss_giou_3: 0.3785 (0.3819)  loss_ce_4: 0.2718 (0.2437)  loss_bbox_4: 0.1365 (0.1499)  loss_giou_4: 0.3620 (0.3916)  loss_ce_unscaled: 0.2207 (0.2321)  class_error_unscaled: 10.0000 (11.3387)  loss_bbox_unscaled: 0.0235 (0.0287)  loss_giou_unscaled: 0.1821 (0.1862)  cardinality_error_unscaled: 3.5000 (3.6591)  loss_ce_0_unscaled: 0.2308 (0.2820)  loss_bbox_0_unscaled: 0.0393 (0.0451)  loss_giou_0_unscaled: 0.2324 (0.2312)  cardinality_error_0_unscaled: 5.7500 (6.3182)  loss_ce_1_unscaled: 0.3059 (0.2847)  loss_bbox_1_unscaled: 0.0279 (0.0351)  loss_giou_1_unscaled: 0.2035 (0.1965)  cardinality_error_1_unscaled: 3.2500 (4.4318)  loss_ce_2_unscaled: 0.2537 (0.2406)  loss_bbox_2_unscaled: 0.0310 (0.0333)  loss_giou_2_unscaled: 0.1861 (0.1916)  cardinality_error_2_unscaled: 3.7500 (4.4091)  loss_ce_3_unscaled: 0.2892 (0.2466)  loss_bbox_3_unscaled: 0.0271 (0.0299)  loss_giou_3_unscaled: 0.1892 (0.1909)  cardinality_error_3_unscaled: 2.7500 (3.3182)  loss_ce_4_unscaled: 0.2718 (0.2437)  loss_bbox_4_unscaled: 0.0273 (0.0300)  loss_giou_4_unscaled: 0.1810 (0.1958)  cardinality_error_4_unscaled: 3.2500 (3.4545)  time: 0.6506  data: 0.0781  max mem: 9695
# ...
# Test:  [ 90/160]  eta: 0:00:43  class_error: 7.69  loss: 3.6393 (4.7639)  loss_ce: 0.0809 (0.1649)  loss_bbox: 0.1015 (0.1360)  loss_giou: 0.3140 (0.4384)  loss_ce_0: 0.1984 (0.2717)  loss_bbox_0: 0.1445 (0.1791)  loss_giou_0: 0.3632 (0.4955)  loss_ce_1: 0.1239 (0.2225)  loss_bbox_1: 0.1144 (0.1519)  loss_giou_1: 0.4325 (0.4606)  loss_ce_2: 0.1095 (0.2058)  loss_bbox_2: 0.1040 (0.1397)  loss_giou_2: 0.3857 (0.4409)  loss_ce_3: 0.0671 (0.1715)  loss_bbox_3: 0.1034 (0.1373)  loss_giou_3: 0.3464 (0.4337)  loss_ce_4: 0.0735 (0.1612)  loss_bbox_4: 0.0981 (0.1333)  loss_giou_4: 0.3223 (0.4199)  loss_ce_unscaled: 0.0809 (0.1649)  class_error_unscaled: 7.6923 (11.5871)  loss_bbox_unscaled: 0.0203 (0.0272)  loss_giou_unscaled: 0.1570 (0.2192)  cardinality_error_unscaled: 0.7500 (1.5549)  loss_ce_0_unscaled: 0.1984 (0.2717)  loss_bbox_0_unscaled: 0.0289 (0.0358)  loss_giou_0_unscaled: 0.1816 (0.2477)  cardinality_error_0_unscaled: 3.2500 (4.5604)  loss_ce_1_unscaled: 0.1239 (0.2225)  loss_bbox_1_unscaled: 0.0229 (0.0304)  loss_giou_1_unscaled: 0.2162 (0.2303)  cardinality_error_1_unscaled: 1.7500 (2.9203)  loss_ce_2_unscaled: 0.1095 (0.2058)  loss_bbox_2_unscaled: 0.0208 (0.0279)  loss_giou_2_unscaled: 0.1929 (0.2205)  cardinality_error_2_unscaled: 1.0000 (2.3379)  loss_ce_3_unscaled: 0.0671 (0.1715)  loss_bbox_3_unscaled: 0.0207 (0.0275)  loss_giou_3_unscaled: 0.1732 (0.2169)  cardinality_error_3_unscaled: 1.0000 (1.8544)  loss_ce_4_unscaled: 0.0735 (0.1612)  loss_bbox_4_unscaled: 0.0196 (0.0267)  loss_giou_4_unscaled: 0.1612 (0.2099)  cardinality_error_4_unscaled: 0.7500 (1.4698)  time: 0.5906  data: 0.0185  max mem: 11061
# Test:  [100/160]  eta: 0:00:36  class_error: 20.00  loss: 4.4520 (4.8459)  loss_ce: 0.1313 (0.1751)  loss_bbox: 0.1083 (0.1346)  loss_giou: 0.4301 (0.4440)  loss_ce_0: 0.3189 (0.2805)  loss_bbox_0: 0.1498 (0.1787)  loss_giou_0: 0.4950 (0.5014)  loss_ce_1: 0.2256 (0.2299)  loss_bbox_1: 0.1298 (0.1510)  loss_giou_1: 0.4516 (0.4654)  loss_ce_2: 0.1709 (0.2150)  loss_bbox_2: 0.1063 (0.1384)  loss_giou_2: 0.3863 (0.4473)  loss_ce_3: 0.1238 (0.1823)  loss_bbox_3: 0.1090 (0.1356)  loss_giou_3: 0.3545 (0.4375)  loss_ce_4: 0.0968 (0.1727)  loss_bbox_4: 0.1060 (0.1315)  loss_giou_4: 0.4152 (0.4248)  loss_ce_unscaled: 0.1313 (0.1751)  class_error_unscaled: 7.6923 (11.9515)  loss_bbox_unscaled: 0.0217 (0.0269)  loss_giou_unscaled: 0.2151 (0.2220)  cardinality_error_unscaled: 1.0000 (1.5817)  loss_ce_0_unscaled: 0.3189 (0.2805)  loss_bbox_0_unscaled: 0.0300 (0.0357)  loss_giou_0_unscaled: 0.2475 (0.2507)  cardinality_error_0_unscaled: 3.7500 (4.6931)  loss_ce_1_unscaled: 0.2256 (0.2299)  loss_bbox_1_unscaled: 0.0260 (0.0302)  loss_giou_1_unscaled: 0.2258 (0.2327)  cardinality_error_1_unscaled: 2.0000 (2.9332)  loss_ce_2_unscaled: 0.1709 (0.2150)  loss_bbox_2_unscaled: 0.0213 (0.0277)  loss_giou_2_unscaled: 0.1931 (0.2237)  cardinality_error_2_unscaled: 1.5000 (2.3911)  loss_ce_3_unscaled: 0.1238 (0.1823)  loss_bbox_3_unscaled: 0.0218 (0.0271)  loss_giou_3_unscaled: 0.1772 (0.2187)  cardinality_error_3_unscaled: 1.5000 (1.8886)  loss_ce_4_unscaled: 0.0968 (0.1727)  loss_bbox_4_unscaled: 0.0212 (0.0263)  loss_giou_4_unscaled: 0.2076 (0.2124)  cardinality_error_4_unscaled: 1.0000 (1.4901)  time: 0.5958  data: 0.0191  max mem: 11061
# Test:  [110/160]  eta: 0:00:30  class_error: 12.50  loss: 5.0113 (4.9024)  loss_ce: 0.1519 (0.1775)  loss_bbox: 0.1169 (0.1353)  loss_giou: 0.4917 (0.4495)  loss_ce_0: 0.3281 (0.2830)  loss_bbox_0: 0.1576 (0.1792)  loss_giou_0: 0.5730 (0.5093)  loss_ce_1: 0.2256 (0.2328)  loss_bbox_1: 0.1298 (0.1526)  loss_giou_1: 0.5117 (0.4707)  loss_ce_2: 0.2036 (0.2186)  loss_bbox_2: 0.1110 (0.1390)  loss_giou_2: 0.5012 (0.4523)  loss_ce_3: 0.1547 (0.1844)  loss_bbox_3: 0.1030 (0.1358)  loss_giou_3: 0.5084 (0.4451)  loss_ce_4: 0.1385 (0.1738)  loss_bbox_4: 0.1060 (0.1323)  loss_giou_4: 0.4501 (0.4315)  loss_ce_unscaled: 0.1519 (0.1775)  class_error_unscaled: 13.3333 (12.1200)  loss_bbox_unscaled: 0.0234 (0.0271)  loss_giou_unscaled: 0.2459 (0.2248)  cardinality_error_unscaled: 1.2500 (1.6757)  loss_ce_0_unscaled: 0.3281 (0.2830)  loss_bbox_0_unscaled: 0.0315 (0.0358)  loss_giou_0_unscaled: 0.2865 (0.2546)  cardinality_error_0_unscaled: 3.7500 (4.8266)  loss_ce_1_unscaled: 0.2256 (0.2328)  loss_bbox_1_unscaled: 0.0260 (0.0305)  loss_giou_1_unscaled: 0.2559 (0.2354)  cardinality_error_1_unscaled: 2.2500 (3.0360)  loss_ce_2_unscaled: 0.2036 (0.2186)  loss_bbox_2_unscaled: 0.0222 (0.0278)  loss_giou_2_unscaled: 0.2506 (0.2261)  cardinality_error_2_unscaled: 2.2500 (2.4797)  loss_ce_3_unscaled: 0.1547 (0.1844)  loss_bbox_3_unscaled: 0.0206 (0.0272)  loss_giou_3_unscaled: 0.2542 (0.2226)  cardinality_error_3_unscaled: 2.0000 (1.9977)  loss_ce_4_unscaled: 0.1385 (0.1738)  loss_bbox_4_unscaled: 0.0212 (0.0265)  loss_giou_4_unscaled: 0.2250 (0.2157)  cardinality_error_4_unscaled: 1.0000 (1.5788)  time: 0.6028  data: 0.0190  max mem: 11061
# Test:  [120/160]  eta: 0:00:24  class_error: 0.00  loss: 4.6416 (4.8131)  loss_ce: 0.1331 (0.1713)  loss_bbox: 0.1003 (0.1331)  loss_giou: 0.4458 (0.4433)  loss_ce_0: 0.2636 (0.2774)  loss_bbox_0: 0.1508 (0.1760)  loss_giou_0: 0.4563 (0.5010)  loss_ce_1: 0.2000 (0.2278)  loss_bbox_1: 0.1178 (0.1500)  loss_giou_1: 0.4444 (0.4645)  loss_ce_2: 0.1786 (0.2113)  loss_bbox_2: 0.1061 (0.1367)  loss_giou_2: 0.4545 (0.4480)  loss_ce_3: 0.1498 (0.1795)  loss_bbox_3: 0.1004 (0.1333)  loss_giou_3: 0.4149 (0.4385)  loss_ce_4: 0.1051 (0.1667)  loss_bbox_4: 0.0951 (0.1298)  loss_giou_4: 0.4299 (0.4248)  loss_ce_unscaled: 0.1331 (0.1713)  class_error_unscaled: 11.1111 (11.7718)  loss_bbox_unscaled: 0.0201 (0.0266)  loss_giou_unscaled: 0.2229 (0.2217)  cardinality_error_unscaled: 0.2500 (1.6240)  loss_ce_0_unscaled: 0.2636 (0.2774)  loss_bbox_0_unscaled: 0.0302 (0.0352)  loss_giou_0_unscaled: 0.2281 (0.2505)  cardinality_error_0_unscaled: 3.7500 (4.7521)  loss_ce_1_unscaled: 0.2000 (0.2278)  loss_bbox_1_unscaled: 0.0236 (0.0300)  loss_giou_1_unscaled: 0.2222 (0.2322)  cardinality_error_1_unscaled: 1.7500 (2.9525)  loss_ce_2_unscaled: 0.1786 (0.2113)  loss_bbox_2_unscaled: 0.0212 (0.0273)  loss_giou_2_unscaled: 0.2272 (0.2240)  cardinality_error_2_unscaled: 1.0000 (2.4112)  loss_ce_3_unscaled: 0.1498 (0.1795)  loss_bbox_3_unscaled: 0.0201 (0.0267)  loss_giou_3_unscaled: 0.2075 (0.2192)  cardinality_error_3_unscaled: 0.5000 (1.9401)  loss_ce_4_unscaled: 0.1051 (0.1667)  loss_bbox_4_unscaled: 0.0190 (0.0260)  loss_giou_4_unscaled: 0.2149 (0.2124)  cardinality_error_4_unscaled: 0.5000 (1.5248)  time: 0.5935  data: 0.0183  max mem: 11061
# Test:  [130/160]  eta: 0:00:18  class_error: 5.26  loss: 3.4742 (4.7704)  loss_ce: 0.0960 (0.1681)  loss_bbox: 0.0967 (0.1313)  loss_giou: 0.3385 (0.4418)  loss_ce_0: 0.2366 (0.2757)  loss_bbox_0: 0.1263 (0.1733)  loss_giou_0: 0.4127 (0.4976)  loss_ce_1: 0.1681 (0.2240)  loss_bbox_1: 0.1091 (0.1476)  loss_giou_1: 0.3952 (0.4635)  loss_ce_2: 0.1769 (0.2069)  loss_bbox_2: 0.1019 (0.1349)  loss_giou_2: 0.3936 (0.4470)  loss_ce_3: 0.1166 (0.1768)  loss_bbox_3: 0.0895 (0.1314)  loss_giou_3: 0.3537 (0.4370)  loss_ce_4: 0.0806 (0.1630)  loss_bbox_4: 0.0945 (0.1277)  loss_giou_4: 0.3534 (0.4227)  loss_ce_unscaled: 0.0960 (0.1681)  class_error_unscaled: 8.5714 (11.6336)  loss_bbox_unscaled: 0.0193 (0.0263)  loss_giou_unscaled: 0.1692 (0.2209)  cardinality_error_unscaled: 0.7500 (1.6260)  loss_ce_0_unscaled: 0.2366 (0.2757)  loss_bbox_0_unscaled: 0.0253 (0.0347)  loss_giou_0_unscaled: 0.2064 (0.2488)  cardinality_error_0_unscaled: 4.5000 (4.8378)  loss_ce_1_unscaled: 0.1681 (0.2240)  loss_bbox_1_unscaled: 0.0218 (0.0295)  loss_giou_1_unscaled: 0.1976 (0.2317)  cardinality_error_1_unscaled: 1.7500 (2.9847)  loss_ce_2_unscaled: 0.1769 (0.2069)  loss_bbox_2_unscaled: 0.0204 (0.0270)  loss_giou_2_unscaled: 0.1968 (0.2235)  cardinality_error_2_unscaled: 1.0000 (2.4084)  loss_ce_3_unscaled: 0.1166 (0.1768)  loss_bbox_3_unscaled: 0.0179 (0.0263)  loss_giou_3_unscaled: 0.1768 (0.2185)  cardinality_error_3_unscaled: 1.0000 (1.9714)  loss_ce_4_unscaled: 0.0806 (0.1630)  loss_bbox_4_unscaled: 0.0189 (0.0255)  loss_giou_4_unscaled: 0.1767 (0.2114)  cardinality_error_4_unscaled: 0.7500 (1.5420)  time: 0.5924  data: 0.0188  max mem: 11061
# Test:  [140/160]  eta: 0:00:12  class_error: 6.25  loss: 4.3217 (4.7909)  loss_ce: 0.1411 (0.1681)  loss_bbox: 0.1023 (0.1325)  loss_giou: 0.4318 (0.4428)  loss_ce_0: 0.3041 (0.2796)  loss_bbox_0: 0.1413 (0.1735)  loss_giou_0: 0.4609 (0.4980)  loss_ce_1: 0.2126 (0.2245)  loss_bbox_1: 0.1158 (0.1489)  loss_giou_1: 0.4421 (0.4669)  loss_ce_2: 0.1836 (0.2078)  loss_bbox_2: 0.1059 (0.1357)  loss_giou_2: 0.4297 (0.4492)  loss_ce_3: 0.1588 (0.1773)  loss_bbox_3: 0.1005 (0.1324)  loss_giou_3: 0.4231 (0.4375)  loss_ce_4: 0.1396 (0.1633)  loss_bbox_4: 0.0960 (0.1289)  loss_giou_4: 0.3982 (0.4240)  loss_ce_unscaled: 0.1411 (0.1681)  class_error_unscaled: 9.0909 (11.5839)  loss_bbox_unscaled: 0.0205 (0.0265)  loss_giou_unscaled: 0.2159 (0.2214)  cardinality_error_unscaled: 1.2500 (1.6454)  loss_ce_0_unscaled: 0.3041 (0.2796)  loss_bbox_0_unscaled: 0.0283 (0.0347)  loss_giou_0_unscaled: 0.2305 (0.2490)  cardinality_error_0_unscaled: 5.0000 (4.9592)  loss_ce_1_unscaled: 0.2126 (0.2245)  loss_bbox_1_unscaled: 0.0232 (0.0298)  loss_giou_1_unscaled: 0.2211 (0.2334)  cardinality_error_1_unscaled: 2.2500 (3.0638)  loss_ce_2_unscaled: 0.1836 (0.2078)  loss_bbox_2_unscaled: 0.0212 (0.0271)  loss_giou_2_unscaled: 0.2149 (0.2246)  cardinality_error_2_unscaled: 1.5000 (2.4450)  loss_ce_3_unscaled: 0.1588 (0.1773)  loss_bbox_3_unscaled: 0.0201 (0.0265)  loss_giou_3_unscaled: 0.2116 (0.2187)  cardinality_error_3_unscaled: 1.2500 (1.9947)  loss_ce_4_unscaled: 0.1396 (0.1633)  loss_bbox_4_unscaled: 0.0192 (0.0258)  loss_giou_4_unscaled: 0.1991 (0.2120)  cardinality_error_4_unscaled: 1.2500 (1.5567)  time: 0.5929  data: 0.0189  max mem: 11061
# Test:  [150/160]  eta: 0:00:06  class_error: 0.00  loss: 4.9316 (4.8384)  loss_ce: 0.1713 (0.1740)  loss_bbox: 0.1023 (0.1332)  loss_giou: 0.4598 (0.4445)  loss_ce_0: 0.3516 (0.2862)  loss_bbox_0: 0.1559 (0.1756)  loss_giou_0: 0.5052 (0.4981)  loss_ce_1: 0.2283 (0.2286)  loss_bbox_1: 0.1304 (0.1503)  loss_giou_1: 0.4774 (0.4680)  loss_ce_2: 0.2443 (0.2127)  loss_bbox_2: 0.1089 (0.1361)  loss_giou_2: 0.4643 (0.4511)  loss_ce_3: 0.1651 (0.1820)  loss_bbox_3: 0.1231 (0.1332)  loss_giou_3: 0.4746 (0.4403)  loss_ce_4: 0.1886 (0.1683)  loss_bbox_4: 0.0995 (0.1294)  loss_giou_4: 0.4646 (0.4267)  loss_ce_unscaled: 0.1713 (0.1740)  class_error_unscaled: 9.0909 (11.6670)  loss_bbox_unscaled: 0.0205 (0.0266)  loss_giou_unscaled: 0.2299 (0.2223)  cardinality_error_unscaled: 1.0000 (1.6556)  loss_ce_0_unscaled: 0.3516 (0.2862)  loss_bbox_0_unscaled: 0.0312 (0.0351)  loss_giou_0_unscaled: 0.2526 (0.2490)  cardinality_error_0_unscaled: 4.7500 (4.9818)  loss_ce_1_unscaled: 0.2283 (0.2286)  loss_bbox_1_unscaled: 0.0261 (0.0301)  loss_giou_1_unscaled: 0.2387 (0.2340)  cardinality_error_1_unscaled: 3.2500 (3.0828)  loss_ce_2_unscaled: 0.2443 (0.2127)  loss_bbox_2_unscaled: 0.0218 (0.0272)  loss_giou_2_unscaled: 0.2321 (0.2256)  cardinality_error_2_unscaled: 1.5000 (2.4570)  loss_ce_3_unscaled: 0.1651 (0.1820)  loss_bbox_3_unscaled: 0.0246 (0.0266)  loss_giou_3_unscaled: 0.2373 (0.2201)  cardinality_error_3_unscaled: 1.2500 (1.9950)  loss_ce_4_unscaled: 0.1886 (0.1683)  loss_bbox_4_unscaled: 0.0199 (0.0259)  loss_giou_4_unscaled: 0.2323 (0.2133)  cardinality_error_4_unscaled: 1.0000 (1.5629)  time: 0.5964  data: 0.0188  max mem: 11061
# Test:  [159/160]  eta: 0:00:00  class_error: 0.00  loss: 4.4598 (4.8039)  loss_ce: 0.1268 (0.1717)  loss_bbox: 0.0955 (0.1320)  loss_giou: 0.4450 (0.4427)  loss_ce_0: 0.3095 (0.2842)  loss_bbox_0: 0.1281 (0.1741)  loss_giou_0: 0.4889 (0.4965)  loss_ce_1: 0.2071 (0.2270)  loss_bbox_1: 0.1027 (0.1487)  loss_giou_1: 0.4438 (0.4652)  loss_ce_2: 0.1762 (0.2107)  loss_bbox_2: 0.0956 (0.1353)  loss_giou_2: 0.4396 (0.4482)  loss_ce_3: 0.1553 (0.1805)  loss_bbox_3: 0.0928 (0.1318)  loss_giou_3: 0.4196 (0.4376)  loss_ce_4: 0.1144 (0.1663)  loss_bbox_4: 0.0920 (0.1281)  loss_giou_4: 0.4110 (0.4235)  loss_ce_unscaled: 0.1268 (0.1717)  class_error_unscaled: 7.6923 (11.5699)  loss_bbox_unscaled: 0.0191 (0.0264)  loss_giou_unscaled: 0.2225 (0.2213)  cardinality_error_unscaled: 0.7500 (1.6281)  loss_ce_0_unscaled: 0.3095 (0.2842)  loss_bbox_0_unscaled: 0.0256 (0.0348)  loss_giou_0_unscaled: 0.2445 (0.2482)  cardinality_error_0_unscaled: 5.0000 (5.0016)  loss_ce_1_unscaled: 0.2071 (0.2270)  loss_bbox_1_unscaled: 0.0205 (0.0297)  loss_giou_1_unscaled: 0.2219 (0.2326)  cardinality_error_1_unscaled: 3.0000 (3.0812)  loss_ce_2_unscaled: 0.1762 (0.2107)  loss_bbox_2_unscaled: 0.0191 (0.0271)  loss_giou_2_unscaled: 0.2198 (0.2241)  cardinality_error_2_unscaled: 1.5000 (2.4406)  loss_ce_3_unscaled: 0.1553 (0.1805)  loss_bbox_3_unscaled: 0.0186 (0.0264)  loss_giou_3_unscaled: 0.2098 (0.2188)  cardinality_error_3_unscaled: 1.0000 (1.9688)  loss_ce_4_unscaled: 0.1144 (0.1663)  loss_bbox_4_unscaled: 0.0184 (0.0256)  loss_giou_4_unscaled: 0.2055 (0.2117)  cardinality_error_4_unscaled: 1.0000 (1.5391)  time: 0.5942  data: 0.0189  max mem: 11061
# Test: Total time: 0:01:37 (0.6087 s / it)
# Averaged stats: class_error: 0.00  loss: 4.4598 (4.8039)  loss_ce: 0.1268 (0.1717)  loss_bbox: 0.0955 (0.1320)  loss_giou: 0.4450 (0.4427)  loss_ce_0: 0.3095 (0.2842)  loss_bbox_0: 0.1281 (0.1741)  loss_giou_0: 0.4889 (0.4965)  loss_ce_1: 0.2071 (0.2270)  loss_bbox_1: 0.1027 (0.1487)  loss_giou_1: 0.4438 (0.4652)  loss_ce_2: 0.1762 (0.2107)  loss_bbox_2: 0.0956 (0.1353)  loss_giou_2: 0.4396 (0.4482)  loss_ce_3: 0.1553 (0.1805)  loss_bbox_3: 0.0928 (0.1318)  loss_giou_3: 0.4196 (0.4376)  loss_ce_4: 0.1144 (0.1663)  loss_bbox_4: 0.0920 (0.1281)  loss_giou_4: 0.4110 (0.4235)  loss_ce_unscaled: 0.1268 (0.1717)  class_error_unscaled: 7.6923 (11.5699)  loss_bbox_unscaled: 0.0191 (0.0264)  loss_giou_unscaled: 0.2225 (0.2213)  cardinality_error_unscaled: 0.7500 (1.6281)  loss_ce_0_unscaled: 0.3095 (0.2842)  loss_bbox_0_unscaled: 0.0256 (0.0348)  loss_giou_0_unscaled: 0.2445 (0.2482)  cardinality_error_0_unscaled: 5.0000 (5.0016)  loss_ce_1_unscaled: 0.2071 (0.2270)  loss_bbox_1_unscaled: 0.0205 (0.0297)  loss_giou_1_unscaled: 0.2219 (0.2326)  cardinality_error_1_unscaled: 3.0000 (3.0812)  loss_ce_2_unscaled: 0.1762 (0.2107)  loss_bbox_2_unscaled: 0.0191 (0.0271)  loss_giou_2_unscaled: 0.2198 (0.2241)  cardinality_error_2_unscaled: 1.5000 (2.4406)  loss_ce_3_unscaled: 0.1553 (0.1805)  loss_bbox_3_unscaled: 0.0186 (0.0264)  loss_giou_3_unscaled: 0.2098 (0.2188)  cardinality_error_3_unscaled: 1.0000 (1.9688)  loss_ce_4_unscaled: 0.1144 (0.1663)  loss_bbox_4_unscaled: 0.0184 (0.0256)  loss_giou_4_unscaled: 0.2055 (0.2117)  cardinality_error_4_unscaled: 1.0000 (1.5391)
# Accumulating evaluation results...
# DONE (t=0.61s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.581
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.834
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.653
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.003
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.249
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.629
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.363
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.656
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.732
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.087
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.398
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.776
# Training time 2:01:28

# %% [markdown]
# ## Check the results

# %% [markdown]
# ### Monitoring of training
#
# Reference: https://github.com/lessw2020/Thunder-Detr/blob/master/View_your_training_results.ipynb

# %%
from util.plot_utils import plot_logs

from pathlib import Path

log_directory = [Path('outputs/')]

# %% [markdown]
#   As mentioned in the code of [`plot_logs`](https://github.com/facebookresearch/detr/blob/5e66b4cd15b2b182da347103dd16578d28b49d69/util/plot_utils.py#L13):
# -   solid lines are training results,
# -   dashed lines are validation results.

# %%
fields_of_interest = (
    'loss',
    'mAP',
    )

plot_logs(log_directory,
          fields_of_interest)

# %%
fields_of_interest = (
    'loss_ce',
    'loss_bbox',
    'loss_giou',
    )

plot_logs(log_directory,
          fields_of_interest)

# %%
fields_of_interest = (
    'class_error',
    'cardinality_error_unscaled',
    )

plot_logs(log_directory,
          fields_of_interest)

# %% [markdown]
# ### Load the fine-tuned model
#
# - Explanation: https://github.com/facebookresearch/detr/issues/9#issuecomment-636391562

# %%
model = torch.hub.load('facebookresearch/detr',
                       'detr_resnet101',
                       pretrained=False,
                       num_classes=num_classes)

checkpoint = torch.load('outputs/checkpoint.pth',
                        map_location='cpu')

model.load_state_dict(checkpoint['model'],
                      strict=False)

model.eval();
# Out:
# Downloading: "https://github.com/facebookresearch/detr/archive/master.zip" to /root/.cache/torch/hub/master.zip
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
# HBox(children=(FloatProgress(value=0.0, max=178728960.0), HTML(value='')))

# %% [markdown]
# ### Boilerplate functions to display fine-tuned results

# %%
def plot_finetuned_results(pil_img, prob=None, boxes=None):
    plt.figure(figsize=(16,10))
    plt.imshow(pil_img)
    ax = plt.gca()
    colors = COLORS * 100
    if prob is not None and boxes is not None:
      for p, (xmin, ymin, xmax, ymax), c in zip(prob, boxes.tolist(), colors):
          ax.add_patch(plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                    fill=False, color=c, linewidth=3))
          cl = p.argmax()
          text = f'{finetuned_classes[cl]}: {p[cl]:0.2f}'
          ax.text(xmin, ymin, text, fontsize=15,
                  bbox=dict(facecolor='yellow', alpha=0.5))
    plt.axis('off')
    plt.show()

# %%
def run_worflow(my_image, my_model):
  # mean-std normalize the input image (batch-size: 1)
  img = transform(my_image).unsqueeze(0)

  # propagate through the model
  outputs = my_model(img)

  for threshold in [0.85, 0.5, 0.0]:
    
    probas_to_keep, bboxes_scaled = filter_bboxes_from_outputs(outputs, my_image.size,
                                                               threshold=threshold)

    plot_finetuned_results(my_image,
                           probas_to_keep, 
                           bboxes_scaled)

# %% [markdown]
# ### With a training image

# %%
train_path = proj_path+'/content/data/POD/train/'
imgs = os.listdir(train_path)
rand_img = imgs[np.random.randint(0,len(imgs))]

os.chdir(proj_path)
print(os.getcwd())
img_name = proj_path + '/content/data/POD/train/' + rand_img

im = Image.open(img_name)

run_worflow(im,
            model)
# Out:
# /content/drive/My Drive/Main Task

# %% [markdown]
# ### With a validation image

# %%
val_path = proj_path+'/content/data/POD/val/'
imgs = os.listdir(val_path)
rand_img = imgs[np.random.randint(0,len(imgs))]

img_name = proj_path + '/content/data/POD/val/' + rand_img
im = Image.open(img_name)

run_worflow(im,
            model)

# %% [markdown]
# ## Evaluate on all images

# %%
from tqdm.notebook import tqdm
import json
import pandas as pd


dataDir=proj_path+'/content/data/POD/'
dataType='all'
annFile='{}annotations/all.json'.format(dataDir)

output_annotation_file = proj_path+'/content/detr/outputs/predictions.json'
imgsDir = dataDir + '/' + dataType

# %%
# initialize COCO api for instance annotations
coco=COCO(annFile)

imgIds = coco.getImgIds()
# Out:
# loading annotations into memory...
# Done (t=0.56s)
# creating index...
# index created!

# %%
# display COCO categories and supercategories
cats = coco.loadCats(coco.getCatIds())
nms=[cat['name'] for cat in cats]
print(nms)
nms1 = set([cat['supercategory'] for cat in cats])
print(nms1)
# Out:
# ['abstract', 'author', 'caption', 'date', 'equation', 'figure', 'footer', 'formula', 'list', 'logo', 'natural_image', 'paragraph', 'reference', 'section', 'signature', 'table', 'title']
# {'none'}

# %% [markdown]
# ## Save the outputs to a json file

# %%
img_data = []

for imgId in tqdm(imgIds):

  img = coco.loadImgs(imgId)[0]
  img_name = '%s/%s/%s'%(dataDir,dataType,img['file_name'])
  #print(img_name)

  im = Image.open(img_name)
  im1 = transform(im).unsqueeze(0)

  # propagate through the model
  outputs = model(im1)
  
  annotations_tmp = {}
  for logits,boxes in zip(outputs["pred_logits"],outputs["pred_boxes"]):
    annotations_tmp['image_id'] = imgId
    annotations_tmp['image_size'] = im.size
    annotations_tmp['pred_logits'] = logits.tolist()
    annotations_tmp['pred_boxes'] = boxes.tolist()
    img_data.append(annotations_tmp)

#save the outputs to a json file
outfile =  open(output_annotation_file, 'w')
json_str = json.dumps(img_data, indent=4)
outfile.write(json_str)
outfile.close()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1600.0), HTML(value='')))

# %%
imgsDir = dataDir + '/' + dataType
imgIds = coco.getImgIds();
bb_threshold = 0.85
iou_threshold = 0.5

results = []
for i in range(num_classes):
  results.append({'class':nms[i], 'rel':0, 'ret':0, 'rel_ret':0, 'prec':0, 'rec':0, 'F1':0})

#load the outputs from the json file to a dictionary
with open(output_annotation_file) as json_file: 
    img_data = json.load(json_file)

for imgId in imgIds:
  
  img = coco.loadImgs(imgId)[0]
  img_name = '%s/%s/%s'%(dataDir,dataType,img['file_name'])
  #print(img_name)

  annIds = coco.getAnnIds(imgIds=img['id'])
  anns = coco.loadAnns(annIds)
  #_ = [print(ann) for ann in anns]
  #I = io.imread(img_name)
  #plt.imshow(I)
  #coco.showAnns(anns, draw_bbox=True)

  outputs = {}
  outputs["pred_logits"] = torch.FloatTensor([img_data[imgId]["pred_logits"]])
  outputs["pred_boxes"] =  torch.FloatTensor([img_data[imgId]["pred_boxes"]])

  prob, boxes = filter_bboxes_from_outputs(outputs, img_data[imgId]['image_size'], threshold=bb_threshold)
  #print(prob, boxes)
  #plot_finetuned_results(I, prob, boxes)


  for ann in anns:
    bb1 = list(ann['bbox'])
    cat1 = ann['category_id']
    results[cat1]['rel'] += 1

    #add del x, del y to x1, y1 to get x2, y2
    bb1[2] += bb1[0]; bb1[3] += bb1[1]
    for p, bb2 in zip(prob, boxes.tolist()):
      cat2 = int(p.argmax())
      if bb_intersection_over_union(bb1,bb2) >= iou_threshold and cat1==cat2:
        results[cat1]['rel_ret'] += 1
        break

  for p in prob:
    cat2 = int(p.argmax())
    results[cat2]['ret'] += 1

for cat in results:
  if cat['rel_ret'] != 0:
    cat['prec'] = cat['rel_ret'] / cat['ret']
    cat['rec'] = cat['rel_ret'] / cat['rel']
    cat['F1'] = 2 * (cat['prec']*cat['rec'])/((cat['prec']+cat['rec']))

df = pd.DataFrame(results)
df = df[(df.rel!=0) | (df.ret!=0) | (df.rel_ret!=0)]
print(df)
print("\nMean")
print(df[["prec", "rec", "F1"]].mean())
# Out:
#       class   rel   ret  rel_ret      prec       rec        F1
# 5    figure  1978  1930     1772  0.918135  0.895854  0.906858
# 7   formula  3515  3489     2237  0.641158  0.636415  0.638778
# 15    table   699   722      664  0.919668  0.949928  0.934553
#
# Mean
# prec    0.826320
# rec     0.827399
# F1      0.826730
# dtype: float64
