# %% [markdown]
# # Objective: fine-tuning DETR
#
# -   This notebook can be found on my Github profile: https://github.com/woctezuma/finetune-detr
# -   Official DETR repository: https://github.com/facebookresearch/detr
# -   Discussion about fine-tuning in [a Github issue](https://github.com/facebookresearch/detr/issues/9).
# -   A nice blog post about another approach (Mask R-CNN) and the balloon dataset (which we use in this notebook): [here](https://engineering.matterport.com/splash-of-color-instance-segmentation-with-mask-r-cnn-and-tensorflow-7c761e238b46).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Define useful boilerplate functions
#
# Adapted from:
# -   https://colab.research.google.com/github/facebookresearch/detr/blob/colab/notebooks/detr_attention.ipynb

# %%
import torch, torchvision
print(torch.__version__, torch.cuda.is_available())

torch.set_grad_enabled(False);

import os
proj_path = "/content/drive/My Drive/Main Task"
os.chdir(proj_path)
# Out:
# 1.6.0+cu101 False

# %%
import torchvision.transforms as T

# standard PyTorch mean-std input image normalization
transform = T.Compose([
    T.Resize(800),
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# for output bounding box post-processing
def box_cxcywh_to_xyxy(x):
    x_c, y_c, w, h = x.unbind(1)
    b = [(x_c - 0.5 * w), (y_c - 0.5 * h),
         (x_c + 0.5 * w), (y_c + 0.5 * h)]
    return torch.stack(b, dim=1)

def rescale_bboxes(out_bbox, size):
    img_w, img_h = size
    b = box_cxcywh_to_xyxy(out_bbox)
    b = b * torch.tensor([img_w, img_h, img_w, img_h], dtype=torch.float32)
    return b

# %%
def filter_bboxes_from_outputs(outputs, size,
                               threshold=0.7):
  
  # keep only predictions with confidence above threshold
  probas = outputs['pred_logits'].softmax(-1)[0, :, :-1]
  keep = probas.max(-1).values > threshold

  probas_to_keep = probas[keep]

  # convert boxes from [0; 1] to image scales
  bboxes_scaled = rescale_bboxes(outputs['pred_boxes'][0, keep], size)
  
  return probas_to_keep, bboxes_scaled

# %%
def bb_intersection_over_union(boxA, boxB):
	# determine the (x, y)-coordinates of the intersection rectangle
	xA = max(boxA[0], boxB[0])
	yA = max(boxA[1], boxB[1])
	xB = min(boxA[2], boxB[2])
	yB = min(boxA[3], boxB[3])
	# compute the area of intersection rectangle
	interArea = max(0, xB - xA + 1) * max(0, yB - yA + 1)
	# compute the area of both the prediction and ground-truth
	# rectangles
	boxAArea = (boxA[2] - boxA[0] + 1) * (boxA[3] - boxA[1] + 1)
	boxBArea = (boxB[2] - boxB[0] + 1) * (boxB[3] - boxB[1] + 1)
	# compute the intersection over union by taking the intersection
	# area and dividing it by the sum of prediction + ground-truth
	# areas - the interesection area
	iou = interArea / float(boxAArea + boxBArea - interArea)
	# return the intersection over union value
	return iou

# %%
# colors for visualization
COLORS = [[0.000, 0.447, 0.741], [0.850, 0.325, 0.098], [0.929, 0.694, 0.125],
          [0.494, 0.184, 0.556], [0.466, 0.674, 0.188], [0.301, 0.745, 0.933]]

# %% [markdown]
# ## Load pre-trained weights
#
# Load a check-point (urls can be found [here](https://github.com/facebookresearch/detr#model-zoo)), then remove the classification head.

# %%
# Get pretrained weights
checkpoint = torch.hub.load_state_dict_from_url(
            url='https://dl.fbaipublicfiles.com/detr/detr-r101-2c7b67e5.pth',
            map_location='cpu',
            check_hash=True)

# Remove class weights
del checkpoint["model"]["class_embed.weight"]
del checkpoint["model"]["class_embed.bias"]

# Save
os.chdir(os.path.join(proj_path,"content/detr"))
torch.save(checkpoint,
           'detr-r101_no-class-head.pth')
# Out:
# Downloading: "https://dl.fbaipublicfiles.com/detr/detr-r101-2c7b67e5.pth" to /root/.cache/torch/hub/checkpoints/detr-r101-2c7b67e5.pth
# HBox(children=(FloatProgress(value=0.0, max=242846568.0), HTML(value='')))

# %% [markdown]
# ## Prepare the dataset for fine-tuning

# %% [markdown]
# We expect the directory structure to be the following:
# ```
# path/to/coco/
# ├ annotations/  # JSON annotations
# │  ├ annotations/custom_train.json
# │  └ annotations/custom_val.json
# ├ train2017/    # training images
# └ val2017/      # validation images
# ```

# %% [markdown]
# ## Check the dataset after it was pre-processed for fine-tuning
#
# To verify the data loading is correct, let's visualize the annotations of randomly selected samples in the training set:
# -   Demo of COCO API: https://github.com/cocodataset/cocoapi/blob/master/PythonAPI/pycocoDemo.ipynb

# %%
# %matplotlib inline
import pycocotools.coco as coco
from pycocotools.coco import COCO
import numpy as np
import skimage.io as io
import matplotlib.pyplot as plt
import pylab
pylab.rcParams['figure.figsize'] = (10.0, 8.0)
from PIL import Image

# %%
dataDir=proj_path+'/content/data/POD/'
dataType='train'
annFile='{}annotations/train.json'.format(dataDir)

# %%
# initialize COCO api for instance annotations
coco=COCO(annFile)
# Out:
# loading annotations into memory...
# Done (t=0.71s)
# creating index...
# index created!

# %%
# display COCO categories and supercategories
cats = coco.loadCats(coco.getCatIds())
nms=[cat['name'] for cat in cats]
print(nms)
nms1 = set([cat['supercategory'] for cat in cats])
print(nms1)
# Out:
# ['figure', 'formula', 'table']
# {'none'}

# %%
# load and display image
catIds = coco.getCatIds(catNms=[])

for id in catIds:
  imgCount = len(coco.getImgIds(catIds=id))
  if imgCount > 0:
    print("id :",id,", name : ",nms[id],", image count : ",imgCount)

imgIds = coco.getImgIds(catIds=[0,1,2])
# will return images having all objects mentioned in the catIds list

#print(catIds)
print(len(imgIds))
# Out:
# id : 0 , name :  figure , image count :  539
# id : 1 , name :  formula , image count :  533
# id : 2 , name :  table , image count :  339
# 24

# %%
img_id = imgIds[np.random.randint(0,len(imgIds))]
#print(img_id)

img = coco.loadImgs(img_id)[0]

img_name = '%s/%s/%s'%(dataDir,dataType,img['file_name'])
print(img_name)

I = io.imread(img_name)
plt.imshow(I)
# Out:
# /content/drive/My Drive/Main Task/content/data/POD//train/POD_0886.bmp

# %%
annIds = coco.getAnnIds(imgIds=img['id'], catIds=catIds)
anns = coco.loadAnns(annIds)
print(annIds)
_ = [print(i) for i in anns]
# Out:
# [3422, 3423, 3424]
# {'id': 3422, 'image_id': 886, 'segmentation': [], 'ignore': 0, 'area': 28150, 'iscrowd': 0, 'bbox': [348, 1060, 563, 50], 'category_id': 1}
# {'id': 3423, 'image_id': 886, 'segmentation': [], 'ignore': 0, 'area': 186948, 'iscrowd': 0, 'bbox': [254, 605, 577, 324], 'category_id': 2}
# {'id': 3424, 'image_id': 886, 'segmentation': [], 'ignore': 0, 'area': 86868, 'iscrowd': 0, 'bbox': [369, 181, 342, 254], 'category_id': 0}

# %%
# load and display instance annotations
plt.imshow(I)
coco.showAnns(anns, draw_bbox=True)

# %% [markdown]
# ## Fine-tuning
#
# -   Instructions appear in [a Github Gist](https://gist.github.com/mlk1337/651297e28199b4bb7907fc413c49f58f).
#
# NB: There is a `--frozen_weights` argument. However,
# i) I have yet to figure out how it is used,
# ii) it is of no use for box detection. Indeed, "frozen training is meant for segmentation only" (as mentioned at this [line](https://github.com/facebookresearch/detr/blob/f4cdc542de34de771da8b9189742e5465f5220cd/main.py#L110) of the source-code).

# %% [markdown]
# ## Boilerplate variables
# Caveat: the parameter name num_classes is misleading. It is actually the ID which DETR will reserve for its own no_object class.
#
# It should be set to one plus the highest class ID in your dataset.
#
# For instance, if you have one class (balloon):
#
# -   if you used the index n°0 for this class, then max_id = 0 and num_classes = max_id+1 = 1
# -   if you used the index n°1 for this class, then max_id = 1 and num_classes = max_id+1 = 2
#
# Reference: https://github.com/facebookresearch/detr/issues/108#issuecomment-650269223

# %%
# Fine-tuned classes
finetuned_classes = ['figure', 'formula', 'table',]

num_classes = len(finetuned_classes)
print(num_classes)
# Out:
# 3

# %%
os.chdir(os.path.join(proj_path,"content/detr"))
print(os.getcwd())

#resume "/content/drive/My Drive/Main Task/content/detr/outputs/checkpoint.pth" \
#resume "/content/drive/My Drive/Main Task/content/detr/detr-r101_no-class-head.pth" \
# Out:
# /content/drive/My Drive/Main Task/content/detr

# %%
# !python main.py \
  --dataset_file "custom" \
  --coco_path "/content/drive/My Drive/Main Task/content/data/POD" \
  --output_dir "outputs" \
  --resume "/content/drive/My Drive/Main Task/content/detr/outputs/checkpoint.pth" \
  --num_classes $num_classes \
  --epochs 170 \
  --device "cuda" \
  --batch_size 2  \
  --backbone "resnet101"
# Out:
# Not using distributed mode
# git:
#   sha: 6ecf58fe5e8eb503cb3be015983756789a9964f5, status: has uncommited changes, branch: finetune
#
# Namespace(aux_loss=True, backbone='resnet101', batch_size=2, bbox_loss_coef=5, clip_max_norm=0.1, coco_panoptic_path=None, coco_path='/content/drive/My Drive/Main Task/content/data/POD', dataset_file='custom', dec_layers=6, device='cuda', dice_loss_coef=1, dilation=False, dim_feedforward=2048, dist_url='env://', distributed=False, dropout=0.1, enc_layers=6, eos_coef=0.1, epochs=170, eval=False, frozen_weights=None, giou_loss_coef=2, hidden_dim=256, lr=0.0001, lr_backbone=1e-05, lr_drop=200, mask_loss_coef=1, masks=False, nheads=8, num_classes=3, num_queries=100, num_workers=2, output_dir='outputs', position_embedding='sine', pre_norm=False, remove_difficult=False, resume='/content/drive/My Drive/Main Task/content/detr/outputs/checkpoint.pth', seed=42, set_cost_bbox=5, set_cost_class=1, set_cost_giou=2, start_epoch=0, weight_decay=0.0001, world_size=1)
# number of params: 60219656
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# loading annotations into memory...
# Done (t=0.01s)
# creating index...
# index created!
# Start training
# Epoch: [150]  [  0/480]  eta: 0:08:13  lr: 0.000100  class_error: 28.57  loss: 5.4652 (5.4652)  loss_ce: 0.2123 (0.2123)  loss_bbox: 0.1526 (0.1526)  loss_giou: 0.5921 (0.5921)  loss_ce_0: 0.2412 (0.2412)  loss_bbox_0: 0.1903 (0.1903)  loss_giou_0: 0.7663 (0.7663)  loss_ce_1: 0.2184 (0.2184)  loss_bbox_1: 0.1097 (0.1097)  loss_giou_1: 0.5441 (0.5441)  loss_ce_2: 0.2369 (0.2369)  loss_bbox_2: 0.1189 (0.1189)  loss_giou_2: 0.5434 (0.5434)  loss_ce_3: 0.1887 (0.1887)  loss_bbox_3: 0.1254 (0.1254)  loss_giou_3: 0.4010 (0.4010)  loss_ce_4: 0.0914 (0.0914)  loss_bbox_4: 0.1301 (0.1301)  loss_giou_4: 0.6024 (0.6024)  loss_ce_unscaled: 0.2123 (0.2123)  class_error_unscaled: 28.5714 (28.5714)  loss_bbox_unscaled: 0.0305 (0.0305)  loss_giou_unscaled: 0.2961 (0.2961)  cardinality_error_unscaled: 0.5000 (0.5000)  loss_ce_0_unscaled: 0.2412 (0.2412)  loss_bbox_0_unscaled: 0.0381 (0.0381)  loss_giou_0_unscaled: 0.3832 (0.3832)  cardinality_error_0_unscaled: 5.5000 (5.5000)  loss_ce_1_unscaled: 0.2184 (0.2184)  loss_bbox_1_unscaled: 0.0219 (0.0219)  loss_giou_1_unscaled: 0.2720 (0.2720)  cardinality_error_1_unscaled: 5.0000 (5.0000)  loss_ce_2_unscaled: 0.2369 (0.2369)  loss_bbox_2_unscaled: 0.0238 (0.0238)  loss_giou_2_unscaled: 0.2717 (0.2717)  cardinality_error_2_unscaled: 2.0000 (2.0000)  loss_ce_3_unscaled: 0.1887 (0.1887)  loss_bbox_3_unscaled: 0.0251 (0.0251)  loss_giou_3_unscaled: 0.2005 (0.2005)  cardinality_error_3_unscaled: 3.0000 (3.0000)  loss_ce_4_unscaled: 0.0914 (0.0914)  loss_bbox_4_unscaled: 0.0260 (0.0260)  loss_giou_4_unscaled: 0.3012 (0.3012)  cardinality_error_4_unscaled: 0.5000 (0.5000)  time: 1.0272  data: 0.3498  max mem: 2580
# Epoch: [150]  [ 10/480]  eta: 0:05:22  lr: 0.000100  class_error: 0.00  loss: 4.1248 (4.1861)  loss_ce: 0.1266 (0.1187)  loss_bbox: 0.1110 (0.1152)  loss_giou: 0.3643 (0.3967)  loss_ce_0: 0.2412 (0.2407)  loss_bbox_0: 0.1310 (0.1484)  loss_giou_0: 0.3974 (0.4558)  loss_ce_1: 0.2034 (0.1956)  loss_bbox_1: 0.1097 (0.1234)  loss_giou_1: 0.4009 (0.4279)  loss_ce_2: 0.1650 (0.1782)  loss_bbox_2: 0.1120 (0.1156)  loss_giou_2: 0.4032 (0.3793)  loss_ce_3: 0.1454 (0.1379)  loss_bbox_3: 0.1110 (0.1146)  loss_giou_3: 0.4082 (0.4163)  loss_ce_4: 0.0914 (0.1121)  loss_bbox_4: 0.1105 (0.1127)  loss_giou_4: 0.3512 (0.3969)  loss_ce_unscaled: 0.1266 (0.1187)  class_error_unscaled: 7.6923 (9.1554)  loss_bbox_unscaled: 0.0222 (0.0230)  loss_giou_unscaled: 0.1821 (0.1984)  cardinality_error_unscaled: 1.5000 (2.2727)  loss_ce_0_unscaled: 0.2412 (0.2407)  loss_bbox_0_unscaled: 0.0262 (0.0297)  loss_giou_0_unscaled: 0.1987 (0.2279)  cardinality_error_0_unscaled: 6.5000 (8.0909)  loss_ce_1_unscaled: 0.2034 (0.1956)  loss_bbox_1_unscaled: 0.0219 (0.0247)  loss_giou_1_unscaled: 0.2005 (0.2140)  cardinality_error_1_unscaled: 6.0000 (6.4091)  loss_ce_2_unscaled: 0.1650 (0.1782)  loss_bbox_2_unscaled: 0.0224 (0.0231)  loss_giou_2_unscaled: 0.2016 (0.1896)  cardinality_error_2_unscaled: 2.5000 (4.1818)  loss_ce_3_unscaled: 0.1454 (0.1379)  loss_bbox_3_unscaled: 0.0222 (0.0229)  loss_giou_3_unscaled: 0.2041 (0.2081)  cardinality_error_3_unscaled: 2.0000 (2.9091)  loss_ce_4_unscaled: 0.0914 (0.1121)  loss_bbox_4_unscaled: 0.0221 (0.0225)  loss_giou_4_unscaled: 0.1756 (0.1984)  cardinality_error_4_unscaled: 2.0000 (2.4545)  time: 0.6865  data: 0.0395  max mem: 4284
# Epoch: [150]  [ 20/480]  eta: 0:05:01  lr: 0.000100  class_error: 7.14  loss: 3.8189 (3.7892)  loss_ce: 0.0590 (0.1038)  loss_bbox: 0.1039 (0.1088)  loss_giou: 0.3416 (0.3721)  loss_ce_0: 0.2030 (0.2206)  loss_bbox_0: 0.1252 (0.1437)  loss_giou_0: 0.3761 (0.4123)  loss_ce_1: 0.1630 (0.1777)  loss_bbox_1: 0.1109 (0.1154)  loss_giou_1: 0.3176 (0.3696)  loss_ce_2: 0.0991 (0.1572)  loss_bbox_2: 0.1113 (0.1109)  loss_giou_2: 0.3496 (0.3427)  loss_ce_3: 0.1071 (0.1174)  loss_bbox_3: 0.1016 (0.1072)  loss_giou_3: 0.4072 (0.3721)  loss_ce_4: 0.0860 (0.1052)  loss_bbox_4: 0.1010 (0.1067)  loss_giou_4: 0.3277 (0.3458)  loss_ce_unscaled: 0.0590 (0.1038)  class_error_unscaled: 0.0000 (8.0610)  loss_bbox_unscaled: 0.0208 (0.0218)  loss_giou_unscaled: 0.1708 (0.1861)  cardinality_error_unscaled: 1.0000 (1.8333)  loss_ce_0_unscaled: 0.2030 (0.2206)  loss_bbox_0_unscaled: 0.0250 (0.0287)  loss_giou_0_unscaled: 0.1881 (0.2061)  cardinality_error_0_unscaled: 6.5000 (7.7381)  loss_ce_1_unscaled: 0.1630 (0.1777)  loss_bbox_1_unscaled: 0.0222 (0.0231)  loss_giou_1_unscaled: 0.1588 (0.1848)  cardinality_error_1_unscaled: 5.0000 (6.1429)  loss_ce_2_unscaled: 0.0991 (0.1572)  loss_bbox_2_unscaled: 0.0223 (0.0222)  loss_giou_2_unscaled: 0.1748 (0.1714)  cardinality_error_2_unscaled: 2.5000 (4.1429)  loss_ce_3_unscaled: 0.1071 (0.1174)  loss_bbox_3_unscaled: 0.0203 (0.0214)  loss_giou_3_unscaled: 0.2036 (0.1860)  cardinality_error_3_unscaled: 2.0000 (2.6429)  loss_ce_4_unscaled: 0.0860 (0.1052)  loss_bbox_4_unscaled: 0.0202 (0.0213)  loss_giou_4_unscaled: 0.1638 (0.1729)  cardinality_error_4_unscaled: 1.5000 (2.0476)  time: 0.6379  data: 0.0089  max mem: 4284
# Epoch: [150]  [ 30/480]  eta: 0:05:00  lr: 0.000100  class_error: 0.00  loss: 3.3708 (3.6004)  loss_ce: 0.0250 (0.0858)  loss_bbox: 0.0971 (0.1082)  loss_giou: 0.3336 (0.3571)  loss_ce_0: 0.1461 (0.2048)  loss_bbox_0: 0.1320 (0.1420)  loss_giou_0: 0.3287 (0.3852)  loss_ce_1: 0.0840 (0.1608)  loss_bbox_1: 0.1163 (0.1200)  loss_giou_1: 0.3012 (0.3556)  loss_ce_2: 0.0582 (0.1430)  loss_bbox_2: 0.1016 (0.1114)  loss_giou_2: 0.2641 (0.3230)  loss_ce_3: 0.0438 (0.1032)  loss_bbox_3: 0.0974 (0.1093)  loss_giou_3: 0.2741 (0.3541)  loss_ce_4: 0.0341 (0.0865)  loss_bbox_4: 0.0979 (0.1063)  loss_giou_4: 0.3032 (0.3441)  loss_ce_unscaled: 0.0250 (0.0858)  class_error_unscaled: 0.0000 (6.3778)  loss_bbox_unscaled: 0.0194 (0.0216)  loss_giou_unscaled: 0.1668 (0.1785)  cardinality_error_unscaled: 0.5000 (1.5000)  loss_ce_0_unscaled: 0.1461 (0.2048)  loss_bbox_0_unscaled: 0.0264 (0.0284)  loss_giou_0_unscaled: 0.1643 (0.1926)  cardinality_error_0_unscaled: 4.5000 (7.1129)  loss_ce_1_unscaled: 0.0840 (0.1608)  loss_bbox_1_unscaled: 0.0233 (0.0240)  loss_giou_1_unscaled: 0.1506 (0.1778)  cardinality_error_1_unscaled: 2.5000 (5.3387)  loss_ce_2_unscaled: 0.0582 (0.1430)  loss_bbox_2_unscaled: 0.0203 (0.0223)  loss_giou_2_unscaled: 0.1321 (0.1615)  cardinality_error_2_unscaled: 1.5000 (3.4516)  loss_ce_3_unscaled: 0.0438 (0.1032)  loss_bbox_3_unscaled: 0.0195 (0.0219)  loss_giou_3_unscaled: 0.1370 (0.1770)  cardinality_error_3_unscaled: 1.0000 (2.1935)  loss_ce_4_unscaled: 0.0341 (0.0865)  loss_bbox_4_unscaled: 0.0196 (0.0213)  loss_giou_4_unscaled: 0.1516 (0.1721)  cardinality_error_4_unscaled: 1.0000 (1.6774)  time: 0.6566  data: 0.0093  max mem: 4284
# Epoch: [150]  [ 40/480]  eta: 0:04:53  lr: 0.000100  class_error: 16.67  loss: 3.3708 (3.6524)  loss_ce: 0.0296 (0.0900)  loss_bbox: 0.1101 (0.1092)  loss_giou: 0.3341 (0.3591)  loss_ce_0: 0.1761 (0.2108)  loss_bbox_0: 0.1441 (0.1441)  loss_giou_0: 0.3559 (0.4001)  loss_ce_1: 0.1082 (0.1634)  loss_bbox_1: 0.1358 (0.1225)  loss_giou_1: 0.3316 (0.3564)  loss_ce_2: 0.0674 (0.1353)  loss_bbox_2: 0.1158 (0.1133)  loss_giou_2: 0.3151 (0.3343)  loss_ce_3: 0.0438 (0.1016)  loss_bbox_3: 0.1098 (0.1092)  loss_giou_3: 0.2847 (0.3533)  loss_ce_4: 0.0293 (0.0880)  loss_bbox_4: 0.0988 (0.1092)  loss_giou_4: 0.3312 (0.3528)  loss_ce_unscaled: 0.0296 (0.0900)  class_error_unscaled: 0.0000 (6.6007)  loss_bbox_unscaled: 0.0220 (0.0218)  loss_giou_unscaled: 0.1671 (0.1795)  cardinality_error_unscaled: 1.0000 (1.6829)  loss_ce_0_unscaled: 0.1761 (0.2108)  loss_bbox_0_unscaled: 0.0288 (0.0288)  loss_giou_0_unscaled: 0.1780 (0.2001)  cardinality_error_0_unscaled: 5.0000 (7.2073)  loss_ce_1_unscaled: 0.1082 (0.1634)  loss_bbox_1_unscaled: 0.0272 (0.0245)  loss_giou_1_unscaled: 0.1658 (0.1782)  cardinality_error_1_unscaled: 3.0000 (5.6585)  loss_ce_2_unscaled: 0.0674 (0.1353)  loss_bbox_2_unscaled: 0.0232 (0.0227)  loss_giou_2_unscaled: 0.1576 (0.1671)  cardinality_error_2_unscaled: 1.5000 (3.6951)  loss_ce_3_unscaled: 0.0438 (0.1016)  loss_bbox_3_unscaled: 0.0220 (0.0218)  loss_giou_3_unscaled: 0.1424 (0.1767)  cardinality_error_3_unscaled: 1.0000 (2.4756)  loss_ce_4_unscaled: 0.0293 (0.0880)  loss_bbox_4_unscaled: 0.0198 (0.0218)  loss_giou_4_unscaled: 0.1656 (0.1764)  cardinality_error_4_unscaled: 1.0000 (1.7805)  time: 0.6801  data: 0.0099  max mem: 4284
# Epoch: [150]  [ 50/480]  eta: 0:04:46  lr: 0.000100  class_error: 0.00  loss: 3.3483 (3.5704)  loss_ce: 0.0310 (0.0939)  loss_bbox: 0.1062 (0.1088)  loss_giou: 0.2718 (0.3431)  loss_ce_0: 0.2219 (0.2061)  loss_bbox_0: 0.1463 (0.1479)  loss_giou_0: 0.4065 (0.3887)  loss_ce_1: 0.1364 (0.1609)  loss_bbox_1: 0.1174 (0.1228)  loss_giou_1: 0.3036 (0.3372)  loss_ce_2: 0.0674 (0.1388)  loss_bbox_2: 0.1106 (0.1144)  loss_giou_2: 0.2854 (0.3235)  loss_ce_3: 0.0474 (0.1033)  loss_bbox_3: 0.1020 (0.1088)  loss_giou_3: 0.2847 (0.3373)  loss_ce_4: 0.0334 (0.0950)  loss_bbox_4: 0.1077 (0.1084)  loss_giou_4: 0.2812 (0.3318)  loss_ce_unscaled: 0.0310 (0.0939)  class_error_unscaled: 0.0000 (7.2672)  loss_bbox_unscaled: 0.0212 (0.0218)  loss_giou_unscaled: 0.1359 (0.1715)  cardinality_error_unscaled: 0.5000 (1.5392)  loss_ce_0_unscaled: 0.2219 (0.2061)  loss_bbox_0_unscaled: 0.0293 (0.0296)  loss_giou_0_unscaled: 0.2033 (0.1943)  cardinality_error_0_unscaled: 3.5000 (6.7549)  loss_ce_1_unscaled: 0.1364 (0.1609)  loss_bbox_1_unscaled: 0.0235 (0.0246)  loss_giou_1_unscaled: 0.1518 (0.1686)  cardinality_error_1_unscaled: 3.0000 (5.1667)  loss_ce_2_unscaled: 0.0674 (0.1388)  loss_bbox_2_unscaled: 0.0221 (0.0229)  loss_giou_2_unscaled: 0.1427 (0.1618)  cardinality_error_2_unscaled: 1.5000 (3.2353)  loss_ce_3_unscaled: 0.0474 (0.1033)  loss_bbox_3_unscaled: 0.0204 (0.0218)  loss_giou_3_unscaled: 0.1424 (0.1686)  cardinality_error_3_unscaled: 0.5000 (2.2451)  loss_ce_4_unscaled: 0.0334 (0.0950)  loss_bbox_4_unscaled: 0.0215 (0.0217)  loss_giou_4_unscaled: 0.1406 (0.1659)  cardinality_error_4_unscaled: 0.5000 (1.6275)  time: 0.6620  data: 0.0101  max mem: 4284
# Epoch: [150]  [ 60/480]  eta: 0:04:37  lr: 0.000100  class_error: 0.00  loss: 2.6797 (3.5370)  loss_ce: 0.0338 (0.0966)  loss_bbox: 0.0962 (0.1076)  loss_giou: 0.2480 (0.3401)  loss_ce_0: 0.1120 (0.2015)  loss_bbox_0: 0.1478 (0.1460)  loss_giou_0: 0.3627 (0.3815)  loss_ce_1: 0.0811 (0.1601)  loss_bbox_1: 0.1161 (0.1260)  loss_giou_1: 0.2954 (0.3322)  loss_ce_2: 0.0477 (0.1346)  loss_bbox_2: 0.1052 (0.1131)  loss_giou_2: 0.2616 (0.3204)  loss_ce_3: 0.0275 (0.1003)  loss_bbox_3: 0.1008 (0.1094)  loss_giou_3: 0.2572 (0.3365)  loss_ce_4: 0.0302 (0.0955)  loss_bbox_4: 0.0903 (0.1081)  loss_giou_4: 0.2662 (0.3277)  loss_ce_unscaled: 0.0338 (0.0966)  class_error_unscaled: 0.0000 (7.0322)  loss_bbox_unscaled: 0.0192 (0.0215)  loss_giou_unscaled: 0.1240 (0.1700)  cardinality_error_unscaled: 0.5000 (1.5000)  loss_ce_0_unscaled: 0.1120 (0.2015)  loss_bbox_0_unscaled: 0.0296 (0.0292)  loss_giou_0_unscaled: 0.1813 (0.1907)  cardinality_error_0_unscaled: 3.0000 (6.5738)  loss_ce_1_unscaled: 0.0811 (0.1601)  loss_bbox_1_unscaled: 0.0232 (0.0252)  loss_giou_1_unscaled: 0.1477 (0.1661)  cardinality_error_1_unscaled: 1.5000 (4.9098)  loss_ce_2_unscaled: 0.0477 (0.1346)  loss_bbox_2_unscaled: 0.0210 (0.0226)  loss_giou_2_unscaled: 0.1308 (0.1602)  cardinality_error_2_unscaled: 1.0000 (2.9918)  loss_ce_3_unscaled: 0.0275 (0.1003)  loss_bbox_3_unscaled: 0.0202 (0.0219)  loss_giou_3_unscaled: 0.1286 (0.1682)  cardinality_error_3_unscaled: 0.5000 (2.1066)  loss_ce_4_unscaled: 0.0302 (0.0955)  loss_bbox_4_unscaled: 0.0181 (0.0216)  loss_giou_4_unscaled: 0.1331 (0.1639)  cardinality_error_4_unscaled: 0.5000 (1.5820)  time: 0.6432  data: 0.0095  max mem: 4284
# Epoch: [150]  [ 70/480]  eta: 0:04:33  lr: 0.000100  class_error: 0.00  loss: 3.7891 (3.6999)  loss_ce: 0.0415 (0.1046)  loss_bbox: 0.1048 (0.1125)  loss_giou: 0.3241 (0.3565)  loss_ce_0: 0.1363 (0.2047)  loss_bbox_0: 0.1471 (0.1496)  loss_giou_0: 0.3817 (0.3894)  loss_ce_1: 0.1127 (0.1681)  loss_bbox_1: 0.1198 (0.1305)  loss_giou_1: 0.3180 (0.3511)  loss_ce_2: 0.1009 (0.1447)  loss_bbox_2: 0.1087 (0.1177)  loss_giou_2: 0.2885 (0.3373)  loss_ce_3: 0.0392 (0.1076)  loss_bbox_3: 0.1016 (0.1143)  loss_giou_3: 0.3247 (0.3464)  loss_ce_4: 0.0323 (0.1077)  loss_bbox_4: 0.0993 (0.1130)  loss_giou_4: 0.3055 (0.3441)  loss_ce_unscaled: 0.0415 (0.1046)  class_error_unscaled: 0.0000 (7.4946)  loss_bbox_unscaled: 0.0210 (0.0225)  loss_giou_unscaled: 0.1620 (0.1783)  cardinality_error_unscaled: 0.5000 (1.5563)  loss_ce_0_unscaled: 0.1363 (0.2047)  loss_bbox_0_unscaled: 0.0294 (0.0299)  loss_giou_0_unscaled: 0.1909 (0.1947)  cardinality_error_0_unscaled: 3.5000 (6.2958)  loss_ce_1_unscaled: 0.1127 (0.1681)  loss_bbox_1_unscaled: 0.0240 (0.0261)  loss_giou_1_unscaled: 0.1590 (0.1756)  cardinality_error_1_unscaled: 2.0000 (4.7817)  loss_ce_2_unscaled: 0.1009 (0.1447)  loss_bbox_2_unscaled: 0.0217 (0.0235)  loss_giou_2_unscaled: 0.1443 (0.1687)  cardinality_error_2_unscaled: 1.0000 (3.0070)  loss_ce_3_unscaled: 0.0392 (0.1076)  loss_bbox_3_unscaled: 0.0203 (0.0229)  loss_giou_3_unscaled: 0.1624 (0.1732)  cardinality_error_3_unscaled: 1.0000 (2.1690)  loss_ce_4_unscaled: 0.0323 (0.1077)  loss_bbox_4_unscaled: 0.0199 (0.0226)  loss_giou_4_unscaled: 0.1527 (0.1720)  cardinality_error_4_unscaled: 0.5000 (1.6338)  time: 0.6732  data: 0.0100  max mem: 4284
# Epoch: [150]  [ 80/480]  eta: 0:04:25  lr: 0.000100  class_error: 25.00  loss: 3.8914 (3.7782)  loss_ce: 0.0545 (0.1054)  loss_bbox: 0.1092 (0.1130)  loss_giou: 0.3774 (0.3667)  loss_ce_0: 0.1901 (0.2100)  loss_bbox_0: 0.1377 (0.1506)  loss_giou_0: 0.3944 (0.3949)  loss_ce_1: 0.1329 (0.1707)  loss_bbox_1: 0.1275 (0.1316)  loss_giou_1: 0.3748 (0.3600)  loss_ce_2: 0.1220 (0.1459)  loss_bbox_2: 0.1234 (0.1202)  loss_giou_2: 0.3659 (0.3501)  loss_ce_3: 0.0879 (0.1077)  loss_bbox_3: 0.1155 (0.1155)  loss_giou_3: 0.4010 (0.3584)  loss_ce_4: 0.0869 (0.1085)  loss_bbox_4: 0.1126 (0.1134)  loss_giou_4: 0.4034 (0.3555)  loss_ce_unscaled: 0.0545 (0.1054)  class_error_unscaled: 0.0000 (7.5295)  loss_bbox_unscaled: 0.0218 (0.0226)  loss_giou_unscaled: 0.1887 (0.1833)  cardinality_error_unscaled: 0.5000 (1.5679)  loss_ce_0_unscaled: 0.1901 (0.2100)  loss_bbox_0_unscaled: 0.0275 (0.0301)  loss_giou_0_unscaled: 0.1972 (0.1975)  cardinality_error_0_unscaled: 3.5000 (6.0988)  loss_ce_1_unscaled: 0.1329 (0.1707)  loss_bbox_1_unscaled: 0.0255 (0.0263)  loss_giou_1_unscaled: 0.1874 (0.1800)  cardinality_error_1_unscaled: 2.0000 (4.6790)  loss_ce_2_unscaled: 0.1220 (0.1459)  loss_bbox_2_unscaled: 0.0247 (0.0240)  loss_giou_2_unscaled: 0.1830 (0.1750)  cardinality_error_2_unscaled: 1.5000 (2.9506)  loss_ce_3_unscaled: 0.0879 (0.1077)  loss_bbox_3_unscaled: 0.0231 (0.0231)  loss_giou_3_unscaled: 0.2005 (0.1792)  cardinality_error_3_unscaled: 1.0000 (2.1481)  loss_ce_4_unscaled: 0.0869 (0.1085)  loss_bbox_4_unscaled: 0.0225 (0.0227)  loss_giou_4_unscaled: 0.2017 (0.1777)  cardinality_error_4_unscaled: 0.5000 (1.6420)  time: 0.6728  data: 0.0101  max mem: 4284
# Epoch: [150]  [ 90/480]  eta: 0:04:18  lr: 0.000100  class_error: 20.00  loss: 4.0417 (3.7998)  loss_ce: 0.0765 (0.1058)  loss_bbox: 0.1057 (0.1121)  loss_giou: 0.4367 (0.3742)  loss_ce_0: 0.2245 (0.2049)  loss_bbox_0: 0.1377 (0.1507)  loss_giou_0: 0.3603 (0.3946)  loss_ce_1: 0.1820 (0.1693)  loss_bbox_1: 0.1227 (0.1305)  loss_giou_1: 0.3773 (0.3654)  loss_ce_2: 0.1270 (0.1428)  loss_bbox_2: 0.1234 (0.1198)  loss_giou_2: 0.3842 (0.3557)  loss_ce_3: 0.0879 (0.1080)  loss_bbox_3: 0.1155 (0.1154)  loss_giou_3: 0.3705 (0.3668)  loss_ce_4: 0.0869 (0.1070)  loss_bbox_4: 0.1015 (0.1122)  loss_giou_4: 0.4034 (0.3645)  loss_ce_unscaled: 0.0765 (0.1058)  class_error_unscaled: 0.0000 (7.5833)  loss_bbox_unscaled: 0.0211 (0.0224)  loss_giou_unscaled: 0.2183 (0.1871)  cardinality_error_unscaled: 1.5000 (1.6648)  loss_ce_0_unscaled: 0.2245 (0.2049)  loss_bbox_0_unscaled: 0.0275 (0.0301)  loss_giou_0_unscaled: 0.1801 (0.1973)  cardinality_error_0_unscaled: 4.0000 (6.0659)  loss_ce_1_unscaled: 0.1820 (0.1693)  loss_bbox_1_unscaled: 0.0245 (0.0261)  loss_giou_1_unscaled: 0.1887 (0.1827)  cardinality_error_1_unscaled: 3.5000 (4.8187)  loss_ce_2_unscaled: 0.1270 (0.1428)  loss_bbox_2_unscaled: 0.0247 (0.0240)  loss_giou_2_unscaled: 0.1921 (0.1779)  cardinality_error_2_unscaled: 1.5000 (3.0220)  loss_ce_3_unscaled: 0.0879 (0.1080)  loss_bbox_3_unscaled: 0.0231 (0.0231)  loss_giou_3_unscaled: 0.1852 (0.1834)  cardinality_error_3_unscaled: 1.5000 (2.2143)  loss_ce_4_unscaled: 0.0869 (0.1070)  loss_bbox_4_unscaled: 0.0203 (0.0224)  loss_giou_4_unscaled: 0.2017 (0.1822)  cardinality_error_4_unscaled: 1.0000 (1.7198)  time: 0.6414  data: 0.0095  max mem: 4284
# Epoch: [150]  [100/480]  eta: 0:04:11  lr: 0.000100  class_error: 0.00  loss: 2.7099 (3.6881)  loss_ce: 0.0314 (0.0991)  loss_bbox: 0.1047 (0.1135)  loss_giou: 0.2619 (0.3612)  loss_ce_0: 0.0790 (0.1935)  loss_bbox_0: 0.1413 (0.1519)  loss_giou_0: 0.2956 (0.3867)  loss_ce_1: 0.0429 (0.1576)  loss_bbox_1: 0.1219 (0.1301)  loss_giou_1: 0.3293 (0.3552)  loss_ce_2: 0.0399 (0.1338)  loss_bbox_2: 0.1246 (0.1201)  loss_giou_2: 0.3101 (0.3455)  loss_ce_3: 0.0330 (0.1024)  loss_bbox_3: 0.1154 (0.1160)  loss_giou_3: 0.2893 (0.3560)  loss_ce_4: 0.0287 (0.0994)  loss_bbox_4: 0.1019 (0.1133)  loss_giou_4: 0.2801 (0.3529)  loss_ce_unscaled: 0.0314 (0.0991)  class_error_unscaled: 0.0000 (6.9150)  loss_bbox_unscaled: 0.0209 (0.0227)  loss_giou_unscaled: 0.1309 (0.1806)  cardinality_error_unscaled: 0.5000 (1.6139)  loss_ce_0_unscaled: 0.0790 (0.1935)  loss_bbox_0_unscaled: 0.0283 (0.0304)  loss_giou_0_unscaled: 0.1478 (0.1934)  cardinality_error_0_unscaled: 2.5000 (5.8020)  loss_ce_1_unscaled: 0.0429 (0.1576)  loss_bbox_1_unscaled: 0.0244 (0.0260)  loss_giou_1_unscaled: 0.1646 (0.1776)  cardinality_error_1_unscaled: 1.5000 (4.5495)  loss_ce_2_unscaled: 0.0399 (0.1338)  loss_bbox_2_unscaled: 0.0249 (0.0240)  loss_giou_2_unscaled: 0.1550 (0.1727)  cardinality_error_2_unscaled: 1.0000 (2.8960)  loss_ce_3_unscaled: 0.0330 (0.1024)  loss_bbox_3_unscaled: 0.0231 (0.0232)  loss_giou_3_unscaled: 0.1446 (0.1780)  cardinality_error_3_unscaled: 0.5000 (2.1436)  loss_ce_4_unscaled: 0.0287 (0.0994)  loss_bbox_4_unscaled: 0.0204 (0.0227)  loss_giou_4_unscaled: 0.1401 (0.1764)  cardinality_error_4_unscaled: 0.5000 (1.6733)  time: 0.6518  data: 0.0093  max mem: 4284
# Epoch: [150]  [110/480]  eta: 0:04:03  lr: 0.000100  class_error: 0.00  loss: 3.1911 (3.7198)  loss_ce: 0.0163 (0.1005)  loss_bbox: 0.1067 (0.1133)  loss_giou: 0.3157 (0.3633)  loss_ce_0: 0.1198 (0.2004)  loss_bbox_0: 0.1466 (0.1511)  loss_giou_0: 0.3148 (0.3900)  loss_ce_1: 0.0600 (0.1611)  loss_bbox_1: 0.1219 (0.1304)  loss_giou_1: 0.3082 (0.3580)  loss_ce_2: 0.0445 (0.1367)  loss_bbox_2: 0.1094 (0.1196)  loss_giou_2: 0.2825 (0.3459)  loss_ce_3: 0.0330 (0.1031)  loss_bbox_3: 0.1132 (0.1157)  loss_giou_3: 0.3512 (0.3609)  loss_ce_4: 0.0162 (0.1033)  loss_bbox_4: 0.1099 (0.1129)  loss_giou_4: 0.2801 (0.3536)  loss_ce_unscaled: 0.0163 (0.1005)  class_error_unscaled: 0.0000 (6.8969)  loss_bbox_unscaled: 0.0213 (0.0227)  loss_giou_unscaled: 0.1578 (0.1816)  cardinality_error_unscaled: 0.5000 (1.7342)  loss_ce_0_unscaled: 0.1198 (0.2004)  loss_bbox_0_unscaled: 0.0293 (0.0302)  loss_giou_0_unscaled: 0.1574 (0.1950)  cardinality_error_0_unscaled: 3.5000 (5.6847)  loss_ce_1_unscaled: 0.0600 (0.1611)  loss_bbox_1_unscaled: 0.0244 (0.0261)  loss_giou_1_unscaled: 0.1541 (0.1790)  cardinality_error_1_unscaled: 2.0000 (4.6216)  loss_ce_2_unscaled: 0.0445 (0.1367)  loss_bbox_2_unscaled: 0.0219 (0.0239)  loss_giou_2_unscaled: 0.1413 (0.1730)  cardinality_error_2_unscaled: 0.5000 (3.0000)  loss_ce_3_unscaled: 0.0330 (0.1031)  loss_bbox_3_unscaled: 0.0226 (0.0231)  loss_giou_3_unscaled: 0.1756 (0.1804)  cardinality_error_3_unscaled: 0.5000 (2.2748)  loss_ce_4_unscaled: 0.0162 (0.1033)  loss_bbox_4_unscaled: 0.0220 (0.0226)  loss_giou_4_unscaled: 0.1401 (0.1768)  cardinality_error_4_unscaled: 0.5000 (1.7748)  time: 0.6476  data: 0.0090  max mem: 4284
# Epoch: [150]  [120/480]  eta: 0:03:56  lr: 0.000100  class_error: 0.00  loss: 3.5829 (3.6958)  loss_ce: 0.0187 (0.0974)  loss_bbox: 0.1069 (0.1140)  loss_giou: 0.3434 (0.3643)  loss_ce_0: 0.1693 (0.1956)  loss_bbox_0: 0.1466 (0.1510)  loss_giou_0: 0.3881 (0.3880)  loss_ce_1: 0.1122 (0.1569)  loss_bbox_1: 0.1148 (0.1299)  loss_giou_1: 0.3334 (0.3601)  loss_ce_2: 0.0549 (0.1337)  loss_bbox_2: 0.1138 (0.1198)  loss_giou_2: 0.3661 (0.3429)  loss_ce_3: 0.0253 (0.1007)  loss_bbox_3: 0.1105 (0.1158)  loss_giou_3: 0.3897 (0.3605)  loss_ce_4: 0.0319 (0.1003)  loss_bbox_4: 0.1048 (0.1129)  loss_giou_4: 0.3486 (0.3519)  loss_ce_unscaled: 0.0187 (0.0974)  class_error_unscaled: 0.0000 (6.7205)  loss_bbox_unscaled: 0.0214 (0.0228)  loss_giou_unscaled: 0.1717 (0.1822)  cardinality_error_unscaled: 0.5000 (1.6281)  loss_ce_0_unscaled: 0.1693 (0.1956)  loss_bbox_0_unscaled: 0.0293 (0.0302)  loss_giou_0_unscaled: 0.1940 (0.1940)  cardinality_error_0_unscaled: 3.5000 (5.5248)  loss_ce_1_unscaled: 0.1122 (0.1569)  loss_bbox_1_unscaled: 0.0230 (0.0260)  loss_giou_1_unscaled: 0.1667 (0.1800)  cardinality_error_1_unscaled: 3.0000 (4.4339)  loss_ce_2_unscaled: 0.0549 (0.1337)  loss_bbox_2_unscaled: 0.0228 (0.0240)  loss_giou_2_unscaled: 0.1830 (0.1715)  cardinality_error_2_unscaled: 1.0000 (2.8512)  loss_ce_3_unscaled: 0.0253 (0.1007)  loss_bbox_3_unscaled: 0.0221 (0.0232)  loss_giou_3_unscaled: 0.1949 (0.1802)  cardinality_error_3_unscaled: 0.5000 (2.1446)  loss_ce_4_unscaled: 0.0319 (0.1003)  loss_bbox_4_unscaled: 0.0210 (0.0226)  loss_giou_4_unscaled: 0.1743 (0.1760)  cardinality_error_4_unscaled: 0.5000 (1.6653)  time: 0.6379  data: 0.0097  max mem: 4284
# Epoch: [150]  [130/480]  eta: 0:03:48  lr: 0.000100  class_error: 16.67  loss: 3.4820 (3.7417)  loss_ce: 0.0287 (0.0996)  loss_bbox: 0.1085 (0.1161)  loss_giou: 0.3559 (0.3650)  loss_ce_0: 0.1553 (0.1958)  loss_bbox_0: 0.1480 (0.1535)  loss_giou_0: 0.3897 (0.3932)  loss_ce_1: 0.0657 (0.1607)  loss_bbox_1: 0.1250 (0.1320)  loss_giou_1: 0.3427 (0.3644)  loss_ce_2: 0.0548 (0.1344)  loss_bbox_2: 0.1193 (0.1221)  loss_giou_2: 0.3661 (0.3464)  loss_ce_3: 0.0253 (0.1023)  loss_bbox_3: 0.1105 (0.1171)  loss_giou_3: 0.3980 (0.3642)  loss_ce_4: 0.0317 (0.1012)  loss_bbox_4: 0.1021 (0.1153)  loss_giou_4: 0.3737 (0.3583)  loss_ce_unscaled: 0.0287 (0.0996)  class_error_unscaled: 0.0000 (7.0122)  loss_bbox_unscaled: 0.0217 (0.0232)  loss_giou_unscaled: 0.1779 (0.1825)  cardinality_error_unscaled: 0.5000 (1.6412)  loss_ce_0_unscaled: 0.1553 (0.1958)  loss_bbox_0_unscaled: 0.0296 (0.0307)  loss_giou_0_unscaled: 0.1949 (0.1966)  cardinality_error_0_unscaled: 5.0000 (5.6260)  loss_ce_1_unscaled: 0.0657 (0.1607)  loss_bbox_1_unscaled: 0.0250 (0.0264)  loss_giou_1_unscaled: 0.1714 (0.1822)  cardinality_error_1_unscaled: 2.5000 (4.5649)  loss_ce_2_unscaled: 0.0548 (0.1344)  loss_bbox_2_unscaled: 0.0239 (0.0244)  loss_giou_2_unscaled: 0.1830 (0.1732)  cardinality_error_2_unscaled: 1.0000 (2.9084)  loss_ce_3_unscaled: 0.0253 (0.1023)  loss_bbox_3_unscaled: 0.0221 (0.0234)  loss_giou_3_unscaled: 0.1990 (0.1821)  cardinality_error_3_unscaled: 0.5000 (2.1450)  loss_ce_4_unscaled: 0.0317 (0.1012)  loss_bbox_4_unscaled: 0.0204 (0.0231)  loss_giou_4_unscaled: 0.1869 (0.1792)  cardinality_error_4_unscaled: 0.5000 (1.6756)  time: 0.6157  data: 0.0095  max mem: 4284
# Epoch: [150]  [140/480]  eta: 0:03:42  lr: 0.000100  class_error: 0.00  loss: 3.2755 (3.7144)  loss_ce: 0.0877 (0.0982)  loss_bbox: 0.1007 (0.1153)  loss_giou: 0.2999 (0.3604)  loss_ce_0: 0.1242 (0.1942)  loss_bbox_0: 0.1431 (0.1523)  loss_giou_0: 0.3753 (0.3904)  loss_ce_1: 0.0702 (0.1594)  loss_bbox_1: 0.1256 (0.1312)  loss_giou_1: 0.3564 (0.3612)  loss_ce_2: 0.0511 (0.1332)  loss_bbox_2: 0.1128 (0.1216)  loss_giou_2: 0.2908 (0.3430)  loss_ce_3: 0.0413 (0.1017)  loss_bbox_3: 0.1147 (0.1172)  loss_giou_3: 0.3956 (0.3642)  loss_ce_4: 0.0388 (0.1023)  loss_bbox_4: 0.1014 (0.1145)  loss_giou_4: 0.3535 (0.3541)  loss_ce_unscaled: 0.0877 (0.0982)  class_error_unscaled: 0.0000 (6.9339)  loss_bbox_unscaled: 0.0201 (0.0231)  loss_giou_unscaled: 0.1500 (0.1802)  cardinality_error_unscaled: 0.5000 (1.5887)  loss_ce_0_unscaled: 0.1242 (0.1942)  loss_bbox_0_unscaled: 0.0286 (0.0305)  loss_giou_0_unscaled: 0.1877 (0.1952)  cardinality_error_0_unscaled: 5.0000 (5.6986)  loss_ce_1_unscaled: 0.0702 (0.1594)  loss_bbox_1_unscaled: 0.0251 (0.0262)  loss_giou_1_unscaled: 0.1782 (0.1806)  cardinality_error_1_unscaled: 2.0000 (4.4716)  loss_ce_2_unscaled: 0.0511 (0.1332)  loss_bbox_2_unscaled: 0.0226 (0.0243)  loss_giou_2_unscaled: 0.1454 (0.1715)  cardinality_error_2_unscaled: 1.0000 (2.8546)  loss_ce_3_unscaled: 0.0413 (0.1017)  loss_bbox_3_unscaled: 0.0229 (0.0234)  loss_giou_3_unscaled: 0.1978 (0.1821)  cardinality_error_3_unscaled: 0.5000 (2.0887)  loss_ce_4_unscaled: 0.0388 (0.1023)  loss_bbox_4_unscaled: 0.0203 (0.0229)  loss_giou_4_unscaled: 0.1767 (0.1771)  cardinality_error_4_unscaled: 0.5000 (1.6348)  time: 0.6378  data: 0.0092  max mem: 4284
# Epoch: [150]  [150/480]  eta: 0:03:35  lr: 0.000100  class_error: 10.00  loss: 3.5271 (3.7527)  loss_ce: 0.0985 (0.1025)  loss_bbox: 0.0898 (0.1140)  loss_giou: 0.3166 (0.3628)  loss_ce_0: 0.2343 (0.2016)  loss_bbox_0: 0.1334 (0.1512)  loss_giou_0: 0.3447 (0.3925)  loss_ce_1: 0.2044 (0.1667)  loss_bbox_1: 0.1068 (0.1293)  loss_giou_1: 0.3606 (0.3621)  loss_ce_2: 0.1251 (0.1371)  loss_bbox_2: 0.1063 (0.1204)  loss_giou_2: 0.2908 (0.3452)  loss_ce_3: 0.0918 (0.1063)  loss_bbox_3: 0.0983 (0.1161)  loss_giou_3: 0.3833 (0.3671)  loss_ce_4: 0.0971 (0.1070)  loss_bbox_4: 0.0949 (0.1132)  loss_giou_4: 0.3526 (0.3575)  loss_ce_unscaled: 0.0985 (0.1025)  class_error_unscaled: 0.0000 (7.1571)  loss_bbox_unscaled: 0.0180 (0.0228)  loss_giou_unscaled: 0.1583 (0.1814)  cardinality_error_unscaled: 1.0000 (1.6921)  loss_ce_0_unscaled: 0.2343 (0.2016)  loss_bbox_0_unscaled: 0.0267 (0.0302)  loss_giou_0_unscaled: 0.1724 (0.1963)  cardinality_error_0_unscaled: 5.0000 (5.8079)  loss_ce_1_unscaled: 0.2044 (0.1667)  loss_bbox_1_unscaled: 0.0214 (0.0259)  loss_giou_1_unscaled: 0.1803 (0.1811)  cardinality_error_1_unscaled: 3.5000 (4.6126)  loss_ce_2_unscaled: 0.1251 (0.1371)  loss_bbox_2_unscaled: 0.0213 (0.0241)  loss_giou_2_unscaled: 0.1454 (0.1726)  cardinality_error_2_unscaled: 2.0000 (2.9503)  loss_ce_3_unscaled: 0.0918 (0.1063)  loss_bbox_3_unscaled: 0.0197 (0.0232)  loss_giou_3_unscaled: 0.1917 (0.1836)  cardinality_error_3_unscaled: 1.0000 (2.1457)  loss_ce_4_unscaled: 0.0971 (0.1070)  loss_bbox_4_unscaled: 0.0190 (0.0226)  loss_giou_4_unscaled: 0.1763 (0.1788)  cardinality_error_4_unscaled: 1.0000 (1.7185)  time: 0.6631  data: 0.0097  max mem: 4284
# Epoch: [150]  [160/480]  eta: 0:03:30  lr: 0.000100  class_error: 0.00  loss: 3.3754 (3.7156)  loss_ce: 0.0985 (0.1014)  loss_bbox: 0.0884 (0.1138)  loss_giou: 0.3015 (0.3590)  loss_ce_0: 0.2107 (0.1996)  loss_bbox_0: 0.1231 (0.1503)  loss_giou_0: 0.3316 (0.3906)  loss_ce_1: 0.1851 (0.1640)  loss_bbox_1: 0.1068 (0.1289)  loss_giou_1: 0.3017 (0.3583)  loss_ce_2: 0.1210 (0.1347)  loss_bbox_2: 0.1000 (0.1199)  loss_giou_2: 0.2897 (0.3417)  loss_ce_3: 0.0873 (0.1041)  loss_bbox_3: 0.0931 (0.1156)  loss_giou_3: 0.3149 (0.3616)  loss_ce_4: 0.0884 (0.1056)  loss_bbox_4: 0.0917 (0.1128)  loss_giou_4: 0.3398 (0.3536)  loss_ce_unscaled: 0.0985 (0.1014)  class_error_unscaled: 0.0000 (7.0128)  loss_bbox_unscaled: 0.0177 (0.0228)  loss_giou_unscaled: 0.1508 (0.1795)  cardinality_error_unscaled: 1.5000 (1.7578)  loss_ce_0_unscaled: 0.2107 (0.1996)  loss_bbox_0_unscaled: 0.0246 (0.0301)  loss_giou_0_unscaled: 0.1658 (0.1953)  cardinality_error_0_unscaled: 4.5000 (5.9193)  loss_ce_1_unscaled: 0.1851 (0.1640)  loss_bbox_1_unscaled: 0.0214 (0.0258)  loss_giou_1_unscaled: 0.1508 (0.1791)  cardinality_error_1_unscaled: 3.0000 (4.6118)  loss_ce_2_unscaled: 0.1210 (0.1347)  loss_bbox_2_unscaled: 0.0200 (0.0240)  loss_giou_2_unscaled: 0.1449 (0.1709)  cardinality_error_2_unscaled: 2.5000 (2.9689)  loss_ce_3_unscaled: 0.0873 (0.1041)  loss_bbox_3_unscaled: 0.0186 (0.0231)  loss_giou_3_unscaled: 0.1574 (0.1808)  cardinality_error_3_unscaled: 1.5000 (2.1615)  loss_ce_4_unscaled: 0.0884 (0.1056)  loss_bbox_4_unscaled: 0.0183 (0.0226)  loss_giou_4_unscaled: 0.1699 (0.1768)  cardinality_error_4_unscaled: 1.5000 (1.7702)  time: 0.6732  data: 0.0095  max mem: 4284
# Epoch: [150]  [170/480]  eta: 0:03:24  lr: 0.000100  class_error: 0.00  loss: 2.4575 (3.6903)  loss_ce: 0.0287 (0.0993)  loss_bbox: 0.1002 (0.1139)  loss_giou: 0.2449 (0.3538)  loss_ce_0: 0.0891 (0.1960)  loss_bbox_0: 0.1411 (0.1522)  loss_giou_0: 0.3074 (0.3896)  loss_ce_1: 0.0715 (0.1602)  loss_bbox_1: 0.1124 (0.1293)  loss_giou_1: 0.2665 (0.3575)  loss_ce_2: 0.0350 (0.1323)  loss_bbox_2: 0.1093 (0.1202)  loss_giou_2: 0.2533 (0.3419)  loss_ce_3: 0.0221 (0.1029)  loss_bbox_3: 0.1020 (0.1157)  loss_giou_3: 0.2498 (0.3596)  loss_ce_4: 0.0194 (0.1030)  loss_bbox_4: 0.0955 (0.1124)  loss_giou_4: 0.2312 (0.3505)  loss_ce_unscaled: 0.0287 (0.0993)  class_error_unscaled: 0.0000 (6.7001)  loss_bbox_unscaled: 0.0200 (0.0228)  loss_giou_unscaled: 0.1225 (0.1769)  cardinality_error_unscaled: 0.5000 (1.8333)  loss_ce_0_unscaled: 0.0891 (0.1960)  loss_bbox_0_unscaled: 0.0282 (0.0304)  loss_giou_0_unscaled: 0.1537 (0.1948)  cardinality_error_0_unscaled: 3.0000 (5.8509)  loss_ce_1_unscaled: 0.0715 (0.1602)  loss_bbox_1_unscaled: 0.0225 (0.0259)  loss_giou_1_unscaled: 0.1332 (0.1787)  cardinality_error_1_unscaled: 1.5000 (4.5819)  loss_ce_2_unscaled: 0.0350 (0.1323)  loss_bbox_2_unscaled: 0.0219 (0.0240)  loss_giou_2_unscaled: 0.1267 (0.1709)  cardinality_error_2_unscaled: 1.0000 (2.9649)  loss_ce_3_unscaled: 0.0221 (0.1029)  loss_bbox_3_unscaled: 0.0204 (0.0231)  loss_giou_3_unscaled: 0.1249 (0.1798)  cardinality_error_3_unscaled: 0.5000 (2.2135)  loss_ce_4_unscaled: 0.0194 (0.1030)  loss_bbox_4_unscaled: 0.0191 (0.0225)  loss_giou_4_unscaled: 0.1156 (0.1752)  cardinality_error_4_unscaled: 0.5000 (1.8480)  time: 0.7059  data: 0.0094  max mem: 4284
# Epoch: [150]  [180/480]  eta: 0:03:18  lr: 0.000100  class_error: 0.00  loss: 3.4421 (3.7081)  loss_ce: 0.0208 (0.0990)  loss_bbox: 0.1136 (0.1155)  loss_giou: 0.3018 (0.3558)  loss_ce_0: 0.0952 (0.1948)  loss_bbox_0: 0.1671 (0.1531)  loss_giou_0: 0.3679 (0.3926)  loss_ce_1: 0.0986 (0.1617)  loss_bbox_1: 0.1173 (0.1299)  loss_giou_1: 0.3096 (0.3575)  loss_ce_2: 0.0680 (0.1337)  loss_bbox_2: 0.1147 (0.1210)  loss_giou_2: 0.3330 (0.3437)  loss_ce_3: 0.0354 (0.1047)  loss_bbox_3: 0.1135 (0.1166)  loss_giou_3: 0.3176 (0.3604)  loss_ce_4: 0.0194 (0.1037)  loss_bbox_4: 0.1089 (0.1139)  loss_giou_4: 0.2972 (0.3505)  loss_ce_unscaled: 0.0208 (0.0990)  class_error_unscaled: 0.0000 (6.6299)  loss_bbox_unscaled: 0.0227 (0.0231)  loss_giou_unscaled: 0.1509 (0.1779)  cardinality_error_unscaled: 0.5000 (1.7901)  loss_ce_0_unscaled: 0.0952 (0.1948)  loss_bbox_0_unscaled: 0.0334 (0.0306)  loss_giou_0_unscaled: 0.1839 (0.1963)  cardinality_error_0_unscaled: 3.0000 (5.7265)  loss_ce_1_unscaled: 0.0986 (0.1617)  loss_bbox_1_unscaled: 0.0235 (0.0260)  loss_giou_1_unscaled: 0.1548 (0.1787)  cardinality_error_1_unscaled: 1.5000 (4.4475)  loss_ce_2_unscaled: 0.0680 (0.1337)  loss_bbox_2_unscaled: 0.0229 (0.0242)  loss_giou_2_unscaled: 0.1665 (0.1719)  cardinality_error_2_unscaled: 1.0000 (2.9033)  loss_ce_3_unscaled: 0.0354 (0.1047)  loss_bbox_3_unscaled: 0.0227 (0.0233)  loss_giou_3_unscaled: 0.1588 (0.1802)  cardinality_error_3_unscaled: 0.5000 (2.1740)  loss_ce_4_unscaled: 0.0194 (0.1037)  loss_bbox_4_unscaled: 0.0218 (0.0228)  loss_giou_4_unscaled: 0.1486 (0.1753)  cardinality_error_4_unscaled: 0.5000 (1.8066)  time: 0.6901  data: 0.0098  max mem: 4284
# Epoch: [150]  [190/480]  eta: 0:03:11  lr: 0.000100  class_error: 0.00  loss: 4.2794 (3.7464)  loss_ce: 0.0387 (0.0986)  loss_bbox: 0.1329 (0.1165)  loss_giou: 0.4341 (0.3641)  loss_ce_0: 0.1491 (0.1953)  loss_bbox_0: 0.1770 (0.1547)  loss_giou_0: 0.4515 (0.3955)  loss_ce_1: 0.1120 (0.1629)  loss_bbox_1: 0.1491 (0.1317)  loss_giou_1: 0.3782 (0.3603)  loss_ce_2: 0.1264 (0.1340)  loss_bbox_2: 0.1358 (0.1228)  loss_giou_2: 0.3750 (0.3478)  loss_ce_3: 0.0706 (0.1047)  loss_bbox_3: 0.1377 (0.1180)  loss_giou_3: 0.3640 (0.3640)  loss_ce_4: 0.0337 (0.1038)  loss_bbox_4: 0.1299 (0.1151)  loss_giou_4: 0.3653 (0.3567)  loss_ce_unscaled: 0.0387 (0.0986)  class_error_unscaled: 0.0000 (6.5412)  loss_bbox_unscaled: 0.0266 (0.0233)  loss_giou_unscaled: 0.2170 (0.1821)  cardinality_error_unscaled: 0.5000 (1.7801)  loss_ce_0_unscaled: 0.1491 (0.1953)  loss_bbox_0_unscaled: 0.0354 (0.0309)  loss_giou_0_unscaled: 0.2257 (0.1978)  cardinality_error_0_unscaled: 3.0000 (5.6597)  loss_ce_1_unscaled: 0.1120 (0.1629)  loss_bbox_1_unscaled: 0.0298 (0.0263)  loss_giou_1_unscaled: 0.1891 (0.1801)  cardinality_error_1_unscaled: 2.0000 (4.3953)  loss_ce_2_unscaled: 0.1264 (0.1340)  loss_bbox_2_unscaled: 0.0272 (0.0246)  loss_giou_2_unscaled: 0.1875 (0.1739)  cardinality_error_2_unscaled: 2.0000 (2.9005)  loss_ce_3_unscaled: 0.0706 (0.1047)  loss_bbox_3_unscaled: 0.0275 (0.0236)  loss_giou_3_unscaled: 0.1820 (0.1820)  cardinality_error_3_unscaled: 1.0000 (2.1597)  loss_ce_4_unscaled: 0.0337 (0.1038)  loss_bbox_4_unscaled: 0.0260 (0.0230)  loss_giou_4_unscaled: 0.1826 (0.1784)  cardinality_error_4_unscaled: 0.5000 (1.7958)  time: 0.6718  data: 0.0099  max mem: 4284
# Epoch: [150]  [200/480]  eta: 0:03:05  lr: 0.000100  class_error: 11.11  loss: 4.2794 (3.7661)  loss_ce: 0.0808 (0.1006)  loss_bbox: 0.1315 (0.1179)  loss_giou: 0.3846 (0.3639)  loss_ce_0: 0.1906 (0.1944)  loss_bbox_0: 0.1770 (0.1558)  loss_giou_0: 0.4527 (0.3989)  loss_ce_1: 0.1251 (0.1627)  loss_bbox_1: 0.1507 (0.1326)  loss_giou_1: 0.4127 (0.3637)  loss_ce_2: 0.0798 (0.1333)  loss_bbox_2: 0.1358 (0.1238)  loss_giou_2: 0.3588 (0.3500)  loss_ce_3: 0.0941 (0.1058)  loss_bbox_3: 0.1341 (0.1196)  loss_giou_3: 0.3546 (0.3647)  loss_ce_4: 0.0878 (0.1044)  loss_bbox_4: 0.1267 (0.1165)  loss_giou_4: 0.3847 (0.3575)  loss_ce_unscaled: 0.0808 (0.1006)  class_error_unscaled: 0.0000 (6.9291)  loss_bbox_unscaled: 0.0263 (0.0236)  loss_giou_unscaled: 0.1923 (0.1820)  cardinality_error_unscaled: 1.0000 (1.7711)  loss_ce_0_unscaled: 0.1906 (0.1944)  loss_bbox_0_unscaled: 0.0354 (0.0312)  loss_giou_0_unscaled: 0.2263 (0.1995)  cardinality_error_0_unscaled: 4.0000 (5.6219)  loss_ce_1_unscaled: 0.1251 (0.1627)  loss_bbox_1_unscaled: 0.0301 (0.0265)  loss_giou_1_unscaled: 0.2063 (0.1818)  cardinality_error_1_unscaled: 2.5000 (4.3881)  loss_ce_2_unscaled: 0.0798 (0.1333)  loss_bbox_2_unscaled: 0.0272 (0.0248)  loss_giou_2_unscaled: 0.1794 (0.1750)  cardinality_error_2_unscaled: 2.0000 (2.9030)  loss_ce_3_unscaled: 0.0941 (0.1058)  loss_bbox_3_unscaled: 0.0268 (0.0239)  loss_giou_3_unscaled: 0.1773 (0.1824)  cardinality_error_3_unscaled: 1.0000 (2.1443)  loss_ce_4_unscaled: 0.0878 (0.1044)  loss_bbox_4_unscaled: 0.0253 (0.0233)  loss_giou_4_unscaled: 0.1923 (0.1787)  cardinality_error_4_unscaled: 1.0000 (1.7836)  time: 0.6783  data: 0.0104  max mem: 4284
# Epoch: [150]  [210/480]  eta: 0:02:58  lr: 0.000100  class_error: 0.00  loss: 3.2877 (3.7576)  loss_ce: 0.0648 (0.0993)  loss_bbox: 0.1193 (0.1190)  loss_giou: 0.3030 (0.3626)  loss_ce_0: 0.1906 (0.1939)  loss_bbox_0: 0.1615 (0.1567)  loss_giou_0: 0.3812 (0.3971)  loss_ce_1: 0.1185 (0.1611)  loss_bbox_1: 0.1344 (0.1332)  loss_giou_1: 0.3281 (0.3623)  loss_ce_2: 0.0727 (0.1325)  loss_bbox_2: 0.1270 (0.1255)  loss_giou_2: 0.3441 (0.3490)  loss_ce_3: 0.0621 (0.1043)  loss_bbox_3: 0.1299 (0.1209)  loss_giou_3: 0.2906 (0.3638)  loss_ce_4: 0.0551 (0.1029)  loss_bbox_4: 0.1245 (0.1176)  loss_giou_4: 0.2834 (0.3558)  loss_ce_unscaled: 0.0648 (0.0993)  class_error_unscaled: 0.0000 (6.7685)  loss_bbox_unscaled: 0.0239 (0.0238)  loss_giou_unscaled: 0.1515 (0.1813)  cardinality_error_unscaled: 1.0000 (1.7488)  loss_ce_0_unscaled: 0.1906 (0.1939)  loss_bbox_0_unscaled: 0.0323 (0.0313)  loss_giou_0_unscaled: 0.1906 (0.1985)  cardinality_error_0_unscaled: 4.5000 (5.6209)  loss_ce_1_unscaled: 0.1185 (0.1611)  loss_bbox_1_unscaled: 0.0269 (0.0266)  loss_giou_1_unscaled: 0.1640 (0.1812)  cardinality_error_1_unscaled: 2.5000 (4.3791)  loss_ce_2_unscaled: 0.0727 (0.1325)  loss_bbox_2_unscaled: 0.0254 (0.0251)  loss_giou_2_unscaled: 0.1720 (0.1745)  cardinality_error_2_unscaled: 2.5000 (2.8886)  loss_ce_3_unscaled: 0.0621 (0.1043)  loss_bbox_3_unscaled: 0.0260 (0.0242)  loss_giou_3_unscaled: 0.1453 (0.1819)  cardinality_error_3_unscaled: 1.0000 (2.1161)  loss_ce_4_unscaled: 0.0551 (0.1029)  loss_bbox_4_unscaled: 0.0249 (0.0235)  loss_giou_4_unscaled: 0.1417 (0.1779)  cardinality_error_4_unscaled: 1.0000 (1.7536)  time: 0.6735  data: 0.0103  max mem: 4284
# Epoch: [150]  [220/480]  eta: 0:02:52  lr: 0.000100  class_error: 14.29  loss: 3.1302 (3.7670)  loss_ce: 0.0455 (0.0996)  loss_bbox: 0.1153 (0.1194)  loss_giou: 0.2813 (0.3637)  loss_ce_0: 0.1393 (0.1939)  loss_bbox_0: 0.1615 (0.1569)  loss_giou_0: 0.3812 (0.3993)  loss_ce_1: 0.0768 (0.1599)  loss_bbox_1: 0.1245 (0.1335)  loss_giou_1: 0.3183 (0.3636)  loss_ce_2: 0.0507 (0.1325)  loss_bbox_2: 0.1241 (0.1251)  loss_giou_2: 0.3293 (0.3499)  loss_ce_3: 0.0621 (0.1045)  loss_bbox_3: 0.1146 (0.1213)  loss_giou_3: 0.2934 (0.3652)  loss_ce_4: 0.0386 (0.1024)  loss_bbox_4: 0.1123 (0.1181)  loss_giou_4: 0.2834 (0.3581)  loss_ce_unscaled: 0.0455 (0.0996)  class_error_unscaled: 0.0000 (6.8185)  loss_bbox_unscaled: 0.0231 (0.0239)  loss_giou_unscaled: 0.1407 (0.1819)  cardinality_error_unscaled: 0.5000 (1.7602)  loss_ce_0_unscaled: 0.1393 (0.1939)  loss_bbox_0_unscaled: 0.0323 (0.0314)  loss_giou_0_unscaled: 0.1906 (0.1996)  cardinality_error_0_unscaled: 2.5000 (5.6222)  loss_ce_1_unscaled: 0.0768 (0.1599)  loss_bbox_1_unscaled: 0.0249 (0.0267)  loss_giou_1_unscaled: 0.1592 (0.1818)  cardinality_error_1_unscaled: 2.0000 (4.3778)  loss_ce_2_unscaled: 0.0507 (0.1325)  loss_bbox_2_unscaled: 0.0248 (0.0250)  loss_giou_2_unscaled: 0.1646 (0.1750)  cardinality_error_2_unscaled: 1.5000 (2.9050)  loss_ce_3_unscaled: 0.0621 (0.1045)  loss_bbox_3_unscaled: 0.0229 (0.0243)  loss_giou_3_unscaled: 0.1467 (0.1826)  cardinality_error_3_unscaled: 0.5000 (2.1154)  loss_ce_4_unscaled: 0.0386 (0.1024)  loss_bbox_4_unscaled: 0.0225 (0.0236)  loss_giou_4_unscaled: 0.1417 (0.1791)  cardinality_error_4_unscaled: 0.5000 (1.7443)  time: 0.6773  data: 0.0095  max mem: 4284
# Epoch: [150]  [230/480]  eta: 0:02:46  lr: 0.000100  class_error: 0.00  loss: 3.3785 (3.7533)  loss_ce: 0.0657 (0.0985)  loss_bbox: 0.1072 (0.1195)  loss_giou: 0.3179 (0.3633)  loss_ce_0: 0.1393 (0.1922)  loss_bbox_0: 0.1392 (0.1557)  loss_giou_0: 0.3187 (0.3955)  loss_ce_1: 0.0754 (0.1573)  loss_bbox_1: 0.1216 (0.1336)  loss_giou_1: 0.2681 (0.3637)  loss_ce_2: 0.1007 (0.1321)  loss_bbox_2: 0.1085 (0.1250)  loss_giou_2: 0.3106 (0.3483)  loss_ce_3: 0.0867 (0.1039)  loss_bbox_3: 0.1137 (0.1214)  loss_giou_3: 0.3397 (0.3651)  loss_ce_4: 0.0670 (0.1011)  loss_bbox_4: 0.1097 (0.1183)  loss_giou_4: 0.3497 (0.3590)  loss_ce_unscaled: 0.0657 (0.0985)  class_error_unscaled: 0.0000 (6.6640)  loss_bbox_unscaled: 0.0214 (0.0239)  loss_giou_unscaled: 0.1589 (0.1816)  cardinality_error_unscaled: 0.5000 (1.7294)  loss_ce_0_unscaled: 0.1393 (0.1922)  loss_bbox_0_unscaled: 0.0278 (0.0311)  loss_giou_0_unscaled: 0.1593 (0.1977)  cardinality_error_0_unscaled: 2.5000 (5.5216)  loss_ce_1_unscaled: 0.0754 (0.1573)  loss_bbox_1_unscaled: 0.0243 (0.0267)  loss_giou_1_unscaled: 0.1340 (0.1818)  cardinality_error_1_unscaled: 1.5000 (4.2576)  loss_ce_2_unscaled: 0.1007 (0.1321)  loss_bbox_2_unscaled: 0.0217 (0.0250)  loss_giou_2_unscaled: 0.1553 (0.1741)  cardinality_error_2_unscaled: 1.0000 (2.8593)  loss_ce_3_unscaled: 0.0867 (0.1039)  loss_bbox_3_unscaled: 0.0227 (0.0243)  loss_giou_3_unscaled: 0.1698 (0.1826)  cardinality_error_3_unscaled: 0.5000 (2.0844)  loss_ce_4_unscaled: 0.0670 (0.1011)  loss_bbox_4_unscaled: 0.0219 (0.0237)  loss_giou_4_unscaled: 0.1749 (0.1795)  cardinality_error_4_unscaled: 0.5000 (1.7186)  time: 0.6809  data: 0.0100  max mem: 4284
# Epoch: [150]  [240/480]  eta: 0:02:39  lr: 0.000100  class_error: 6.82  loss: 3.8092 (3.8149)  loss_ce: 0.0816 (0.1008)  loss_bbox: 0.1231 (0.1210)  loss_giou: 0.4064 (0.3703)  loss_ce_0: 0.1684 (0.1945)  loss_bbox_0: 0.1392 (0.1581)  loss_giou_0: 0.3226 (0.4017)  loss_ce_1: 0.1288 (0.1599)  loss_bbox_1: 0.1285 (0.1355)  loss_giou_1: 0.3761 (0.3684)  loss_ce_2: 0.1351 (0.1356)  loss_bbox_2: 0.1207 (0.1265)  loss_giou_2: 0.3120 (0.3528)  loss_ce_3: 0.0989 (0.1058)  loss_bbox_3: 0.1336 (0.1228)  loss_giou_3: 0.3397 (0.3711)  loss_ce_4: 0.0685 (0.1030)  loss_bbox_4: 0.1252 (0.1203)  loss_giou_4: 0.4040 (0.3669)  loss_ce_unscaled: 0.0816 (0.1008)  class_error_unscaled: 0.0000 (6.9609)  loss_bbox_unscaled: 0.0246 (0.0242)  loss_giou_unscaled: 0.2032 (0.1851)  cardinality_error_unscaled: 1.0000 (1.8423)  loss_ce_0_unscaled: 0.1684 (0.1945)  loss_bbox_0_unscaled: 0.0278 (0.0316)  loss_giou_0_unscaled: 0.1613 (0.2009)  cardinality_error_0_unscaled: 3.0000 (5.6452)  loss_ce_1_unscaled: 0.1288 (0.1599)  loss_bbox_1_unscaled: 0.0257 (0.0271)  loss_giou_1_unscaled: 0.1881 (0.1842)  cardinality_error_1_unscaled: 2.0000 (4.4066)  loss_ce_2_unscaled: 0.1351 (0.1356)  loss_bbox_2_unscaled: 0.0241 (0.0253)  loss_giou_2_unscaled: 0.1560 (0.1764)  cardinality_error_2_unscaled: 2.0000 (2.9730)  loss_ce_3_unscaled: 0.0989 (0.1058)  loss_bbox_3_unscaled: 0.0267 (0.0246)  loss_giou_3_unscaled: 0.1698 (0.1855)  cardinality_error_3_unscaled: 1.5000 (2.1867)  loss_ce_4_unscaled: 0.0685 (0.1030)  loss_bbox_4_unscaled: 0.0250 (0.0241)  loss_giou_4_unscaled: 0.2020 (0.1834)  cardinality_error_4_unscaled: 1.0000 (1.8237)  time: 0.7015  data: 0.0103  max mem: 4284
# Epoch: [150]  [250/480]  eta: 0:02:33  lr: 0.000100  class_error: 0.00  loss: 3.8933 (3.8139)  loss_ce: 0.0797 (0.0999)  loss_bbox: 0.1256 (0.1211)  loss_giou: 0.3490 (0.3695)  loss_ce_0: 0.2252 (0.1948)  loss_bbox_0: 0.1886 (0.1584)  loss_giou_0: 0.4477 (0.4031)  loss_ce_1: 0.1303 (0.1588)  loss_bbox_1: 0.1402 (0.1353)  loss_giou_1: 0.3853 (0.3690)  loss_ce_2: 0.1148 (0.1341)  loss_bbox_2: 0.1321 (0.1267)  loss_giou_2: 0.3693 (0.3553)  loss_ce_3: 0.0737 (0.1052)  loss_bbox_3: 0.1290 (0.1228)  loss_giou_3: 0.3219 (0.3710)  loss_ce_4: 0.0685 (0.1022)  loss_bbox_4: 0.1288 (0.1205)  loss_giou_4: 0.3525 (0.3662)  loss_ce_unscaled: 0.0797 (0.0999)  class_error_unscaled: 0.0000 (6.8771)  loss_bbox_unscaled: 0.0251 (0.0242)  loss_giou_unscaled: 0.1745 (0.1848)  cardinality_error_unscaled: 1.5000 (1.8386)  loss_ce_0_unscaled: 0.2252 (0.1948)  loss_bbox_0_unscaled: 0.0377 (0.0317)  loss_giou_0_unscaled: 0.2238 (0.2015)  cardinality_error_0_unscaled: 5.5000 (5.7092)  loss_ce_1_unscaled: 0.1303 (0.1588)  loss_bbox_1_unscaled: 0.0280 (0.0271)  loss_giou_1_unscaled: 0.1926 (0.1845)  cardinality_error_1_unscaled: 3.5000 (4.4143)  loss_ce_2_unscaled: 0.1148 (0.1341)  loss_bbox_2_unscaled: 0.0264 (0.0253)  loss_giou_2_unscaled: 0.1847 (0.1776)  cardinality_error_2_unscaled: 2.0000 (2.9641)  loss_ce_3_unscaled: 0.0737 (0.1052)  loss_bbox_3_unscaled: 0.0258 (0.0246)  loss_giou_3_unscaled: 0.1610 (0.1855)  cardinality_error_3_unscaled: 1.5000 (2.1554)  loss_ce_4_unscaled: 0.0685 (0.1022)  loss_bbox_4_unscaled: 0.0258 (0.0241)  loss_giou_4_unscaled: 0.1762 (0.1831)  cardinality_error_4_unscaled: 2.0000 (1.8167)  time: 0.7099  data: 0.0097  max mem: 4284
# Epoch: [150]  [260/480]  eta: 0:02:27  lr: 0.000100  class_error: 27.27  loss: 3.8933 (3.8441)  loss_ce: 0.0891 (0.1029)  loss_bbox: 0.1132 (0.1206)  loss_giou: 0.3443 (0.3713)  loss_ce_0: 0.2791 (0.2003)  loss_bbox_0: 0.1605 (0.1581)  loss_giou_0: 0.4364 (0.4050)  loss_ce_1: 0.1667 (0.1622)  loss_bbox_1: 0.1223 (0.1349)  loss_giou_1: 0.3856 (0.3707)  loss_ce_2: 0.1148 (0.1368)  loss_bbox_2: 0.1246 (0.1267)  loss_giou_2: 0.3705 (0.3574)  loss_ce_3: 0.0860 (0.1085)  loss_bbox_3: 0.1166 (0.1226)  loss_giou_3: 0.3822 (0.3724)  loss_ce_4: 0.0898 (0.1049)  loss_bbox_4: 0.1054 (0.1200)  loss_giou_4: 0.3440 (0.3689)  loss_ce_unscaled: 0.0891 (0.1029)  class_error_unscaled: 0.0000 (7.0873)  loss_bbox_unscaled: 0.0226 (0.0241)  loss_giou_unscaled: 0.1721 (0.1857)  cardinality_error_unscaled: 2.0000 (1.9693)  loss_ce_0_unscaled: 0.2791 (0.2003)  loss_bbox_0_unscaled: 0.0321 (0.0316)  loss_giou_0_unscaled: 0.2182 (0.2025)  cardinality_error_0_unscaled: 7.0000 (5.9042)  loss_ce_1_unscaled: 0.1667 (0.1622)  loss_bbox_1_unscaled: 0.0245 (0.0270)  loss_giou_1_unscaled: 0.1928 (0.1853)  cardinality_error_1_unscaled: 5.0000 (4.5996)  loss_ce_2_unscaled: 0.1148 (0.1368)  loss_bbox_2_unscaled: 0.0249 (0.0253)  loss_giou_2_unscaled: 0.1853 (0.1787)  cardinality_error_2_unscaled: 2.5000 (3.1149)  loss_ce_3_unscaled: 0.0860 (0.1085)  loss_bbox_3_unscaled: 0.0233 (0.0245)  loss_giou_3_unscaled: 0.1911 (0.1862)  cardinality_error_3_unscaled: 1.5000 (2.2663)  loss_ce_4_unscaled: 0.0898 (0.1049)  loss_bbox_4_unscaled: 0.0211 (0.0240)  loss_giou_4_unscaled: 0.1720 (0.1844)  cardinality_error_4_unscaled: 2.0000 (1.9157)  time: 0.6951  data: 0.0095  max mem: 4284
# Epoch: [150]  [270/480]  eta: 0:02:20  lr: 0.000100  class_error: 0.00  loss: 3.9725 (3.8521)  loss_ce: 0.0891 (0.1022)  loss_bbox: 0.1110 (0.1211)  loss_giou: 0.3863 (0.3737)  loss_ce_0: 0.2261 (0.1990)  loss_bbox_0: 0.1499 (0.1579)  loss_giou_0: 0.3938 (0.4073)  loss_ce_1: 0.1881 (0.1616)  loss_bbox_1: 0.1292 (0.1355)  loss_giou_1: 0.3649 (0.3713)  loss_ce_2: 0.0795 (0.1356)  loss_bbox_2: 0.1246 (0.1271)  loss_giou_2: 0.3903 (0.3590)  loss_ce_3: 0.0841 (0.1082)  loss_bbox_3: 0.1171 (0.1226)  loss_giou_3: 0.4083 (0.3744)  loss_ce_4: 0.0778 (0.1042)  loss_bbox_4: 0.1054 (0.1204)  loss_giou_4: 0.4005 (0.3711)  loss_ce_unscaled: 0.0891 (0.1022)  class_error_unscaled: 0.0000 (6.9181)  loss_bbox_unscaled: 0.0222 (0.0242)  loss_giou_unscaled: 0.1932 (0.1869)  cardinality_error_unscaled: 1.5000 (2.0111)  loss_ce_0_unscaled: 0.2261 (0.1990)  loss_bbox_0_unscaled: 0.0300 (0.0316)  loss_giou_0_unscaled: 0.1969 (0.2037)  cardinality_error_0_unscaled: 7.5000 (5.9982)  loss_ce_1_unscaled: 0.1881 (0.1616)  loss_bbox_1_unscaled: 0.0258 (0.0271)  loss_giou_1_unscaled: 0.1825 (0.1856)  cardinality_error_1_unscaled: 5.0000 (4.6919)  loss_ce_2_unscaled: 0.0795 (0.1356)  loss_bbox_2_unscaled: 0.0249 (0.0254)  loss_giou_2_unscaled: 0.1952 (0.1795)  cardinality_error_2_unscaled: 2.5000 (3.1439)  loss_ce_3_unscaled: 0.0841 (0.1082)  loss_bbox_3_unscaled: 0.0234 (0.0245)  loss_giou_3_unscaled: 0.2041 (0.1872)  cardinality_error_3_unscaled: 1.0000 (2.2952)  loss_ce_4_unscaled: 0.0778 (0.1042)  loss_bbox_4_unscaled: 0.0211 (0.0241)  loss_giou_4_unscaled: 0.2003 (0.1855)  cardinality_error_4_unscaled: 1.0000 (1.9539)  time: 0.6967  data: 0.0096  max mem: 4284
# ...
# Test:  [250/320]  eta: 0:00:25  class_error: 0.00  loss: 2.9061 (4.5136)  loss_ce: 0.0242 (0.1710)  loss_bbox: 0.0917 (0.1392)  loss_giou: 0.2395 (0.3995)  loss_ce_0: 0.0851 (0.2414)  loss_bbox_0: 0.1271 (0.1733)  loss_giou_0: 0.3080 (0.4743)  loss_ce_1: 0.0493 (0.2212)  loss_bbox_1: 0.1068 (0.1482)  loss_giou_1: 0.2583 (0.3998)  loss_ce_2: 0.0381 (0.1927)  loss_bbox_2: 0.0891 (0.1356)  loss_giou_2: 0.2486 (0.3757)  loss_ce_3: 0.0290 (0.1797)  loss_bbox_3: 0.0977 (0.1408)  loss_giou_3: 0.2665 (0.3989)  loss_ce_4: 0.0223 (0.1770)  loss_bbox_4: 0.0925 (0.1389)  loss_giou_4: 0.2820 (0.4063)  loss_ce_unscaled: 0.0242 (0.1710)  class_error_unscaled: 0.0000 (11.9955)  loss_bbox_unscaled: 0.0183 (0.0278)  loss_giou_unscaled: 0.1197 (0.1998)  cardinality_error_unscaled: 0.5000 (1.2231)  loss_ce_0_unscaled: 0.0851 (0.2414)  loss_bbox_0_unscaled: 0.0254 (0.0347)  loss_giou_0_unscaled: 0.1540 (0.2372)  cardinality_error_0_unscaled: 1.5000 (2.6773)  loss_ce_1_unscaled: 0.0493 (0.2212)  loss_bbox_1_unscaled: 0.0214 (0.0296)  loss_giou_1_unscaled: 0.1292 (0.1999)  cardinality_error_1_unscaled: 0.5000 (1.3267)  loss_ce_2_unscaled: 0.0381 (0.1927)  loss_bbox_2_unscaled: 0.0178 (0.0271)  loss_giou_2_unscaled: 0.1243 (0.1878)  cardinality_error_2_unscaled: 0.5000 (1.6335)  loss_ce_3_unscaled: 0.0290 (0.1797)  loss_bbox_3_unscaled: 0.0195 (0.0282)  loss_giou_3_unscaled: 0.1333 (0.1995)  cardinality_error_3_unscaled: 0.5000 (1.3785)  loss_ce_4_unscaled: 0.0223 (0.1770)  loss_bbox_4_unscaled: 0.0185 (0.0278)  loss_giou_4_unscaled: 0.1410 (0.2031)  cardinality_error_4_unscaled: 0.5000 (1.1275)  time: 0.3654  data: 0.0101  max mem: 5640
# Test:  [260/320]  eta: 0:00:22  class_error: 20.00  loss: 3.2506 (4.5221)  loss_ce: 0.0872 (0.1721)  loss_bbox: 0.0904 (0.1385)  loss_giou: 0.2614 (0.3999)  loss_ce_0: 0.1359 (0.2431)  loss_bbox_0: 0.1318 (0.1733)  loss_giou_0: 0.3436 (0.4771)  loss_ce_1: 0.1544 (0.2223)  loss_bbox_1: 0.1093 (0.1474)  loss_giou_1: 0.2674 (0.3997)  loss_ce_2: 0.0995 (0.1945)  loss_bbox_2: 0.0923 (0.1349)  loss_giou_2: 0.2643 (0.3757)  loss_ce_3: 0.0843 (0.1809)  loss_bbox_3: 0.1026 (0.1401)  loss_giou_3: 0.2678 (0.3992)  loss_ce_4: 0.0925 (0.1787)  loss_bbox_4: 0.0922 (0.1386)  loss_giou_4: 0.2885 (0.4061)  loss_ce_unscaled: 0.0872 (0.1721)  class_error_unscaled: 7.1429 (12.1367)  loss_bbox_unscaled: 0.0181 (0.0277)  loss_giou_unscaled: 0.1307 (0.1999)  cardinality_error_unscaled: 0.5000 (1.2318)  loss_ce_0_unscaled: 0.1359 (0.2431)  loss_bbox_0_unscaled: 0.0264 (0.0347)  loss_giou_0_unscaled: 0.1718 (0.2386)  cardinality_error_0_unscaled: 2.5000 (2.7701)  loss_ce_1_unscaled: 0.1544 (0.2223)  loss_bbox_1_unscaled: 0.0219 (0.0295)  loss_giou_1_unscaled: 0.1337 (0.1998)  cardinality_error_1_unscaled: 0.5000 (1.3602)  loss_ce_2_unscaled: 0.0995 (0.1945)  loss_bbox_2_unscaled: 0.0185 (0.0270)  loss_giou_2_unscaled: 0.1322 (0.1878)  cardinality_error_2_unscaled: 0.5000 (1.6762)  loss_ce_3_unscaled: 0.0843 (0.1809)  loss_bbox_3_unscaled: 0.0205 (0.0280)  loss_giou_3_unscaled: 0.1339 (0.1996)  cardinality_error_3_unscaled: 0.5000 (1.3966)  loss_ce_4_unscaled: 0.0925 (0.1787)  loss_bbox_4_unscaled: 0.0184 (0.0277)  loss_giou_4_unscaled: 0.1442 (0.2030)  cardinality_error_4_unscaled: 0.5000 (1.1456)  time: 0.3680  data: 0.0107  max mem: 5640
# Test:  [270/320]  eta: 0:00:18  class_error: 42.86  loss: 4.1921 (4.5602)  loss_ce: 0.1388 (0.1767)  loss_bbox: 0.1055 (0.1377)  loss_giou: 0.3441 (0.4010)  loss_ce_0: 0.2582 (0.2496)  loss_bbox_0: 0.1318 (0.1727)  loss_giou_0: 0.4521 (0.4789)  loss_ce_1: 0.2598 (0.2280)  loss_bbox_1: 0.1131 (0.1471)  loss_giou_1: 0.4475 (0.4018)  loss_ce_2: 0.2248 (0.2008)  loss_bbox_2: 0.1030 (0.1339)  loss_giou_2: 0.3363 (0.3766)  loss_ce_3: 0.2069 (0.1867)  loss_bbox_3: 0.1105 (0.1395)  loss_giou_3: 0.3659 (0.3999)  loss_ce_4: 0.1877 (0.1835)  loss_bbox_4: 0.1099 (0.1378)  loss_giou_4: 0.3657 (0.4079)  loss_ce_unscaled: 0.1388 (0.1767)  class_error_unscaled: 14.2857 (12.8236)  loss_bbox_unscaled: 0.0211 (0.0275)  loss_giou_unscaled: 0.1721 (0.2005)  cardinality_error_unscaled: 1.0000 (1.2417)  loss_ce_0_unscaled: 0.2582 (0.2496)  loss_bbox_0_unscaled: 0.0264 (0.0345)  loss_giou_0_unscaled: 0.2260 (0.2395)  cardinality_error_0_unscaled: 2.5000 (2.8118)  loss_ce_1_unscaled: 0.2598 (0.2280)  loss_bbox_1_unscaled: 0.0226 (0.0294)  loss_giou_1_unscaled: 0.2238 (0.2009)  cardinality_error_1_unscaled: 1.5000 (1.3967)  loss_ce_2_unscaled: 0.2248 (0.2008)  loss_bbox_2_unscaled: 0.0206 (0.0268)  loss_giou_2_unscaled: 0.1681 (0.1883)  cardinality_error_2_unscaled: 1.5000 (1.7177)  loss_ce_3_unscaled: 0.2069 (0.1867)  loss_bbox_3_unscaled: 0.0221 (0.0279)  loss_giou_3_unscaled: 0.1829 (0.2000)  cardinality_error_3_unscaled: 1.5000 (1.4133)  loss_ce_4_unscaled: 0.1877 (0.1835)  loss_bbox_4_unscaled: 0.0220 (0.0276)  loss_giou_4_unscaled: 0.1829 (0.2039)  cardinality_error_4_unscaled: 1.0000 (1.1476)  time: 0.3699  data: 0.0108  max mem: 5640
# Test:  [280/320]  eta: 0:00:14  class_error: 12.50  loss: 4.0747 (4.5585)  loss_ce: 0.1144 (0.1765)  loss_bbox: 0.1096 (0.1370)  loss_giou: 0.4272 (0.4016)  loss_ce_0: 0.2582 (0.2482)  loss_bbox_0: 0.1319 (0.1736)  loss_giou_0: 0.4422 (0.4800)  loss_ce_1: 0.2146 (0.2267)  loss_bbox_1: 0.1190 (0.1473)  loss_giou_1: 0.4475 (0.4023)  loss_ce_2: 0.1558 (0.2008)  loss_bbox_2: 0.1030 (0.1334)  loss_giou_2: 0.3363 (0.3775)  loss_ce_3: 0.1630 (0.1864)  loss_bbox_3: 0.1173 (0.1392)  loss_giou_3: 0.3786 (0.3996)  loss_ce_4: 0.1448 (0.1832)  loss_bbox_4: 0.1196 (0.1375)  loss_giou_4: 0.3827 (0.4077)  loss_ce_unscaled: 0.1144 (0.1765)  class_error_unscaled: 14.2857 (12.6778)  loss_bbox_unscaled: 0.0219 (0.0274)  loss_giou_unscaled: 0.2136 (0.2008)  cardinality_error_unscaled: 1.5000 (1.2847)  loss_ce_0_unscaled: 0.2582 (0.2482)  loss_bbox_0_unscaled: 0.0264 (0.0347)  loss_giou_0_unscaled: 0.2211 (0.2400)  cardinality_error_0_unscaled: 2.0000 (2.8310)  loss_ce_1_unscaled: 0.2146 (0.2267)  loss_bbox_1_unscaled: 0.0238 (0.0295)  loss_giou_1_unscaled: 0.2238 (0.2011)  cardinality_error_1_unscaled: 1.0000 (1.4235)  loss_ce_2_unscaled: 0.1558 (0.2008)  loss_bbox_2_unscaled: 0.0206 (0.0267)  loss_giou_2_unscaled: 0.1681 (0.1887)  cardinality_error_2_unscaled: 2.5000 (1.8007)  loss_ce_3_unscaled: 0.1630 (0.1864)  loss_bbox_3_unscaled: 0.0235 (0.0278)  loss_giou_3_unscaled: 0.1893 (0.1998)  cardinality_error_3_unscaled: 2.0000 (1.4591)  loss_ce_4_unscaled: 0.1448 (0.1832)  loss_bbox_4_unscaled: 0.0239 (0.0275)  loss_giou_4_unscaled: 0.1913 (0.2038)  cardinality_error_4_unscaled: 1.0000 (1.1922)  time: 0.3686  data: 0.0104  max mem: 5640
# Test:  [290/320]  eta: 0:00:11  class_error: 50.00  loss: 3.6611 (4.6146)  loss_ce: 0.0696 (0.1795)  loss_bbox: 0.1235 (0.1386)  loss_giou: 0.4387 (0.4057)  loss_ce_0: 0.1778 (0.2522)  loss_bbox_0: 0.1826 (0.1747)  loss_giou_0: 0.4830 (0.4833)  loss_ce_1: 0.1645 (0.2301)  loss_bbox_1: 0.1472 (0.1494)  loss_giou_1: 0.4103 (0.4058)  loss_ce_2: 0.1384 (0.2039)  loss_bbox_2: 0.1167 (0.1352)  loss_giou_2: 0.3951 (0.3821)  loss_ce_3: 0.1486 (0.1906)  loss_bbox_3: 0.1305 (0.1408)  loss_giou_3: 0.4329 (0.4047)  loss_ce_4: 0.1448 (0.1878)  loss_bbox_4: 0.1269 (0.1388)  loss_giou_4: 0.4247 (0.4113)  loss_ce_unscaled: 0.0696 (0.1795)  class_error_unscaled: 0.0000 (12.8035)  loss_bbox_unscaled: 0.0247 (0.0277)  loss_giou_unscaled: 0.2193 (0.2029)  cardinality_error_unscaled: 1.0000 (1.2887)  loss_ce_0_unscaled: 0.1778 (0.2522)  loss_bbox_0_unscaled: 0.0365 (0.0349)  loss_giou_0_unscaled: 0.2415 (0.2416)  cardinality_error_0_unscaled: 2.0000 (2.8076)  loss_ce_1_unscaled: 0.1645 (0.2301)  loss_bbox_1_unscaled: 0.0294 (0.0299)  loss_giou_1_unscaled: 0.2051 (0.2029)  cardinality_error_1_unscaled: 1.0000 (1.4072)  loss_ce_2_unscaled: 0.1384 (0.2039)  loss_bbox_2_unscaled: 0.0233 (0.0270)  loss_giou_2_unscaled: 0.1976 (0.1911)  cardinality_error_2_unscaled: 1.0000 (1.7921)  loss_ce_3_unscaled: 0.1486 (0.1906)  loss_bbox_3_unscaled: 0.0261 (0.0282)  loss_giou_3_unscaled: 0.2165 (0.2023)  cardinality_error_3_unscaled: 1.0000 (1.4553)  loss_ce_4_unscaled: 0.1448 (0.1878)  loss_bbox_4_unscaled: 0.0254 (0.0278)  loss_giou_4_unscaled: 0.2124 (0.2056)  cardinality_error_4_unscaled: 1.0000 (1.2027)  time: 0.3646  data: 0.0101  max mem: 5640
# Test:  [300/320]  eta: 0:00:07  class_error: 9.09  loss: 4.7184 (4.6309)  loss_ce: 0.2041 (0.1812)  loss_bbox: 0.1061 (0.1387)  loss_giou: 0.4333 (0.4066)  loss_ce_0: 0.2813 (0.2530)  loss_bbox_0: 0.1515 (0.1751)  loss_giou_0: 0.5271 (0.4849)  loss_ce_1: 0.2775 (0.2316)  loss_bbox_1: 0.1094 (0.1498)  loss_giou_1: 0.4103 (0.4070)  loss_ce_2: 0.1647 (0.2047)  loss_bbox_2: 0.1039 (0.1358)  loss_giou_2: 0.4194 (0.3835)  loss_ce_3: 0.1486 (0.1908)  loss_bbox_3: 0.1096 (0.1415)  loss_giou_3: 0.4665 (0.4064)  loss_ce_4: 0.1875 (0.1899)  loss_bbox_4: 0.1001 (0.1389)  loss_giou_4: 0.4242 (0.4116)  loss_ce_unscaled: 0.2041 (0.1812)  class_error_unscaled: 9.0909 (12.8472)  loss_bbox_unscaled: 0.0212 (0.0277)  loss_giou_unscaled: 0.2167 (0.2033)  cardinality_error_unscaled: 1.0000 (1.3189)  loss_ce_0_unscaled: 0.2813 (0.2530)  loss_bbox_0_unscaled: 0.0303 (0.0350)  loss_giou_0_unscaled: 0.2635 (0.2425)  cardinality_error_0_unscaled: 3.0000 (2.8355)  loss_ce_1_unscaled: 0.2775 (0.2316)  loss_bbox_1_unscaled: 0.0219 (0.0300)  loss_giou_1_unscaled: 0.2051 (0.2035)  cardinality_error_1_unscaled: 1.5000 (1.4402)  loss_ce_2_unscaled: 0.1647 (0.2047)  loss_bbox_2_unscaled: 0.0208 (0.0272)  loss_giou_2_unscaled: 0.2097 (0.1917)  cardinality_error_2_unscaled: 1.0000 (1.8223)  loss_ce_3_unscaled: 0.1486 (0.1908)  loss_bbox_3_unscaled: 0.0219 (0.0283)  loss_giou_3_unscaled: 0.2333 (0.2032)  cardinality_error_3_unscaled: 1.0000 (1.4784)  loss_ce_4_unscaled: 0.1875 (0.1899)  loss_bbox_4_unscaled: 0.0200 (0.0278)  loss_giou_4_unscaled: 0.2121 (0.2058)  cardinality_error_4_unscaled: 1.0000 (1.2209)  time: 0.3642  data: 0.0107  max mem: 5640
# Test:  [310/320]  eta: 0:00:03  class_error: 9.09  loss: 4.3370 (4.6358)  loss_ce: 0.1619 (0.1813)  loss_bbox: 0.0999 (0.1380)  loss_giou: 0.3920 (0.4087)  loss_ce_0: 0.2607 (0.2533)  loss_bbox_0: 0.1397 (0.1742)  loss_giou_0: 0.4995 (0.4869)  loss_ce_1: 0.2296 (0.2310)  loss_bbox_1: 0.1080 (0.1488)  loss_giou_1: 0.4070 (0.4098)  loss_ce_2: 0.1512 (0.2036)  loss_bbox_2: 0.0981 (0.1350)  loss_giou_2: 0.4033 (0.3848)  loss_ce_3: 0.1135 (0.1903)  loss_bbox_3: 0.1046 (0.1408)  loss_giou_3: 0.4310 (0.4070)  loss_ce_4: 0.1453 (0.1899)  loss_bbox_4: 0.0998 (0.1384)  loss_giou_4: 0.4207 (0.4141)  loss_ce_unscaled: 0.1619 (0.1813)  class_error_unscaled: 10.0000 (12.9394)  loss_bbox_unscaled: 0.0200 (0.0276)  loss_giou_unscaled: 0.1960 (0.2043)  cardinality_error_unscaled: 0.5000 (1.3039)  loss_ce_0_unscaled: 0.2607 (0.2533)  loss_bbox_0_unscaled: 0.0279 (0.0348)  loss_giou_0_unscaled: 0.2498 (0.2434)  cardinality_error_0_unscaled: 4.0000 (2.8714)  loss_ce_1_unscaled: 0.2296 (0.2310)  loss_bbox_1_unscaled: 0.0216 (0.0298)  loss_giou_1_unscaled: 0.2035 (0.2049)  cardinality_error_1_unscaled: 1.5000 (1.4421)  loss_ce_2_unscaled: 0.1512 (0.2036)  loss_bbox_2_unscaled: 0.0196 (0.0270)  loss_giou_2_unscaled: 0.2016 (0.1924)  cardinality_error_2_unscaled: 1.0000 (1.8280)  loss_ce_3_unscaled: 0.1135 (0.1903)  loss_bbox_3_unscaled: 0.0209 (0.0282)  loss_giou_3_unscaled: 0.2155 (0.2035)  cardinality_error_3_unscaled: 1.0000 (1.4759)  loss_ce_4_unscaled: 0.1453 (0.1899)  loss_bbox_4_unscaled: 0.0200 (0.0277)  loss_giou_4_unscaled: 0.2103 (0.2070)  cardinality_error_4_unscaled: 0.5000 (1.2122)  time: 0.3728  data: 0.0110  max mem: 5640
# Test:  [319/320]  eta: 0:00:00  class_error: 0.00  loss: 3.9962 (4.6006)  loss_ce: 0.0619 (0.1792)  loss_bbox: 0.0989 (0.1368)  loss_giou: 0.3394 (0.4065)  loss_ce_0: 0.2147 (0.2507)  loss_bbox_0: 0.1190 (0.1726)  loss_giou_0: 0.4121 (0.4840)  loss_ce_1: 0.1752 (0.2289)  loss_bbox_1: 0.1015 (0.1475)  loss_giou_1: 0.3766 (0.4082)  loss_ce_2: 0.1301 (0.2010)  loss_bbox_2: 0.0962 (0.1337)  loss_giou_2: 0.3398 (0.3825)  loss_ce_3: 0.1081 (0.1880)  loss_bbox_3: 0.1041 (0.1396)  loss_giou_3: 0.3744 (0.4048)  loss_ce_4: 0.0723 (0.1878)  loss_bbox_4: 0.0945 (0.1371)  loss_giou_4: 0.3799 (0.4116)  loss_ce_unscaled: 0.0619 (0.1792)  class_error_unscaled: 9.0909 (12.9088)  loss_bbox_unscaled: 0.0198 (0.0274)  loss_giou_unscaled: 0.1697 (0.2033)  cardinality_error_unscaled: 0.5000 (1.2891)  loss_ce_0_unscaled: 0.2147 (0.2507)  loss_bbox_0_unscaled: 0.0238 (0.0345)  loss_giou_0_unscaled: 0.2061 (0.2420)  cardinality_error_0_unscaled: 2.5000 (2.8422)  loss_ce_1_unscaled: 0.1752 (0.2289)  loss_bbox_1_unscaled: 0.0203 (0.0295)  loss_giou_1_unscaled: 0.1883 (0.2041)  cardinality_error_1_unscaled: 1.0000 (1.4297)  loss_ce_2_unscaled: 0.1301 (0.2010)  loss_bbox_2_unscaled: 0.0192 (0.0267)  loss_giou_2_unscaled: 0.1699 (0.1912)  cardinality_error_2_unscaled: 1.0000 (1.8016)  loss_ce_3_unscaled: 0.1081 (0.1880)  loss_bbox_3_unscaled: 0.0208 (0.0279)  loss_giou_3_unscaled: 0.1872 (0.2024)  cardinality_error_3_unscaled: 0.5000 (1.4563)  loss_ce_4_unscaled: 0.0723 (0.1878)  loss_bbox_4_unscaled: 0.0189 (0.0274)  loss_giou_4_unscaled: 0.1899 (0.2058)  cardinality_error_4_unscaled: 0.5000 (1.1969)  time: 0.3699  data: 0.0106  max mem: 5640
# Test: Total time: 0:01:58 (0.3707 s / it)
# Averaged stats: class_error: 0.00  loss: 3.9962 (4.6006)  loss_ce: 0.0619 (0.1792)  loss_bbox: 0.0989 (0.1368)  loss_giou: 0.3394 (0.4065)  loss_ce_0: 0.2147 (0.2507)  loss_bbox_0: 0.1190 (0.1726)  loss_giou_0: 0.4121 (0.4840)  loss_ce_1: 0.1752 (0.2289)  loss_bbox_1: 0.1015 (0.1475)  loss_giou_1: 0.3766 (0.4082)  loss_ce_2: 0.1301 (0.2010)  loss_bbox_2: 0.0962 (0.1337)  loss_giou_2: 0.3398 (0.3825)  loss_ce_3: 0.1081 (0.1880)  loss_bbox_3: 0.1041 (0.1396)  loss_giou_3: 0.3744 (0.4048)  loss_ce_4: 0.0723 (0.1878)  loss_bbox_4: 0.0945 (0.1371)  loss_giou_4: 0.3799 (0.4116)  loss_ce_unscaled: 0.0619 (0.1792)  class_error_unscaled: 9.0909 (12.9088)  loss_bbox_unscaled: 0.0198 (0.0274)  loss_giou_unscaled: 0.1697 (0.2033)  cardinality_error_unscaled: 0.5000 (1.2891)  loss_ce_0_unscaled: 0.2147 (0.2507)  loss_bbox_0_unscaled: 0.0238 (0.0345)  loss_giou_0_unscaled: 0.2061 (0.2420)  cardinality_error_0_unscaled: 2.5000 (2.8422)  loss_ce_1_unscaled: 0.1752 (0.2289)  loss_bbox_1_unscaled: 0.0203 (0.0295)  loss_giou_1_unscaled: 0.1883 (0.2041)  cardinality_error_1_unscaled: 1.0000 (1.4297)  loss_ce_2_unscaled: 0.1301 (0.2010)  loss_bbox_2_unscaled: 0.0192 (0.0267)  loss_giou_2_unscaled: 0.1699 (0.1912)  cardinality_error_2_unscaled: 1.0000 (1.8016)  loss_ce_3_unscaled: 0.1081 (0.1880)  loss_bbox_3_unscaled: 0.0208 (0.0279)  loss_giou_3_unscaled: 0.1872 (0.2024)  cardinality_error_3_unscaled: 0.5000 (1.4563)  loss_ce_4_unscaled: 0.0723 (0.1878)  loss_bbox_4_unscaled: 0.0189 (0.0274)  loss_giou_4_unscaled: 0.1899 (0.2058)  cardinality_error_4_unscaled: 0.5000 (1.1969)
# Accumulating evaluation results...
# DONE (t=0.65s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.599
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.832
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.675
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.042
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.211
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.652
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.375
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.673
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.724
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.071
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.315
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.771
# Training time 2:29:39

# %% [markdown]
# ## Check the results

# %% [markdown]
# ### Monitoring of training
#
# Reference: https://github.com/lessw2020/Thunder-Detr/blob/master/View_your_training_results.ipynb

# %%
from util.plot_utils import plot_logs
from pathlib import Path

log_directory = [Path('outputs/')]

# %% [markdown]
#   As mentioned in the code of [`plot_logs`](https://github.com/facebookresearch/detr/blob/5e66b4cd15b2b182da347103dd16578d28b49d69/util/plot_utils.py#L13):
# -   solid lines are training results,
# -   dashed lines are validation results.

# %%
fields_of_interest = (
    'loss',
    'mAP',
    )

plot_logs(log_directory,
          fields_of_interest)

# %%
fields_of_interest = (
    'loss_ce',
    'loss_bbox',
    'loss_giou',
    )

plot_logs(log_directory,
          fields_of_interest)

# %%
fields_of_interest = (
    'class_error',
    'cardinality_error_unscaled',
    )

plot_logs(log_directory,
          fields_of_interest)

# %% [markdown]
# ### Load the fine-tuned model
#
# - Explanation: https://github.com/facebookresearch/detr/issues/9#issuecomment-636391562

# %%
model = torch.hub.load('facebookresearch/detr',
                       'detr_resnet101',
                       pretrained=False,
                       num_classes=num_classes)

checkpoint = torch.load('outputs/checkpoint.pth',
                        map_location='cpu')

model.load_state_dict(checkpoint['model'],
                      strict=False)

model.eval();

# %% [markdown]
# ### Boilerplate functions to display fine-tuned results

# %%
def plot_finetuned_results(pil_img, prob=None, boxes=None):
    plt.figure(figsize=(16,10))
    plt.imshow(pil_img)
    ax = plt.gca()
    colors = COLORS * 100
    if prob is not None and boxes is not None:
      for p, (xmin, ymin, xmax, ymax), c in zip(prob, boxes.tolist(), colors):
          ax.add_patch(plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                    fill=False, color=c, linewidth=3))
          cl = p.argmax()
          text = f'{finetuned_classes[cl]}: {p[cl]:0.2f}'
          ax.text(xmin, ymin, text, fontsize=15,
                  bbox=dict(facecolor='yellow', alpha=0.5))
    plt.axis('off')
    plt.show()

# %%
def run_worflow(my_image, my_model):
  # mean-std normalize the input image (batch-size: 1)
  img = transform(my_image).unsqueeze(0)

  # propagate through the model
  outputs = my_model(img)

  for threshold in [0.85, 0.5, 0.0]:
    
    probas_to_keep, bboxes_scaled = filter_bboxes_from_outputs(outputs, my_image.size,
                                                               threshold=threshold)

    plot_finetuned_results(my_image,
                           probas_to_keep, 
                           bboxes_scaled)

# %% [markdown]
# ### With a training image

# %%
train_path = proj_path+'/content/data/POD/train/'
imgs = os.listdir(train_path)
rand_img = imgs[np.random.randint(0,len(imgs))]

os.chdir(proj_path)
print(os.getcwd())
img_name = proj_path + '/content/data/POD/train/' + rand_img

im = Image.open(img_name)

run_worflow(im,
            model)
# Out:
# /content/drive/My Drive/Main Task

# %% [markdown]
# ### With a validation image

# %%
val_path = proj_path+'/content/data/POD/val/'
imgs = os.listdir(val_path)
rand_img = imgs[np.random.randint(0,len(imgs))]

img_name = proj_path + '/content/data/POD/val/' + rand_img
im = Image.open(img_name)

run_worflow(im,
            model)

# %% [markdown]
# ## Evaluate on dataset

# %%
from tqdm.notebook import tqdm
import json
import pandas as pd

dataDir=proj_path+'/content/data/POD/'

# %% [markdown]
# ## Boilerplate functions to save the outputs to a json file and evaluate

# %%
def save_outputs(dataType):

  annFile = dataDir + '/annotations/' + dataType + '.json'
  output_annotation_file = proj_path+'/content/detr/outputs/predictions_' + dataType + '.json'
  coco=COCO(annFile)
  imgIds = coco.getImgIds()

  img_data = []

  for imgId in tqdm(imgIds):

    img = coco.loadImgs(imgId)[0]
    img_name = '%s/%s/%s'%(dataDir,dataType,img['file_name'])
    #print(img_name)

    im = Image.open(img_name)
    im1 = transform(im).unsqueeze(0)

    # propagate through the model
    outputs = model(im1)

    annotations_tmp = {}
    for logits,boxes in zip(outputs["pred_logits"],outputs["pred_boxes"]):
      annotations_tmp['image_id'] = imgId
      annotations_tmp['image_size'] = im.size
      annotations_tmp['pred_logits'] = logits.tolist()
      annotations_tmp['pred_boxes'] = boxes.tolist()
      img_data.append(annotations_tmp)

  #save the outputs to a json file
  outfile =  open(output_annotation_file, 'w')
  json_str = json.dumps(img_data, indent=4)
  outfile.write(json_str)
  outfile.close()

# %%
def make_predictions(dataType,results,bb_threshold = 0.85):
  
  annFile = dataDir + '/annotations/' + dataType + '.json'
  output_annotation_file = proj_path+'/content/detr/outputs/predictions_' + dataType + '.json'
  coco=COCO(annFile)
  imgIds = coco.getImgIds()

  iou_threshold = 0.5

  #load the outputs from the json file to a dictionary
  with open(output_annotation_file) as json_file: 
      img_data = json.load(json_file)

  for imgId in imgIds:
    
    img = coco.loadImgs(imgId)[0]
    img_name = '%s/%s/%s'%(dataDir,dataType,img['file_name'])
    #print(img_name)

    annIds = coco.getAnnIds(imgIds=img['id'])
    anns = coco.loadAnns(annIds)
    #_ = [print(ann) for ann in anns]
    #I = io.imread(img_name)
    #plt.imshow(I)
    #coco.showAnns(anns, draw_bbox=True)

    outputs = {}
    outputs["pred_logits"] = torch.FloatTensor([img_data[imgIds.index(imgId)]["pred_logits"]])
    outputs["pred_boxes"] =  torch.FloatTensor([img_data[imgIds.index(imgId)]["pred_boxes"]])

    prob, boxes = filter_bboxes_from_outputs(outputs, img_data[imgIds.index(imgId)]['image_size'], threshold=bb_threshold)
    #print(prob, boxes)
    #plot_finetuned_results(I, prob, boxes)


    for ann in anns:
      bb1 = list(ann['bbox'])
      cat1 = ann['category_id']
      results[cat1]['rel'] += 1

      #add del x, del y to x1, y1 to get x2, y2
      bb1[2] += bb1[0]; bb1[3] += bb1[1]
      for p, bb2 in zip(prob, boxes.tolist()):
        cat2 = int(p.argmax())
        if bb_intersection_over_union(bb1,bb2) >= iou_threshold and cat1==cat2:
          results[cat1]['rel_ret'] += 1
          break

    for p in prob:
      cat2 = int(p.argmax())
      results[cat2]['ret'] += 1

  for cat in results:
    if cat['rel_ret'] != 0:
      cat['prec'] = cat['rel_ret'] / cat['ret']
      cat['rec'] = cat['rel_ret'] / cat['rel']
      cat['F1'] = 2 * (cat['prec']*cat['rec'])/((cat['prec']+cat['rec']))

  print_results(results)
  return results

# %%
def print_results(results):
  df = pd.DataFrame(results)
  df = df[(df.rel!=0) | (df.ret!=0) | (df.rel_ret!=0)]
  print(df)
  print("\nMean")
  print(df[["prec", "rec", "F1"]].mean())

# %% [markdown]
# ## Evaluate and save the results

# %%
save_outputs(dataType='val')
# Out:
# loading annotations into memory...
# Done (t=0.30s)
# creating index...
# index created!
# HBox(children=(FloatProgress(value=0.0, max=640.0), HTML(value='')))

# %%
save_outputs(dataType='train')
# Out:
# loading annotations into memory...
# Done (t=0.03s)
# creating index...
# index created!
# HBox(children=(FloatProgress(value=0.0, max=960.0), HTML(value='')))

# %% [markdown]
# ## Print results

# %%
nms = ['figure', 'formula', 'table']
results = []
for i in range(num_classes):
  results.append({'class':nms[i], 'rel':0, 'ret':0, 'rel_ret':0, 'prec':0, 'rec':0, 'F1':0})

results = make_predictions('val',results)
#results = make_predictions('train',results)
